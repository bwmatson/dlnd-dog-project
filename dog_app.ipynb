# %% [markdown]
# # Artificial Intelligence Nanodegree
#
# ## Convolutional Neural Networks
#
# ## Project: Write an Algorithm for a Dog Identification App
#
# ---
#
# In this notebook, some template code has already been provided for you, and you will need to implement additional functionality to successfully complete this project. You will not need to modify the included code beyond what is requested. Sections that begin with **'(IMPLEMENTATION)'** in the header indicate that the following block of code will require additional functionality which you must provide. Instructions will be provided for each section, and the specifics of the implementation are marked in the code block with a 'TODO' statement. Please be sure to read the instructions carefully!
#
# > **Note**: Once you have completed all of the code implementations, you need to finalize your work by exporting the iPython Notebook as an HTML document. Before exporting the notebook to html, all of the code cells need to have been run so that reviewers can see the final implementation and output. You can then export the notebook by using the menu above and navigating to  \n",
#     "**File -> Download as -> HTML (.html)**. Include the finished document along with this notebook as your submission.
#
# In addition to implementing code, there will be questions that you must answer which relate to the project and your implementation. Each section where you will answer a question is preceded by a **'Question X'** header. Carefully read each question and provide thorough answers in the following text boxes that begin with **'Answer:'**. Your project submission will be evaluated based on your answers to each of the questions and the implementation you provide.
#
# >**Note:** Code and Markdown cells can be executed using the **Shift + Enter** keyboard shortcut.  Markdown cells can be edited by double-clicking the cell to enter edit mode.
#
# The rubric contains _optional_ "Stand Out Suggestions" for enhancing the project beyond the minimum requirements. If you decide to pursue the "Stand Out Suggestions", you should include the code in this IPython notebook.
#
#
#
# ---
# ### Why We're Here
#
# In this notebook, you will make the first steps towards developing an algorithm that could be used as part of a mobile or web app.  At the end of this project, your code will accept any user-supplied image as input.  If a dog is detected in the image, it will provide an estimate of the dog's breed.  If a human is detected, it will provide an estimate of the dog breed that is most resembling.  The image below displays potential sample output of your finished project (... but we expect that each student's algorithm will behave differently!).
#
# ![Sample Dog Output](images/sample_dog_output.png)
#
# In this real-world setting, you will need to piece together a series of models to perform different tasks; for instance, the algorithm that detects humans in an image will be different from the CNN that infers dog breed.  There are many points of possible failure, and no perfect algorithm exists.  Your imperfect solution will nonetheless create a fun user experience!
#
# ### The Road Ahead
#
# We break the notebook into separate steps.  Feel free to use the links below to navigate the notebook.
#
# * [Step 0](#step0): Import Datasets
# * [Step 1](#step1): Detect Humans
# * [Step 2](#step2): Detect Dogs
# * [Step 3](#step3): Create a CNN to Classify Dog Breeds (from Scratch)
# * [Step 4](#step4): Use a CNN to Classify Dog Breeds (using Transfer Learning)
# * [Step 5](#step5): Create a CNN to Classify Dog Breeds (using Transfer Learning)
# * [Step 6](#step6): Write your Algorithm
# * [Step 7](#step7): Test Your Algorithm
#
# ---
# <a id='step0'></a>
# ## Step 0: Import Datasets
#
# ### Import Dog Dataset
#
# In the code cell below, we import a dataset of dog images.  We populate a few variables through the use of the `load_files` function from the scikit-learn library:
# - `train_files`, `valid_files`, `test_files` - numpy arrays containing file paths to images
# - `train_targets`, `valid_targets`, `test_targets` - numpy arrays containing onehot-encoded classification labels
# - `dog_names` - list of string-valued dog breed names for translating labels

# %%
from sklearn.datasets import load_files       
from keras.utils import np_utils
import numpy as np
from glob import glob

# define function to load train, test, and validation datasets
def load_dataset(path):
    data = load_files(path)
    dog_files = np.array(data['filenames'])
    dog_targets = np_utils.to_categorical(np.array(data['target']), 133)
    return dog_files, dog_targets

# load train, test, and validation datasets
train_files, train_targets = load_dataset('dogImages/train')
valid_files, valid_targets = load_dataset('dogImages/valid')
test_files, test_targets = load_dataset('dogImages/test')

# load list of dog names
dog_names = [item[20:-1] for item in sorted(glob("dogImages/train/*/"))]

# print statistics about the dataset
print('There are %d total dog categories.' % len(dog_names))
print('There are %s total dog images.\n' % len(np.hstack([train_files, valid_files, test_files])))
print('There are %d training dog images.' % len(train_files))
print('There are %d validation dog images.' % len(valid_files))
print('There are %d test dog images.'% len(test_files))
# Out:
# C:\Users\bmatson\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# There are 133 total dog categories.
# There are 8351 total dog images.
#
# There are 6680 training dog images.
# There are 835 validation dog images.
# There are 836 test dog images.

# %% [markdown]
# ### Import Human Dataset
#
# In the code cell below, we import a dataset of human images, where the file paths are stored in the numpy array `human_files`.

# %%
import random
random.seed(8675309)

# load filenames in shuffled human dataset
human_files = np.array(glob("lfw/*/*"))
random.shuffle(human_files)

# print statistics about the dataset
print('There are %d total human images.' % len(human_files))
# Out:
# There are 13233 total human images.

# %% [markdown]
# ---
# <a id='step1'></a>
# ## Step 1: Detect Humans
#
# We use OpenCV's implementation of [Haar feature-based cascade classifiers](http://docs.opencv.org/trunk/d7/d8b/tutorial_py_face_detection.html) to detect human faces in images.  OpenCV provides many pre-trained face detectors, stored as XML files on [github](https://github.com/opencv/opencv/tree/master/data/haarcascades).  We have downloaded one of these detectors and stored it in the `haarcascades` directory.
#
# In the next code cell, we demonstrate how to use this detector to find human faces in a sample image.

# %%
import cv2                
import matplotlib.pyplot as plt                        
# %matplotlib inline                               

# extract pre-trained face detector
face_cascade = cv2.CascadeClassifier('haarcascades/haarcascade_frontalface_alt.xml')

# load color (BGR) image
img = cv2.imread(human_files[3])
# convert BGR image to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# find faces in image
faces = face_cascade.detectMultiScale(gray)

# print number of faces detected in the image
print('Number of faces detected:', len(faces))

# get bounding box for each detected face
for (x,y,w,h) in faces:
    # add bounding box to color image
    cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    
# convert BGR image to RGB for plotting
cv_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# display the image, along with bounding box
plt.imshow(cv_rgb)
plt.show()
# Out:
# Number of faces detected: 1

# %% [markdown]
# Before using any of the face detectors, it is standard procedure to convert the images to grayscale.  The `detectMultiScale` function executes the classifier stored in `face_cascade` and takes the grayscale image as a parameter.
#
# In the above code, `faces` is a numpy array of detected faces, where each row corresponds to a detected face.  Each detected face is a 1D array with four entries that specifies the bounding box of the detected face.  The first two entries in the array (extracted in the above code as `x` and `y`) specify the horizontal and vertical positions of the top left corner of the bounding box.  The last two entries in the array (extracted here as `w` and `h`) specify the width and height of the box.
#
# ### Write a Human Face Detector
#
# We can use this procedure to write a function that returns `True` if a human face is detected in an image and `False` otherwise.  This function, aptly named `face_detector`, takes a string-valued file path to an image as input and appears in the code block below.

# %%
# returns "True" if face is detected in image stored at img_path
def face_detector(img_path):
    img = cv2.imread(img_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray)
    return len(faces) > 0

# %% [markdown]
# ### (IMPLEMENTATION) Assess the Human Face Detector
#
# __Question 1:__ Use the code cell below to test the performance of the `face_detector` function.
# - What percentage of the first 100 images in `human_files` have a detected human face?
# - What percentage of the first 100 images in `dog_files` have a detected human face?
#
# Ideally, we would like 100% of human images with a detected face and 0% of dog images with a detected face.  You will see that our algorithm falls short of this goal, but still gives acceptable performance.  We extract the file paths for the first 100 images from each of the datasets and store them in the numpy arrays `human_files_short` and `dog_files_short`.
#
# __Answer:__

# %%
sample = 100

human_files_short = human_files[:sample]
dog_files_short = train_files[:sample]
# Do NOT modify the code above this line.

## TODO: Test the performance of the face_detector algorithm 
human_correct = 0
for human_image in human_files_short:
    result = face_detector(human_image)
    if result:
        human_correct += 1
        
dog_correct = 0
for dog_image in dog_files_short:
    result = face_detector(dog_image)
    if not result:
        dog_correct += 1
        
human_correct_percentage = 100. * float(human_correct) / len(human_files_short)
dog_correct_percentage = 100. * float(dog_correct) / len(dog_files_short)

print(str(human_correct_percentage) + '% of humans were categorized as humans')
print(str(dog_correct_percentage) + '% of dogs were categorized as not humans')
# Out:
# 99.0% of humans were categorized as humans
# 88.0% of dogs were categorized as not humans

# %% [markdown]
# __Question 2:__ This algorithmic choice necessitates that we communicate to the user that we accept human images only when they provide a clear view of a face (otherwise, we risk having unneccessarily frustrated users!). In your opinion, is this a reasonable expectation to pose on the user? If not, can you think of a way to detect humans in images that does not necessitate an image with a clearly presented face?
#
# __Answer:__
#
# We suggest the face detector from OpenCV as a potential way to detect human images in your algorithm, but you are free to explore other approaches, especially approaches that make use of deep learning :).  Please use the code cell below to design and test your own face detection algorithm.  If you decide to pursue this _optional_ task, report performance on each of the datasets.

# %%
## (Optional) TODO: Report the performance of another  
## face detection algorithm on the LFW dataset
### Feel free to use as many code cells as needed.

# Haar cascades seems to be very effective as classify humans and it did good at classifying dogs as not humans 
# especially consideing that some dog images had humans in them.

# %% [markdown]
# ---
# <a id='step2'></a>
# ## Step 2: Detect Dogs
#
# In this section, we use a pre-trained [ResNet-50](http://ethereon.github.io/netscope/#/gist/db945b393d40bfa26006) model to detect dogs in images.  Our first line of code downloads the ResNet-50 model, along with weights that have been trained on [ImageNet](http://www.image-net.org/), a very large, very popular dataset used for image classification and other vision tasks.  ImageNet contains over 10 million URLs, each linking to an image containing an object from one of [1000 categories](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a).  Given an image, this pre-trained ResNet-50 model returns a prediction (derived from the available categories in ImageNet) for the object that is contained in the image.

# %%
from keras.applications.resnet50 import ResNet50

# define ResNet50 model
ResNet50_model = ResNet50(weights='imagenet')

# %% [markdown]
# ### Pre-process the Data
#
# When using TensorFlow as backend, Keras CNNs require a 4D array (which we'll also refer to as a 4D tensor) as input, with shape
#
# $$
# (\text{nb_samples}, \text{rows}, \text{columns}, \text{channels}),
# $$
#
# where `nb_samples` corresponds to the total number of images (or samples), and `rows`, `columns`, and `channels` correspond to the number of rows, columns, and channels for each image, respectively.
#
# The `path_to_tensor` function below takes a string-valued file path to a color image as input and returns a 4D tensor suitable for supplying to a Keras CNN.  The function first loads the image and resizes it to a square image that is $224 \times 224$ pixels.  Next, the image is converted to an array, which is then resized to a 4D tensor.  In this case, since we are working with color images, each image has three channels.  Likewise, since we are processing a single image (or sample), the returned tensor will always have shape
#
# $$
# (1, 224, 224, 3).
# $$
#
# The `paths_to_tensor` function takes a numpy array of string-valued image paths as input and returns a 4D tensor with shape
#
# $$
# (\text{nb_samples}, 224, 224, 3).
# $$
#
# Here, `nb_samples` is the number of samples, or number of images, in the supplied array of image paths.  It is best to think of `nb_samples` as the number of 3D tensors (where each 3D tensor corresponds to a different image) in your dataset!

# %%
from keras.preprocessing import image                  
from tqdm import tqdm

def path_to_tensor(img_path):
    # loads RGB image as PIL.Image.Image type
    img = image.load_img(img_path, target_size=(224, 224))
    # convert PIL.Image.Image type to 3D tensor with shape (224, 224, 3)
    x = image.img_to_array(img)
    # convert 3D tensor to 4D tensor with shape (1, 224, 224, 3) and return 4D tensor
    return np.expand_dims(x, axis=0)

def paths_to_tensor(img_paths):
    list_of_tensors = [path_to_tensor(img_path) for img_path in tqdm(img_paths)]
    return np.vstack(list_of_tensors)

# %% [markdown]
# ### Making Predictions with ResNet-50
#
# Getting the 4D tensor ready for ResNet-50, and for any other pre-trained model in Keras, requires some additional processing.  First, the RGB image is converted to BGR by reordering the channels.  All pre-trained models have the additional normalization step that the mean pixel (expressed in RGB as $[103.939, 116.779, 123.68]$ and calculated from all pixels in all images in ImageNet) must be subtracted from every pixel in each image.  This is implemented in the imported function `preprocess_input`.  If you're curious, you can check the code for `preprocess_input` [here](https://github.com/fchollet/keras/blob/master/keras/applications/imagenet_utils.py).
#
# Now that we have a way to format our image for supplying to ResNet-50, we are now ready to use the model to extract the predictions.  This is accomplished with the `predict` method, which returns an array whose $i$-th entry is the model's predicted probability that the image belongs to the $i$-th ImageNet category.  This is implemented in the `ResNet50_predict_labels` function below.
#
# By taking the argmax of the predicted probability vector, we obtain an integer corresponding to the model's predicted object class, which we can identify with an object category through the use of this [dictionary](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a).

# %%
from keras.applications.resnet50 import preprocess_input, decode_predictions

def ResNet50_predict_labels(img_path):
    # returns prediction vector for image located at img_path
    img = preprocess_input(path_to_tensor(img_path))
    return np.argmax(ResNet50_model.predict(img))

# %% [markdown]
# ### Write a Dog Detector
#
# While looking at the [dictionary](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a), you will notice that the categories corresponding to dogs appear in an uninterrupted sequence and correspond to dictionary keys 151-268, inclusive, to include all categories from `'Chihuahua'` to `'Mexican hairless'`.  Thus, in order to check to see if an image is predicted to contain a dog by the pre-trained ResNet-50 model, we need only check if the `ResNet50_predict_labels` function above returns a value between 151 and 268 (inclusive).
#
# We use these ideas to complete the `dog_detector` function below, which returns `True` if a dog is detected in an image (and `False` if not).

# %%
### returns "True" if a dog is detected in the image stored at img_path
def dog_detector(img_path):
    prediction = ResNet50_predict_labels(img_path)
    return ((prediction <= 268) & (prediction >= 151))

# %% [markdown]
# ### (IMPLEMENTATION) Assess the Dog Detector
#
# __Question 3:__ Use the code cell below to test the performance of your `dog_detector` function.
# - What percentage of the images in `human_files_short` have a detected dog?
# - What percentage of the images in `dog_files_short` have a detected dog?
#
# __Answer:__

# %%
### TODO: Test the performance of the dog_detector function
human_correct = 0
for human_image in human_files_short:
    result = dog_detector(human_image)
    if not result:
        human_correct += 1
        
dog_correct = 0
for dog_image in dog_files_short:
    result = dog_detector(dog_image)
    if result:
        dog_correct += 1

print(str(human_correct) + '% of humans were categorized as not dogs')
print(str(dog_correct) + '% of dogs were categorized as dogs')
# Out:
# 99% of humans were categorized as not dogs
# 100% of dogs were categorized as dogs

# %% [markdown]
# ---
# <a id='step3'></a>
# ## Step 3: Create a CNN to Classify Dog Breeds (from Scratch)
#
# Now that we have functions for detecting humans and dogs in images, we need a way to predict breed from images.  In this step, you will create a CNN that classifies dog breeds.  You must create your CNN _from scratch_ (so, you can't use transfer learning _yet_!), and you must attain a test accuracy of at least 1%.  In Step 5 of this notebook, you will have the opportunity to use transfer learning to create a CNN that attains greatly improved accuracy.
#
# Be careful with adding too many trainable layers!  More parameters means longer training, which means you are more likely to need a GPU to accelerate the training process.  Thankfully, Keras provides a handy estimate of the time that each epoch is likely to take; you can extrapolate this estimate to figure out how long it will take for your algorithm to train.
#
# We mention that the task of assigning breed to dogs from images is considered exceptionally challenging.  To see why, consider that *even a human* would have great difficulty in distinguishing between a Brittany and a Welsh Springer Spaniel.
#
# Brittany | Welsh Springer Spaniel
# - | -
# <img src="images/Brittany_02625.jpg" width="100"> | <img src="images/Welsh_springer_spaniel_08203.jpg" width="200">
#
# It is not difficult to find other dog breed pairs with minimal inter-class variation (for instance, Curly-Coated Retrievers and American Water Spaniels).
#
# Curly-Coated Retriever | American Water Spaniel
# - | -
# <img src="images/Curly-coated_retriever_03896.jpg" width="200"> | <img src="images/American_water_spaniel_00648.jpg" width="200">
#
#
# Likewise, recall that labradors come in yellow, chocolate, and black.  Your vision-based algorithm will have to conquer this high intra-class variation to determine how to classify all of these different shades as the same breed.
#
# Yellow Labrador | Chocolate Labrador | Black Labrador
# - | -
# <img src="images/Labrador_retriever_06457.jpg" width="150"> | <img src="images/Labrador_retriever_06455.jpg" width="240"> | <img src="images/Labrador_retriever_06449.jpg" width="220">
#
# We also mention that random chance presents an exceptionally low bar: setting aside the fact that the classes are slightly imabalanced, a random guess will provide a correct answer roughly 1 in 133 times, which corresponds to an accuracy of less than 1%.
#
# Remember that the practice is far ahead of the theory in deep learning.  Experiment with many different architectures, and trust your intuition.  And, of course, have fun!
#
# ### Pre-process the Data
#
# We rescale the images by dividing every pixel in every image by 255.

# %%
from PIL import ImageFile                            
ImageFile.LOAD_TRUNCATED_IMAGES = True                 

# pre-process the data for Keras
train_tensors = paths_to_tensor(train_files).astype('float32')/255
valid_tensors = paths_to_tensor(valid_files).astype('float32')/255
test_tensors = paths_to_tensor(test_files).astype('float32')/255
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 6680/6680 [00:41<00:00, 161.05it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 835/835 [00:04<00:00, 175.64it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 836/836 [00:04<00:00, 176.91it/s]

# %% [markdown]
# ### (IMPLEMENTATION) Model Architecture
#
# Create a CNN to classify dog breed.  At the end of your code cell block, summarize the layers of your model by executing the line:
#
#         model.summary()
#
# We have imported some Python modules to get you started, but feel free to import as many modules as you need.  If you end up getting stuck, here's a hint that specifies a model that trains relatively fast on CPU and attains >1% test accuracy in 5 epochs:
#
# ![Sample CNN](images/sample_cnn.png)
#
# __Question 4:__ Outline the steps you took to get to your final CNN architecture and your reasoning at each step.  If you chose to use the hinted architecture above, describe why you think that CNN architecture should work well for the image classification task.
#
# __Answer:__

# %%
from keras.layers import Conv2D, BatchNormalization,  MaxPooling2D, GlobalAveragePooling2D
from keras.layers import Dropout, Flatten, Dense
from keras.models import Sequential

model = Sequential()

model.add(Conv2D(filters=16, kernel_size=2, padding='valid', activation='elu', input_shape=(224, 224, 3)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=2, padding='valid'))
model.add(Conv2D(filters=32, kernel_size=2, padding='valid', activation='elu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=2, padding='valid'))
model.add(Conv2D(filters=64, kernel_size=2, padding='valid', activation='elu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=2))
model.add(GlobalAveragePooling2D())
model.add(Dense(133, activation='softmax'))


model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 223, 223, 16)      208
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 223, 223, 16)      64
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 111, 111, 16)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 110, 110, 32)      2080
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 110, 110, 32)      128
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 55, 55, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 54, 54, 64)        8256
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 54, 54, 64)        256
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 27, 27, 64)        0
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 133)               8645
# =================================================================
# Total params: 19,637
# Trainable params: 19,413
# Non-trainable params: 224
# _________________________________________________________________

# %% [markdown]
# ### Compile the Model

# %%
model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ### (IMPLEMENTATION) Train the Model
#
# Train your model in the code cell below.  Use model checkpointing to save the model that attains the best validation loss.
#
# You are welcome to [augment the training data](https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html), but this is not a requirement.

# %%
from keras.callbacks import ModelCheckpoint  

### TODO: specify the number of epochs that you would like to use to train the model.

epochs = 10

### Do NOT modify the code below this line.

checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.from_scratch.hdf5', 
                               verbose=1, save_best_only=True)

model.fit(train_tensors, train_targets, 
          validation_data=(valid_tensors, valid_targets),
          epochs=epochs, batch_size=20, callbacks=[checkpointer], verbose=1)
# Out:
# Train on 6680 samples, validate on 835 samples
# Epoch 1/10
# 6660/6680 [============================>.] - ETA: 5:15 - loss: 5.1455 - acc: 0.0000e+0 - ETA: 1:54 - loss: 5.0560 - acc: 0.0000e+0 - ETA: 1:14 - loss: 5.0167 - acc: 0.0000e+0 - ETA: 56s - loss: 5.0191 - acc: 0.0071    - ETA: 47s - loss: 5.0187 - acc: 0.00 - ETA: 41s - loss: 5.0073 - acc: 0.00 - ETA: 36s - loss: 5.0056 - acc: 0.00 - ETA: 33s - loss: 5.0060 - acc: 0.00 - ETA: 31s - loss: 4.9915 - acc: 0.01 - ETA: 29s - loss: 4.9987 - acc: 0.01 - ETA: 27s - loss: 4.9831 - acc: 0.00 - ETA: 26s - loss: 4.9809 - acc: 0.00 - ETA: 24s - loss: 4.9831 - acc: 0.00 - ETA: 23s - loss: 4.9758 - acc: 0.00 - ETA: 23s - loss: 4.9723 - acc: 0.01 - ETA: 22s - loss: 4.9630 - acc: 0.00 - ETA: 21s - loss: 4.9559 - acc: 0.01 - ETA: 21s - loss: 4.9537 - acc: 0.01 - ETA: 20s - loss: 4.9483 - acc: 0.01 - ETA: 20s - loss: 4.9507 - acc: 0.01 - ETA: 19s - loss: 4.9468 - acc: 0.01 - ETA: 19s - loss: 4.9450 - acc: 0.01 - ETA: 18s - loss: 4.9464 - acc: 0.01 - ETA: 18s - loss: 4.9479 - acc: 0.00 - ETA: 17s - loss: 4.9517 - acc: 0.00 - ETA: 17s - loss: 4.9471 - acc: 0.00 - ETA: 17s - loss: 4.9462 - acc: 0.00 - ETA: 17s - loss: 4.9439 - acc: 0.00 - ETA: 16s - loss: 4.9449 - acc: 0.00 - ETA: 16s - loss: 4.9444 - acc: 0.00 - ETA: 16s - loss: 4.9424 - acc: 0.00 - ETA: 16s - loss: 4.9394 - acc: 0.01 - ETA: 15s - loss: 4.9377 - acc: 0.01 - ETA: 15s - loss: 4.9377 - acc: 0.01 - ETA: 15s - loss: 4.9352 - acc: 0.01 - ETA: 15s - loss: 4.9335 - acc: 0.01 - ETA: 14s - loss: 4.9300 - acc: 0.01 - ETA: 14s - loss: 4.9287 - acc: 0.01 - ETA: 14s - loss: 4.9268 - acc: 0.01 - ETA: 14s - loss: 4.9262 - acc: 0.01 - ETA: 14s - loss: 4.9259 - acc: 0.01 - ETA: 13s - loss: 4.9225 - acc: 0.01 - ETA: 13s - loss: 4.9227 - acc: 0.01 - ETA: 13s - loss: 4.9234 - acc: 0.01 - ETA: 13s - loss: 4.9207 - acc: 0.01 - ETA: 13s - loss: 4.9177 - acc: 0.01 - ETA: 13s - loss: 4.9174 - acc: 0.01 - ETA: 12s - loss: 4.9155 - acc: 0.01 - ETA: 12s - loss: 4.9166 - acc: 0.01 - ETA: 12s - loss: 4.9146 - acc: 0.01 - ETA: 12s - loss: 4.9112 - acc: 0.01 - ETA: 12s - loss: 4.9094 - acc: 0.01 - ETA: 12s - loss: 4.9097 - acc: 0.01 - ETA: 12s - loss: 4.9080 - acc: 0.01 - ETA: 11s - loss: 4.9065 - acc: 0.01 - ETA: 11s - loss: 4.9060 - acc: 0.01 - ETA: 11s - loss: 4.9051 - acc: 0.01 - ETA: 11s - loss: 4.9029 - acc: 0.01 - ETA: 11s - loss: 4.9033 - acc: 0.01 - ETA: 11s - loss: 4.9031 - acc: 0.01 - ETA: 11s - loss: 4.9008 - acc: 0.01 - ETA: 10s - loss: 4.9005 - acc: 0.01 - ETA: 10s - loss: 4.9004 - acc: 0.01 - ETA: 10s - loss: 4.8999 - acc: 0.01 - ETA: 10s - loss: 4.8996 - acc: 0.01 - ETA: 10s - loss: 4.8984 - acc: 0.01 - ETA: 10s - loss: 4.8981 - acc: 0.01 - ETA: 10s - loss: 4.8984 - acc: 0.01 - ETA: 10s - loss: 4.8975 - acc: 0.01 - ETA: 9s - loss: 4.8973 - acc: 0.0129 - ETA: 9s - loss: 4.8977 - acc: 0.012 - ETA: 9s - loss: 4.8959 - acc: 0.012 - ETA: 9s - loss: 4.8942 - acc: 0.012 - ETA: 9s - loss: 4.8928 - acc: 0.012 - ETA: 9s - loss: 4.8913 - acc: 0.012 - ETA: 9s - loss: 4.8908 - acc: 0.012 - ETA: 9s - loss: 4.8924 - acc: 0.012 - ETA: 9s - loss: 4.8925 - acc: 0.012 - ETA: 8s - loss: 4.8922 - acc: 0.012 - ETA: 8s - loss: 4.8924 - acc: 0.012 - ETA: 8s - loss: 4.8911 - acc: 0.012 - ETA: 8s - loss: 4.8909 - acc: 0.012 - ETA: 8s - loss: 4.8899 - acc: 0.012 - ETA: 8s - loss: 4.8899 - acc: 0.012 - ETA: 8s - loss: 4.8886 - acc: 0.012 - ETA: 8s - loss: 4.8866 - acc: 0.012 - ETA: 8s - loss: 4.8864 - acc: 0.012 - ETA: 7s - loss: 4.8844 - acc: 0.012 - ETA: 7s - loss: 4.8835 - acc: 0.012 - ETA: 7s - loss: 4.8832 - acc: 0.012 - ETA: 7s - loss: 4.8813 - acc: 0.012 - ETA: 7s - loss: 4.8804 - acc: 0.012 - ETA: 7s - loss: 4.8788 - acc: 0.013 - ETA: 7s - loss: 4.8798 - acc: 0.012 - ETA: 7s - loss: 4.8786 - acc: 0.013 - ETA: 7s - loss: 4.8782 - acc: 0.012 - ETA: 6s - loss: 4.8783 - acc: 0.013 - ETA: 6s - loss: 4.8776 - acc: 0.012 - ETA: 6s - loss: 4.8771 - acc: 0.012 - ETA: 6s - loss: 4.8774 - acc: 0.012 - ETA: 6s - loss: 4.8768 - acc: 0.012 - ETA: 6s - loss: 4.8761 - acc: 0.013 - ETA: 6s - loss: 4.8760 - acc: 0.013 - ETA: 6s - loss: 4 ...
# Epoch 00001: val_loss improved from inf to 4.79593, saving model to saved_models/weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 17s 3ms/step - loss: 4.8526 - acc: 0.0172 - val_loss: 4.7959 - val_acc: 0.0168
# Epoch 2/10
# 6640/6680 [============================>.] - ETA: 14s - loss: 4.7531 - acc: 0.10 - ETA: 14s - loss: 4.7550 - acc: 0.11 - ETA: 14s - loss: 4.7405 - acc: 0.09 - ETA: 14s - loss: 4.7188 - acc: 0.07 - ETA: 14s - loss: 4.7197 - acc: 0.05 - ETA: 14s - loss: 4.7080 - acc: 0.04 - ETA: 14s - loss: 4.7070 - acc: 0.04 - ETA: 14s - loss: 4.7271 - acc: 0.04 - ETA: 14s - loss: 4.7425 - acc: 0.03 - ETA: 14s - loss: 4.7323 - acc: 0.03 - ETA: 13s - loss: 4.7381 - acc: 0.03 - ETA: 13s - loss: 4.7261 - acc: 0.03 - ETA: 13s - loss: 4.7275 - acc: 0.03 - ETA: 13s - loss: 4.7344 - acc: 0.03 - ETA: 13s - loss: 4.7372 - acc: 0.03 - ETA: 13s - loss: 4.7392 - acc: 0.03 - ETA: 13s - loss: 4.7401 - acc: 0.02 - ETA: 13s - loss: 4.7435 - acc: 0.02 - ETA: 13s - loss: 4.7464 - acc: 0.02 - ETA: 13s - loss: 4.7518 - acc: 0.02 - ETA: 13s - loss: 4.7522 - acc: 0.03 - ETA: 12s - loss: 4.7504 - acc: 0.03 - ETA: 12s - loss: 4.7442 - acc: 0.03 - ETA: 12s - loss: 4.7410 - acc: 0.03 - ETA: 12s - loss: 4.7401 - acc: 0.03 - ETA: 12s - loss: 4.7439 - acc: 0.03 - ETA: 12s - loss: 4.7439 - acc: 0.03 - ETA: 12s - loss: 4.7417 - acc: 0.03 - ETA: 12s - loss: 4.7395 - acc: 0.03 - ETA: 12s - loss: 4.7381 - acc: 0.03 - ETA: 12s - loss: 4.7398 - acc: 0.03 - ETA: 12s - loss: 4.7395 - acc: 0.03 - ETA: 12s - loss: 4.7441 - acc: 0.03 - ETA: 11s - loss: 4.7482 - acc: 0.03 - ETA: 11s - loss: 4.7454 - acc: 0.03 - ETA: 11s - loss: 4.7474 - acc: 0.02 - ETA: 11s - loss: 4.7441 - acc: 0.02 - ETA: 11s - loss: 4.7425 - acc: 0.02 - ETA: 11s - loss: 4.7397 - acc: 0.02 - ETA: 11s - loss: 4.7386 - acc: 0.02 - ETA: 11s - loss: 4.7396 - acc: 0.02 - ETA: 11s - loss: 4.7436 - acc: 0.02 - ETA: 11s - loss: 4.7448 - acc: 0.02 - ETA: 11s - loss: 4.7441 - acc: 0.02 - ETA: 10s - loss: 4.7435 - acc: 0.02 - ETA: 10s - loss: 4.7442 - acc: 0.02 - ETA: 10s - loss: 4.7446 - acc: 0.02 - ETA: 10s - loss: 4.7440 - acc: 0.02 - ETA: 10s - loss: 4.7444 - acc: 0.02 - ETA: 10s - loss: 4.7449 - acc: 0.02 - ETA: 10s - loss: 4.7449 - acc: 0.02 - ETA: 10s - loss: 4.7422 - acc: 0.02 - ETA: 10s - loss: 4.7410 - acc: 0.02 - ETA: 10s - loss: 4.7392 - acc: 0.02 - ETA: 10s - loss: 4.7403 - acc: 0.02 - ETA: 9s - loss: 4.7408 - acc: 0.0279 - ETA: 9s - loss: 4.7412 - acc: 0.027 - ETA: 9s - loss: 4.7408 - acc: 0.027 - ETA: 9s - loss: 4.7419 - acc: 0.028 - ETA: 9s - loss: 4.7397 - acc: 0.028 - ETA: 9s - loss: 4.7398 - acc: 0.028 - ETA: 9s - loss: 4.7396 - acc: 0.028 - ETA: 9s - loss: 4.7380 - acc: 0.028 - ETA: 9s - loss: 4.7377 - acc: 0.029 - ETA: 9s - loss: 4.7369 - acc: 0.029 - ETA: 9s - loss: 4.7371 - acc: 0.029 - ETA: 8s - loss: 4.7398 - acc: 0.028 - ETA: 8s - loss: 4.7406 - acc: 0.029 - ETA: 8s - loss: 4.7414 - acc: 0.028 - ETA: 8s - loss: 4.7413 - acc: 0.028 - ETA: 8s - loss: 4.7406 - acc: 0.028 - ETA: 8s - loss: 4.7416 - acc: 0.028 - ETA: 8s - loss: 4.7424 - acc: 0.027 - ETA: 8s - loss: 4.7415 - acc: 0.027 - ETA: 8s - loss: 4.7412 - acc: 0.027 - ETA: 8s - loss: 4.7420 - acc: 0.026 - ETA: 8s - loss: 4.7417 - acc: 0.026 - ETA: 7s - loss: 4.7416 - acc: 0.026 - ETA: 7s - loss: 4.7405 - acc: 0.026 - ETA: 7s - loss: 4.7419 - acc: 0.026 - ETA: 7s - loss: 4.7417 - acc: 0.025 - ETA: 7s - loss: 4.7409 - acc: 0.025 - ETA: 7s - loss: 4.7420 - acc: 0.025 - ETA: 7s - loss: 4.7420 - acc: 0.024 - ETA: 7s - loss: 4.7420 - acc: 0.024 - ETA: 7s - loss: 4.7423 - acc: 0.025 - ETA: 7s - loss: 4.7428 - acc: 0.024 - ETA: 7s - loss: 4.7420 - acc: 0.024 - ETA: 6s - loss: 4.7435 - acc: 0.024 - ETA: 6s - loss: 4.7436 - acc: 0.025 - ETA: 6s - loss: 4.7426 - acc: 0.025 - ETA: 6s - loss: 4.7433 - acc: 0.026 - ETA: 6s - loss: 4.7430 - acc: 0.025 - ETA: 6s - loss: 4.7441 - acc: 0.025 - ETA: 6s - loss: 4.7441 - acc: 0.025 - ETA: 6s - loss: 4.7441 - acc: 0.025 - ETA: 6s - loss: 4.7438 - acc: 0.025 - ETA: 6s - loss: 4.7436 - acc: 0.025 - ETA: 6s - loss: 4.7438 - acc: 0.025 - ETA: 6s - loss: 4.7442 - acc: 0.025 - ETA: 5s - loss: 4.7436 - acc: 0.025 - ETA: 5s - loss: 4.7434 - acc: 0.025 - ETA: 5s - loss: 4.7420 - acc: 0.026 - ETA: 5s - loss: 4.7430 - acc: 0.026 - ET ...
# Epoch 00002: val_loss improved from 4.79593 to 4.74690, saving model to saved_models/weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 16s 2ms/step - loss: 4.7441 - acc: 0.0249 - val_loss: 4.7469 - val_acc: 0.0251
# Epoch 3/10
# 6640/6680 [============================>.] - ETA: 14s - loss: 4.5638 - acc: 0.05 - ETA: 14s - loss: 4.6477 - acc: 0.03 - ETA: 14s - loss: 4.6932 - acc: 0.03 - ETA: 14s - loss: 4.6752 - acc: 0.03 - ETA: 14s - loss: 4.6491 - acc: 0.04 - ETA: 14s - loss: 4.6515 - acc: 0.04 - ETA: 14s - loss: 4.6619 - acc: 0.04 - ETA: 14s - loss: 4.6455 - acc: 0.05 - ETA: 14s - loss: 4.6444 - acc: 0.04 - ETA: 14s - loss: 4.6417 - acc: 0.04 - ETA: 14s - loss: 4.6487 - acc: 0.04 - ETA: 14s - loss: 4.6573 - acc: 0.03 - ETA: 14s - loss: 4.6637 - acc: 0.04 - ETA: 13s - loss: 4.6705 - acc: 0.03 - ETA: 13s - loss: 4.6724 - acc: 0.03 - ETA: 13s - loss: 4.6724 - acc: 0.03 - ETA: 13s - loss: 4.6787 - acc: 0.03 - ETA: 13s - loss: 4.6673 - acc: 0.03 - ETA: 13s - loss: 4.6711 - acc: 0.03 - ETA: 13s - loss: 4.6730 - acc: 0.03 - ETA: 13s - loss: 4.6735 - acc: 0.03 - ETA: 13s - loss: 4.6764 - acc: 0.02 - ETA: 13s - loss: 4.6775 - acc: 0.03 - ETA: 13s - loss: 4.6764 - acc: 0.03 - ETA: 12s - loss: 4.6806 - acc: 0.03 - ETA: 12s - loss: 4.6849 - acc: 0.03 - ETA: 12s - loss: 4.6889 - acc: 0.03 - ETA: 12s - loss: 4.6863 - acc: 0.03 - ETA: 12s - loss: 4.6872 - acc: 0.03 - ETA: 12s - loss: 4.6880 - acc: 0.03 - ETA: 12s - loss: 4.6865 - acc: 0.03 - ETA: 12s - loss: 4.6851 - acc: 0.03 - ETA: 12s - loss: 4.6862 - acc: 0.03 - ETA: 12s - loss: 4.6844 - acc: 0.03 - ETA: 11s - loss: 4.6787 - acc: 0.03 - ETA: 11s - loss: 4.6780 - acc: 0.03 - ETA: 11s - loss: 4.6769 - acc: 0.03 - ETA: 11s - loss: 4.6779 - acc: 0.03 - ETA: 11s - loss: 4.6776 - acc: 0.03 - ETA: 11s - loss: 4.6789 - acc: 0.03 - ETA: 11s - loss: 4.6777 - acc: 0.03 - ETA: 11s - loss: 4.6817 - acc: 0.03 - ETA: 11s - loss: 4.6801 - acc: 0.03 - ETA: 11s - loss: 4.6807 - acc: 0.03 - ETA: 11s - loss: 4.6823 - acc: 0.03 - ETA: 10s - loss: 4.6826 - acc: 0.03 - ETA: 10s - loss: 4.6825 - acc: 0.03 - ETA: 10s - loss: 4.6814 - acc: 0.03 - ETA: 10s - loss: 4.6834 - acc: 0.03 - ETA: 10s - loss: 4.6832 - acc: 0.03 - ETA: 10s - loss: 4.6856 - acc: 0.03 - ETA: 10s - loss: 4.6827 - acc: 0.03 - ETA: 10s - loss: 4.6830 - acc: 0.03 - ETA: 10s - loss: 4.6829 - acc: 0.03 - ETA: 10s - loss: 4.6851 - acc: 0.03 - ETA: 10s - loss: 4.6829 - acc: 0.03 - ETA: 9s - loss: 4.6840 - acc: 0.0327 - ETA: 9s - loss: 4.6833 - acc: 0.032 - ETA: 9s - loss: 4.6833 - acc: 0.032 - ETA: 9s - loss: 4.6834 - acc: 0.032 - ETA: 9s - loss: 4.6820 - acc: 0.032 - ETA: 9s - loss: 4.6827 - acc: 0.031 - ETA: 9s - loss: 4.6835 - acc: 0.032 - ETA: 9s - loss: 4.6829 - acc: 0.032 - ETA: 9s - loss: 4.6837 - acc: 0.032 - ETA: 9s - loss: 4.6806 - acc: 0.032 - ETA: 9s - loss: 4.6809 - acc: 0.032 - ETA: 8s - loss: 4.6832 - acc: 0.031 - ETA: 8s - loss: 4.6826 - acc: 0.031 - ETA: 8s - loss: 4.6818 - acc: 0.031 - ETA: 8s - loss: 4.6835 - acc: 0.031 - ETA: 8s - loss: 4.6847 - acc: 0.031 - ETA: 8s - loss: 4.6861 - acc: 0.031 - ETA: 8s - loss: 4.6875 - acc: 0.031 - ETA: 8s - loss: 4.6856 - acc: 0.031 - ETA: 8s - loss: 4.6857 - acc: 0.031 - ETA: 8s - loss: 4.6856 - acc: 0.031 - ETA: 8s - loss: 4.6862 - acc: 0.031 - ETA: 7s - loss: 4.6857 - acc: 0.031 - ETA: 7s - loss: 4.6840 - acc: 0.032 - ETA: 7s - loss: 4.6834 - acc: 0.032 - ETA: 7s - loss: 4.6823 - acc: 0.032 - ETA: 7s - loss: 4.6827 - acc: 0.032 - ETA: 7s - loss: 4.6838 - acc: 0.031 - ETA: 7s - loss: 4.6852 - acc: 0.031 - ETA: 7s - loss: 4.6844 - acc: 0.031 - ETA: 7s - loss: 4.6843 - acc: 0.031 - ETA: 7s - loss: 4.6855 - acc: 0.031 - ETA: 7s - loss: 4.6847 - acc: 0.031 - ETA: 7s - loss: 4.6859 - acc: 0.031 - ETA: 6s - loss: 4.6859 - acc: 0.031 - ETA: 6s - loss: 4.6874 - acc: 0.031 - ETA: 6s - loss: 4.6878 - acc: 0.031 - ETA: 6s - loss: 4.6872 - acc: 0.031 - ETA: 6s - loss: 4.6863 - acc: 0.031 - ETA: 6s - loss: 4.6851 - acc: 0.030 - ETA: 6s - loss: 4.6873 - acc: 0.030 - ETA: 6s - loss: 4.6862 - acc: 0.030 - ETA: 6s - loss: 4.6855 - acc: 0.031 - ETA: 6s - loss: 4.6850 - acc: 0.031 - ETA: 6s - loss: 4.6857 - acc: 0.031 - ETA: 5s - loss: 4.6862 - acc: 0.031 - ETA: 5s - loss: 4.6861 - acc: 0.031 - ETA: 5s - loss: 4.6871 - acc: 0.031 - ET ...
# Epoch 00003: val_loss improved from 4.74690 to 4.72128, saving model to saved_models/weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 16s 2ms/step - loss: 4.6877 - acc: 0.0298 - val_loss: 4.7213 - val_acc: 0.0275
# Epoch 4/10
# 6660/6680 [============================>.] - ETA: 14s - loss: 4.6220 - acc: 0.10 - ETA: 14s - loss: 4.5988 - acc: 0.03 - ETA: 14s - loss: 4.6219 - acc: 0.04 - ETA: 14s - loss: 4.6191 - acc: 0.03 - ETA: 14s - loss: 4.6097 - acc: 0.02 - ETA: 14s - loss: 4.6115 - acc: 0.02 - ETA: 14s - loss: 4.6132 - acc: 0.02 - ETA: 13s - loss: 4.6267 - acc: 0.03 - ETA: 13s - loss: 4.6275 - acc: 0.03 - ETA: 13s - loss: 4.6249 - acc: 0.03 - ETA: 13s - loss: 4.6317 - acc: 0.03 - ETA: 13s - loss: 4.6284 - acc: 0.03 - ETA: 13s - loss: 4.6320 - acc: 0.03 - ETA: 13s - loss: 4.6384 - acc: 0.03 - ETA: 13s - loss: 4.6464 - acc: 0.03 - ETA: 13s - loss: 4.6540 - acc: 0.03 - ETA: 13s - loss: 4.6499 - acc: 0.03 - ETA: 13s - loss: 4.6482 - acc: 0.03 - ETA: 13s - loss: 4.6472 - acc: 0.03 - ETA: 13s - loss: 4.6436 - acc: 0.03 - ETA: 13s - loss: 4.6426 - acc: 0.04 - ETA: 12s - loss: 4.6379 - acc: 0.04 - ETA: 12s - loss: 4.6378 - acc: 0.04 - ETA: 12s - loss: 4.6385 - acc: 0.04 - ETA: 12s - loss: 4.6413 - acc: 0.04 - ETA: 12s - loss: 4.6371 - acc: 0.04 - ETA: 12s - loss: 4.6351 - acc: 0.04 - ETA: 12s - loss: 4.6383 - acc: 0.04 - ETA: 12s - loss: 4.6352 - acc: 0.04 - ETA: 12s - loss: 4.6357 - acc: 0.04 - ETA: 12s - loss: 4.6366 - acc: 0.04 - ETA: 12s - loss: 4.6363 - acc: 0.04 - ETA: 11s - loss: 4.6355 - acc: 0.04 - ETA: 11s - loss: 4.6348 - acc: 0.04 - ETA: 11s - loss: 4.6337 - acc: 0.04 - ETA: 11s - loss: 4.6325 - acc: 0.04 - ETA: 11s - loss: 4.6341 - acc: 0.04 - ETA: 11s - loss: 4.6334 - acc: 0.04 - ETA: 11s - loss: 4.6328 - acc: 0.04 - ETA: 11s - loss: 4.6324 - acc: 0.04 - ETA: 11s - loss: 4.6327 - acc: 0.04 - ETA: 11s - loss: 4.6323 - acc: 0.04 - ETA: 11s - loss: 4.6353 - acc: 0.04 - ETA: 10s - loss: 4.6353 - acc: 0.04 - ETA: 10s - loss: 4.6361 - acc: 0.04 - ETA: 10s - loss: 4.6367 - acc: 0.04 - ETA: 10s - loss: 4.6358 - acc: 0.03 - ETA: 10s - loss: 4.6361 - acc: 0.03 - ETA: 10s - loss: 4.6370 - acc: 0.03 - ETA: 10s - loss: 4.6361 - acc: 0.03 - ETA: 10s - loss: 4.6381 - acc: 0.03 - ETA: 10s - loss: 4.6374 - acc: 0.03 - ETA: 10s - loss: 4.6391 - acc: 0.03 - ETA: 10s - loss: 4.6376 - acc: 0.03 - ETA: 10s - loss: 4.6362 - acc: 0.03 - ETA: 9s - loss: 4.6405 - acc: 0.0374 - ETA: 9s - loss: 4.6420 - acc: 0.036 - ETA: 9s - loss: 4.6414 - acc: 0.037 - ETA: 9s - loss: 4.6441 - acc: 0.037 - ETA: 9s - loss: 4.6446 - acc: 0.037 - ETA: 9s - loss: 4.6453 - acc: 0.038 - ETA: 9s - loss: 4.6429 - acc: 0.038 - ETA: 9s - loss: 4.6444 - acc: 0.038 - ETA: 9s - loss: 4.6456 - acc: 0.037 - ETA: 9s - loss: 4.6468 - acc: 0.037 - ETA: 9s - loss: 4.6460 - acc: 0.036 - ETA: 8s - loss: 4.6464 - acc: 0.037 - ETA: 8s - loss: 4.6460 - acc: 0.038 - ETA: 8s - loss: 4.6451 - acc: 0.038 - ETA: 8s - loss: 4.6476 - acc: 0.037 - ETA: 8s - loss: 4.6491 - acc: 0.037 - ETA: 8s - loss: 4.6504 - acc: 0.037 - ETA: 8s - loss: 4.6499 - acc: 0.036 - ETA: 8s - loss: 4.6511 - acc: 0.037 - ETA: 8s - loss: 4.6504 - acc: 0.037 - ETA: 8s - loss: 4.6515 - acc: 0.036 - ETA: 8s - loss: 4.6515 - acc: 0.036 - ETA: 7s - loss: 4.6511 - acc: 0.036 - ETA: 7s - loss: 4.6489 - acc: 0.036 - ETA: 7s - loss: 4.6482 - acc: 0.037 - ETA: 7s - loss: 4.6491 - acc: 0.037 - ETA: 7s - loss: 4.6490 - acc: 0.036 - ETA: 7s - loss: 4.6492 - acc: 0.036 - ETA: 7s - loss: 4.6494 - acc: 0.036 - ETA: 7s - loss: 4.6504 - acc: 0.036 - ETA: 7s - loss: 4.6482 - acc: 0.037 - ETA: 7s - loss: 4.6476 - acc: 0.037 - ETA: 7s - loss: 4.6462 - acc: 0.036 - ETA: 6s - loss: 4.6471 - acc: 0.036 - ETA: 6s - loss: 4.6470 - acc: 0.036 - ETA: 6s - loss: 4.6467 - acc: 0.037 - ETA: 6s - loss: 4.6461 - acc: 0.037 - ETA: 6s - loss: 4.6464 - acc: 0.037 - ETA: 6s - loss: 4.6481 - acc: 0.037 - ETA: 6s - loss: 4.6477 - acc: 0.037 - ETA: 6s - loss: 4.6473 - acc: 0.038 - ETA: 6s - loss: 4.6479 - acc: 0.037 - ETA: 6s - loss: 4.6487 - acc: 0.037 - ETA: 6s - loss: 4.6489 - acc: 0.037 - ETA: 6s - loss: 4.6478 - acc: 0.037 - ETA: 5s - loss: 4.6482 - acc: 0.037 - ETA: 5s - loss: 4.6479 - acc: 0.037 - ETA: 5s - loss: 4.6470 - acc: 0.038 - ETA: 5s - loss: 4.6475 - acc: 0.039 - ET ...
# Epoch 00004: val_loss improved from 4.72128 to 4.69998, saving model to saved_models/weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 16s 2ms/step - loss: 4.6465 - acc: 0.0415 - val_loss: 4.7000 - val_acc: 0.0359
# Epoch 5/10
# 6660/6680 [============================>.] - ETA: 14s - loss: 4.6866 - acc: 0.0000e+ - ETA: 14s - loss: 4.6475 - acc: 0.0167   - ETA: 14s - loss: 4.5441 - acc: 0.05 - ETA: 14s - loss: 4.5502 - acc: 0.05 - ETA: 14s - loss: 4.5482 - acc: 0.06 - ETA: 14s - loss: 4.5529 - acc: 0.05 - ETA: 14s - loss: 4.5341 - acc: 0.05 - ETA: 14s - loss: 4.5337 - acc: 0.04 - ETA: 14s - loss: 4.5345 - acc: 0.04 - ETA: 14s - loss: 4.5414 - acc: 0.04 - ETA: 14s - loss: 4.5551 - acc: 0.04 - ETA: 14s - loss: 4.5693 - acc: 0.04 - ETA: 13s - loss: 4.5834 - acc: 0.04 - ETA: 13s - loss: 4.5927 - acc: 0.03 - ETA: 13s - loss: 4.5984 - acc: 0.03 - ETA: 13s - loss: 4.5926 - acc: 0.03 - ETA: 13s - loss: 4.5911 - acc: 0.03 - ETA: 13s - loss: 4.5931 - acc: 0.04 - ETA: 13s - loss: 4.5833 - acc: 0.04 - ETA: 13s - loss: 4.5862 - acc: 0.04 - ETA: 13s - loss: 4.5937 - acc: 0.04 - ETA: 13s - loss: 4.5922 - acc: 0.04 - ETA: 12s - loss: 4.6016 - acc: 0.04 - ETA: 12s - loss: 4.5934 - acc: 0.04 - ETA: 12s - loss: 4.5940 - acc: 0.03 - ETA: 12s - loss: 4.6042 - acc: 0.03 - ETA: 12s - loss: 4.6035 - acc: 0.03 - ETA: 12s - loss: 4.6010 - acc: 0.03 - ETA: 12s - loss: 4.6048 - acc: 0.03 - ETA: 12s - loss: 4.5976 - acc: 0.03 - ETA: 12s - loss: 4.5978 - acc: 0.04 - ETA: 12s - loss: 4.6027 - acc: 0.04 - ETA: 12s - loss: 4.6052 - acc: 0.04 - ETA: 12s - loss: 4.6043 - acc: 0.03 - ETA: 11s - loss: 4.6019 - acc: 0.04 - ETA: 11s - loss: 4.6022 - acc: 0.04 - ETA: 11s - loss: 4.6017 - acc: 0.04 - ETA: 11s - loss: 4.6017 - acc: 0.04 - ETA: 11s - loss: 4.6008 - acc: 0.04 - ETA: 11s - loss: 4.6004 - acc: 0.03 - ETA: 11s - loss: 4.5981 - acc: 0.04 - ETA: 11s - loss: 4.6021 - acc: 0.03 - ETA: 11s - loss: 4.5977 - acc: 0.03 - ETA: 11s - loss: 4.5982 - acc: 0.03 - ETA: 10s - loss: 4.6015 - acc: 0.03 - ETA: 10s - loss: 4.5974 - acc: 0.03 - ETA: 10s - loss: 4.5926 - acc: 0.03 - ETA: 10s - loss: 4.5917 - acc: 0.03 - ETA: 10s - loss: 4.5906 - acc: 0.03 - ETA: 10s - loss: 4.5912 - acc: 0.03 - ETA: 10s - loss: 4.5894 - acc: 0.04 - ETA: 10s - loss: 4.5898 - acc: 0.03 - ETA: 10s - loss: 4.5897 - acc: 0.03 - ETA: 10s - loss: 4.5926 - acc: 0.03 - ETA: 10s - loss: 4.5938 - acc: 0.03 - ETA: 9s - loss: 4.5962 - acc: 0.0378 - ETA: 9s - loss: 4.5949 - acc: 0.038 - ETA: 9s - loss: 4.5945 - acc: 0.038 - ETA: 9s - loss: 4.5960 - acc: 0.038 - ETA: 9s - loss: 4.5970 - acc: 0.038 - ETA: 9s - loss: 4.5955 - acc: 0.039 - ETA: 9s - loss: 4.6001 - acc: 0.039 - ETA: 9s - loss: 4.6023 - acc: 0.038 - ETA: 9s - loss: 4.6045 - acc: 0.039 - ETA: 9s - loss: 4.6035 - acc: 0.039 - ETA: 9s - loss: 4.6036 - acc: 0.039 - ETA: 8s - loss: 4.6045 - acc: 0.039 - ETA: 8s - loss: 4.6052 - acc: 0.039 - ETA: 8s - loss: 4.6048 - acc: 0.039 - ETA: 8s - loss: 4.6053 - acc: 0.039 - ETA: 8s - loss: 4.6046 - acc: 0.039 - ETA: 8s - loss: 4.6046 - acc: 0.038 - ETA: 8s - loss: 4.6055 - acc: 0.039 - ETA: 8s - loss: 4.6038 - acc: 0.038 - ETA: 8s - loss: 4.6046 - acc: 0.038 - ETA: 8s - loss: 4.6041 - acc: 0.037 - ETA: 8s - loss: 4.6060 - acc: 0.037 - ETA: 7s - loss: 4.6056 - acc: 0.037 - ETA: 7s - loss: 4.6069 - acc: 0.037 - ETA: 7s - loss: 4.6086 - acc: 0.037 - ETA: 7s - loss: 4.6101 - acc: 0.037 - ETA: 7s - loss: 4.6099 - acc: 0.036 - ETA: 7s - loss: 4.6087 - acc: 0.037 - ETA: 7s - loss: 4.6097 - acc: 0.037 - ETA: 7s - loss: 4.6118 - acc: 0.037 - ETA: 7s - loss: 4.6105 - acc: 0.037 - ETA: 7s - loss: 4.6120 - acc: 0.037 - ETA: 7s - loss: 4.6128 - acc: 0.037 - ETA: 7s - loss: 4.6142 - acc: 0.037 - ETA: 6s - loss: 4.6145 - acc: 0.036 - ETA: 6s - loss: 4.6143 - acc: 0.036 - ETA: 6s - loss: 4.6129 - acc: 0.037 - ETA: 6s - loss: 4.6131 - acc: 0.037 - ETA: 6s - loss: 4.6140 - acc: 0.037 - ETA: 6s - loss: 4.6139 - acc: 0.037 - ETA: 6s - loss: 4.6126 - acc: 0.037 - ETA: 6s - loss: 4.6118 - acc: 0.037 - ETA: 6s - loss: 4.6130 - acc: 0.036 - ETA: 6s - loss: 4.6128 - acc: 0.036 - ETA: 6s - loss: 4.6123 - acc: 0.036 - ETA: 5s - loss: 4.6120 - acc: 0.037 - ETA: 5s - loss: 4.6130 - acc: 0.037 - ETA: 5s - loss: 4.6137 - acc: 0.037 - ETA: 5s - loss: 4.6142 - acc: 0. ...
# Epoch 00005: val_loss did not improve
# 6680/6680 [==============================] - 16s 2ms/step - loss: 4.6165 - acc: 0.0400 - val_loss: 4.7061 - val_acc: 0.0263
# Epoch 6/10
# 6640/6680 [============================>.] - ETA: 14s - loss: 4.5186 - acc: 0.05 - ETA: 14s - loss: 4.5672 - acc: 0.01 - ETA: 14s - loss: 4.5279 - acc: 0.03 - ETA: 14s - loss: 4.5294 - acc: 0.02 - ETA: 14s - loss: 4.5364 - acc: 0.02 - ETA: 14s - loss: 4.5637 - acc: 0.03 - ETA: 14s - loss: 4.5459 - acc: 0.04 - ETA: 14s - loss: 4.5380 - acc: 0.04 - ETA: 14s - loss: 4.5519 - acc: 0.03 - ETA: 13s - loss: 4.5624 - acc: 0.03 - ETA: 13s - loss: 4.5552 - acc: 0.03 - ETA: 13s - loss: 4.5520 - acc: 0.03 - ETA: 13s - loss: 4.5577 - acc: 0.04 - ETA: 13s - loss: 4.5552 - acc: 0.03 - ETA: 13s - loss: 4.5564 - acc: 0.03 - ETA: 13s - loss: 4.5542 - acc: 0.03 - ETA: 13s - loss: 4.5490 - acc: 0.03 - ETA: 13s - loss: 4.5423 - acc: 0.04 - ETA: 13s - loss: 4.5512 - acc: 0.04 - ETA: 13s - loss: 4.5519 - acc: 0.04 - ETA: 12s - loss: 4.5581 - acc: 0.04 - ETA: 12s - loss: 4.5547 - acc: 0.04 - ETA: 12s - loss: 4.5552 - acc: 0.04 - ETA: 12s - loss: 4.5513 - acc: 0.04 - ETA: 12s - loss: 4.5580 - acc: 0.03 - ETA: 12s - loss: 4.5579 - acc: 0.04 - ETA: 12s - loss: 4.5579 - acc: 0.04 - ETA: 12s - loss: 4.5525 - acc: 0.04 - ETA: 12s - loss: 4.5472 - acc: 0.04 - ETA: 12s - loss: 4.5495 - acc: 0.04 - ETA: 12s - loss: 4.5561 - acc: 0.04 - ETA: 11s - loss: 4.5584 - acc: 0.04 - ETA: 11s - loss: 4.5570 - acc: 0.04 - ETA: 11s - loss: 4.5567 - acc: 0.04 - ETA: 11s - loss: 4.5572 - acc: 0.04 - ETA: 11s - loss: 4.5605 - acc: 0.04 - ETA: 11s - loss: 4.5669 - acc: 0.04 - ETA: 11s - loss: 4.5705 - acc: 0.04 - ETA: 11s - loss: 4.5692 - acc: 0.04 - ETA: 11s - loss: 4.5696 - acc: 0.04 - ETA: 11s - loss: 4.5678 - acc: 0.04 - ETA: 11s - loss: 4.5703 - acc: 0.04 - ETA: 11s - loss: 4.5702 - acc: 0.04 - ETA: 10s - loss: 4.5719 - acc: 0.04 - ETA: 10s - loss: 4.5769 - acc: 0.04 - ETA: 10s - loss: 4.5736 - acc: 0.04 - ETA: 10s - loss: 4.5744 - acc: 0.04 - ETA: 10s - loss: 4.5727 - acc: 0.04 - ETA: 10s - loss: 4.5680 - acc: 0.04 - ETA: 10s - loss: 4.5695 - acc: 0.04 - ETA: 10s - loss: 4.5744 - acc: 0.04 - ETA: 10s - loss: 4.5754 - acc: 0.04 - ETA: 10s - loss: 4.5766 - acc: 0.04 - ETA: 10s - loss: 4.5760 - acc: 0.04 - ETA: 10s - loss: 4.5773 - acc: 0.04 - ETA: 9s - loss: 4.5766 - acc: 0.0428 - ETA: 9s - loss: 4.5761 - acc: 0.042 - ETA: 9s - loss: 4.5772 - acc: 0.042 - ETA: 9s - loss: 4.5785 - acc: 0.041 - ETA: 9s - loss: 4.5766 - acc: 0.042 - ETA: 9s - loss: 4.5791 - acc: 0.042 - ETA: 9s - loss: 4.5775 - acc: 0.042 - ETA: 9s - loss: 4.5763 - acc: 0.042 - ETA: 9s - loss: 4.5767 - acc: 0.042 - ETA: 9s - loss: 4.5774 - acc: 0.041 - ETA: 9s - loss: 4.5774 - acc: 0.041 - ETA: 8s - loss: 4.5783 - acc: 0.041 - ETA: 8s - loss: 4.5784 - acc: 0.041 - ETA: 8s - loss: 4.5785 - acc: 0.042 - ETA: 8s - loss: 4.5784 - acc: 0.041 - ETA: 8s - loss: 4.5812 - acc: 0.040 - ETA: 8s - loss: 4.5811 - acc: 0.040 - ETA: 8s - loss: 4.5821 - acc: 0.040 - ETA: 8s - loss: 4.5839 - acc: 0.040 - ETA: 8s - loss: 4.5855 - acc: 0.040 - ETA: 8s - loss: 4.5842 - acc: 0.040 - ETA: 8s - loss: 4.5852 - acc: 0.040 - ETA: 7s - loss: 4.5885 - acc: 0.039 - ETA: 7s - loss: 4.5890 - acc: 0.039 - ETA: 7s - loss: 4.5883 - acc: 0.039 - ETA: 7s - loss: 4.5886 - acc: 0.039 - ETA: 7s - loss: 4.5871 - acc: 0.039 - ETA: 7s - loss: 4.5862 - acc: 0.040 - ETA: 7s - loss: 4.5855 - acc: 0.040 - ETA: 7s - loss: 4.5859 - acc: 0.039 - ETA: 7s - loss: 4.5858 - acc: 0.040 - ETA: 7s - loss: 4.5868 - acc: 0.039 - ETA: 7s - loss: 4.5865 - acc: 0.040 - ETA: 6s - loss: 4.5857 - acc: 0.040 - ETA: 6s - loss: 4.5845 - acc: 0.040 - ETA: 6s - loss: 4.5854 - acc: 0.040 - ETA: 6s - loss: 4.5861 - acc: 0.040 - ETA: 6s - loss: 4.5849 - acc: 0.040 - ETA: 6s - loss: 4.5829 - acc: 0.040 - ETA: 6s - loss: 4.5822 - acc: 0.041 - ETA: 6s - loss: 4.5828 - acc: 0.040 - ETA: 6s - loss: 4.5826 - acc: 0.040 - ETA: 6s - loss: 4.5822 - acc: 0.040 - ETA: 6s - loss: 4.5814 - acc: 0.040 - ETA: 5s - loss: 4.5816 - acc: 0.040 - ETA: 5s - loss: 4.5812 - acc: 0.039 - ETA: 5s - loss: 4.5830 - acc: 0.039 - ETA: 5s - loss: 4.5829 - acc: 0.039 - ETA: 5s - loss: 4.5834 - acc: 0.039 - ET ...
# Epoch 00006: val_loss did not improve
# 6680/6680 [==============================] - 16s 2ms/step - loss: 4.5922 - acc: 0.0421 - val_loss: 4.7028 - val_acc: 0.0240
# Epoch 7/10
# 6640/6680 [============================>.] - ETA: 14s - loss: 4.5951 - acc: 0.10 - ETA: 14s - loss: 4.6305 - acc: 0.05 - ETA: 14s - loss: 4.6163 - acc: 0.03 - ETA: 14s - loss: 4.6289 - acc: 0.02 - ETA: 14s - loss: 4.6297 - acc: 0.03 - ETA: 14s - loss: 4.6116 - acc: 0.03 - ETA: 14s - loss: 4.5889 - acc: 0.03 - ETA: 14s - loss: 4.5947 - acc: 0.04 - ETA: 14s - loss: 4.5856 - acc: 0.04 - ETA: 13s - loss: 4.5733 - acc: 0.04 - ETA: 13s - loss: 4.5740 - acc: 0.04 - ETA: 13s - loss: 4.5751 - acc: 0.04 - ETA: 13s - loss: 4.5806 - acc: 0.04 - ETA: 13s - loss: 4.5705 - acc: 0.05 - ETA: 13s - loss: 4.5787 - acc: 0.04 - ETA: 13s - loss: 4.5727 - acc: 0.04 - ETA: 13s - loss: 4.5676 - acc: 0.04 - ETA: 13s - loss: 4.5630 - acc: 0.04 - ETA: 13s - loss: 4.5647 - acc: 0.04 - ETA: 13s - loss: 4.5612 - acc: 0.04 - ETA: 12s - loss: 4.5544 - acc: 0.04 - ETA: 12s - loss: 4.5562 - acc: 0.04 - ETA: 12s - loss: 4.5512 - acc: 0.04 - ETA: 12s - loss: 4.5488 - acc: 0.04 - ETA: 12s - loss: 4.5515 - acc: 0.04 - ETA: 12s - loss: 4.5552 - acc: 0.04 - ETA: 12s - loss: 4.5588 - acc: 0.04 - ETA: 12s - loss: 4.5604 - acc: 0.04 - ETA: 12s - loss: 4.5609 - acc: 0.04 - ETA: 12s - loss: 4.5588 - acc: 0.03 - ETA: 12s - loss: 4.5603 - acc: 0.04 - ETA: 11s - loss: 4.5592 - acc: 0.04 - ETA: 11s - loss: 4.5639 - acc: 0.04 - ETA: 11s - loss: 4.5618 - acc: 0.04 - ETA: 11s - loss: 4.5597 - acc: 0.04 - ETA: 11s - loss: 4.5602 - acc: 0.04 - ETA: 11s - loss: 4.5627 - acc: 0.04 - ETA: 11s - loss: 4.5630 - acc: 0.04 - ETA: 11s - loss: 4.5597 - acc: 0.04 - ETA: 11s - loss: 4.5614 - acc: 0.04 - ETA: 11s - loss: 4.5597 - acc: 0.04 - ETA: 11s - loss: 4.5565 - acc: 0.04 - ETA: 10s - loss: 4.5563 - acc: 0.04 - ETA: 10s - loss: 4.5557 - acc: 0.04 - ETA: 10s - loss: 4.5551 - acc: 0.04 - ETA: 10s - loss: 4.5533 - acc: 0.04 - ETA: 10s - loss: 4.5540 - acc: 0.04 - ETA: 10s - loss: 4.5569 - acc: 0.04 - ETA: 10s - loss: 4.5612 - acc: 0.04 - ETA: 10s - loss: 4.5616 - acc: 0.04 - ETA: 10s - loss: 4.5605 - acc: 0.04 - ETA: 10s - loss: 4.5577 - acc: 0.04 - ETA: 10s - loss: 4.5596 - acc: 0.04 - ETA: 10s - loss: 4.5588 - acc: 0.04 - ETA: 9s - loss: 4.5611 - acc: 0.0412 - ETA: 9s - loss: 4.5623 - acc: 0.041 - ETA: 9s - loss: 4.5640 - acc: 0.041 - ETA: 9s - loss: 4.5610 - acc: 0.042 - ETA: 9s - loss: 4.5597 - acc: 0.043 - ETA: 9s - loss: 4.5601 - acc: 0.042 - ETA: 9s - loss: 4.5591 - acc: 0.043 - ETA: 9s - loss: 4.5596 - acc: 0.043 - ETA: 9s - loss: 4.5598 - acc: 0.042 - ETA: 9s - loss: 4.5607 - acc: 0.042 - ETA: 9s - loss: 4.5585 - acc: 0.043 - ETA: 9s - loss: 4.5585 - acc: 0.042 - ETA: 8s - loss: 4.5579 - acc: 0.042 - ETA: 8s - loss: 4.5571 - acc: 0.042 - ETA: 8s - loss: 4.5593 - acc: 0.043 - ETA: 8s - loss: 4.5589 - acc: 0.043 - ETA: 8s - loss: 4.5568 - acc: 0.044 - ETA: 8s - loss: 4.5577 - acc: 0.044 - ETA: 8s - loss: 4.5565 - acc: 0.045 - ETA: 8s - loss: 4.5574 - acc: 0.046 - ETA: 8s - loss: 4.5558 - acc: 0.046 - ETA: 8s - loss: 4.5559 - acc: 0.047 - ETA: 8s - loss: 4.5543 - acc: 0.048 - ETA: 8s - loss: 4.5530 - acc: 0.047 - ETA: 7s - loss: 4.5552 - acc: 0.047 - ETA: 7s - loss: 4.5551 - acc: 0.047 - ETA: 7s - loss: 4.5560 - acc: 0.046 - ETA: 7s - loss: 4.5549 - acc: 0.046 - ETA: 7s - loss: 4.5547 - acc: 0.046 - ETA: 7s - loss: 4.5538 - acc: 0.046 - ETA: 7s - loss: 4.5543 - acc: 0.046 - ETA: 7s - loss: 4.5542 - acc: 0.045 - ETA: 7s - loss: 4.5555 - acc: 0.045 - ETA: 7s - loss: 4.5549 - acc: 0.045 - ETA: 7s - loss: 4.5540 - acc: 0.045 - ETA: 6s - loss: 4.5518 - acc: 0.045 - ETA: 6s - loss: 4.5506 - acc: 0.045 - ETA: 6s - loss: 4.5497 - acc: 0.045 - ETA: 6s - loss: 4.5494 - acc: 0.045 - ETA: 6s - loss: 4.5489 - acc: 0.045 - ETA: 6s - loss: 4.5503 - acc: 0.045 - ETA: 6s - loss: 4.5519 - acc: 0.045 - ETA: 6s - loss: 4.5532 - acc: 0.044 - ETA: 6s - loss: 4.5537 - acc: 0.044 - ETA: 6s - loss: 4.5525 - acc: 0.043 - ETA: 6s - loss: 4.5532 - acc: 0.043 - ETA: 6s - loss: 4.5540 - acc: 0.043 - ETA: 5s - loss: 4.5537 - acc: 0.043 - ETA: 5s - loss: 4.5542 - acc: 0.043 - ETA: 5s - loss: 4.5550 - acc: 0.043 - ET ...
# Epoch 00007: val_loss improved from 4.69998 to 4.64983, saving model to saved_models/weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 16s 2ms/step - loss: 4.5640 - acc: 0.0458 - val_loss: 4.6498 - val_acc: 0.0347
# Epoch 8/10
# 6660/6680 [============================>.] - ETA: 14s - loss: 4.4954 - acc: 0.0000e+ - ETA: 14s - loss: 4.5567 - acc: 0.0167   - ETA: 14s - loss: 4.5452 - acc: 0.04 - ETA: 14s - loss: 4.6052 - acc: 0.02 - ETA: 14s - loss: 4.5701 - acc: 0.03 - ETA: 14s - loss: 4.5337 - acc: 0.03 - ETA: 14s - loss: 4.5329 - acc: 0.04 - ETA: 14s - loss: 4.5339 - acc: 0.04 - ETA: 14s - loss: 4.5202 - acc: 0.03 - ETA: 14s - loss: 4.5195 - acc: 0.03 - ETA: 14s - loss: 4.5272 - acc: 0.03 - ETA: 13s - loss: 4.5259 - acc: 0.03 - ETA: 13s - loss: 4.5283 - acc: 0.03 - ETA: 13s - loss: 4.5305 - acc: 0.03 - ETA: 13s - loss: 4.5320 - acc: 0.03 - ETA: 13s - loss: 4.5420 - acc: 0.03 - ETA: 13s - loss: 4.5413 - acc: 0.03 - ETA: 13s - loss: 4.5321 - acc: 0.03 - ETA: 13s - loss: 4.5409 - acc: 0.03 - ETA: 13s - loss: 4.5392 - acc: 0.03 - ETA: 13s - loss: 4.5386 - acc: 0.03 - ETA: 13s - loss: 4.5331 - acc: 0.03 - ETA: 12s - loss: 4.5320 - acc: 0.04 - ETA: 12s - loss: 4.5342 - acc: 0.04 - ETA: 12s - loss: 4.5292 - acc: 0.04 - ETA: 12s - loss: 4.5238 - acc: 0.04 - ETA: 12s - loss: 4.5289 - acc: 0.03 - ETA: 12s - loss: 4.5258 - acc: 0.04 - ETA: 12s - loss: 4.5298 - acc: 0.04 - ETA: 12s - loss: 4.5320 - acc: 0.04 - ETA: 12s - loss: 4.5312 - acc: 0.04 - ETA: 12s - loss: 4.5305 - acc: 0.04 - ETA: 12s - loss: 4.5245 - acc: 0.04 - ETA: 11s - loss: 4.5228 - acc: 0.04 - ETA: 11s - loss: 4.5218 - acc: 0.04 - ETA: 11s - loss: 4.5234 - acc: 0.04 - ETA: 11s - loss: 4.5223 - acc: 0.04 - ETA: 11s - loss: 4.5249 - acc: 0.04 - ETA: 11s - loss: 4.5246 - acc: 0.04 - ETA: 11s - loss: 4.5258 - acc: 0.04 - ETA: 11s - loss: 4.5301 - acc: 0.04 - ETA: 11s - loss: 4.5304 - acc: 0.04 - ETA: 11s - loss: 4.5287 - acc: 0.04 - ETA: 11s - loss: 4.5276 - acc: 0.04 - ETA: 10s - loss: 4.5264 - acc: 0.04 - ETA: 10s - loss: 4.5257 - acc: 0.04 - ETA: 10s - loss: 4.5280 - acc: 0.04 - ETA: 10s - loss: 4.5235 - acc: 0.04 - ETA: 10s - loss: 4.5288 - acc: 0.04 - ETA: 10s - loss: 4.5264 - acc: 0.04 - ETA: 10s - loss: 4.5272 - acc: 0.04 - ETA: 10s - loss: 4.5271 - acc: 0.04 - ETA: 10s - loss: 4.5295 - acc: 0.04 - ETA: 10s - loss: 4.5292 - acc: 0.04 - ETA: 10s - loss: 4.5280 - acc: 0.04 - ETA: 9s - loss: 4.5266 - acc: 0.0482 - ETA: 9s - loss: 4.5275 - acc: 0.047 - ETA: 9s - loss: 4.5254 - acc: 0.048 - ETA: 9s - loss: 4.5266 - acc: 0.047 - ETA: 9s - loss: 4.5300 - acc: 0.047 - ETA: 9s - loss: 4.5278 - acc: 0.048 - ETA: 9s - loss: 4.5244 - acc: 0.049 - ETA: 9s - loss: 4.5265 - acc: 0.048 - ETA: 9s - loss: 4.5308 - acc: 0.048 - ETA: 9s - loss: 4.5315 - acc: 0.047 - ETA: 9s - loss: 4.5316 - acc: 0.047 - ETA: 8s - loss: 4.5303 - acc: 0.048 - ETA: 8s - loss: 4.5281 - acc: 0.048 - ETA: 8s - loss: 4.5289 - acc: 0.048 - ETA: 8s - loss: 4.5255 - acc: 0.049 - ETA: 8s - loss: 4.5242 - acc: 0.049 - ETA: 8s - loss: 4.5240 - acc: 0.049 - ETA: 8s - loss: 4.5242 - acc: 0.050 - ETA: 8s - loss: 4.5225 - acc: 0.050 - ETA: 8s - loss: 4.5233 - acc: 0.049 - ETA: 8s - loss: 4.5230 - acc: 0.050 - ETA: 8s - loss: 4.5218 - acc: 0.050 - ETA: 7s - loss: 4.5216 - acc: 0.050 - ETA: 7s - loss: 4.5224 - acc: 0.050 - ETA: 7s - loss: 4.5226 - acc: 0.050 - ETA: 7s - loss: 4.5236 - acc: 0.050 - ETA: 7s - loss: 4.5230 - acc: 0.049 - ETA: 7s - loss: 4.5245 - acc: 0.049 - ETA: 7s - loss: 4.5243 - acc: 0.049 - ETA: 7s - loss: 4.5226 - acc: 0.050 - ETA: 7s - loss: 4.5221 - acc: 0.050 - ETA: 7s - loss: 4.5199 - acc: 0.051 - ETA: 7s - loss: 4.5189 - acc: 0.052 - ETA: 7s - loss: 4.5184 - acc: 0.051 - ETA: 6s - loss: 4.5196 - acc: 0.051 - ETA: 6s - loss: 4.5178 - acc: 0.051 - ETA: 6s - loss: 4.5183 - acc: 0.050 - ETA: 6s - loss: 4.5181 - acc: 0.051 - ETA: 6s - loss: 4.5190 - acc: 0.051 - ETA: 6s - loss: 4.5207 - acc: 0.051 - ETA: 6s - loss: 4.5196 - acc: 0.052 - ETA: 6s - loss: 4.5216 - acc: 0.052 - ETA: 6s - loss: 4.5206 - acc: 0.052 - ETA: 6s - loss: 4.5206 - acc: 0.052 - ETA: 6s - loss: 4.5205 - acc: 0.052 - ETA: 5s - loss: 4.5223 - acc: 0.052 - ETA: 5s - loss: 4.5235 - acc: 0.052 - ETA: 5s - loss: 4.5234 - acc: 0.051 - ETA: 5s - loss: 4.5211 - acc: 0. ...
# Epoch 00008: val_loss improved from 4.64983 to 4.58732, saving model to saved_models/weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 16s 2ms/step - loss: 4.5302 - acc: 0.0487 - val_loss: 4.5873 - val_acc: 0.0443
# Epoch 9/10
# 6660/6680 [============================>.] - ETA: 15s - loss: 4.3413 - acc: 0.0000e+ - ETA: 15s - loss: 4.3867 - acc: 0.0833   - ETA: 14s - loss: 4.3909 - acc: 0.07 - ETA: 14s - loss: 4.4179 - acc: 0.07 - ETA: 14s - loss: 4.4289 - acc: 0.06 - ETA: 14s - loss: 4.3830 - acc: 0.07 - ETA: 14s - loss: 4.3738 - acc: 0.07 - ETA: 14s - loss: 4.4174 - acc: 0.07 - ETA: 14s - loss: 4.4358 - acc: 0.07 - ETA: 14s - loss: 4.4492 - acc: 0.06 - ETA: 13s - loss: 4.4611 - acc: 0.06 - ETA: 13s - loss: 4.4936 - acc: 0.06 - ETA: 13s - loss: 4.4966 - acc: 0.06 - ETA: 13s - loss: 4.5059 - acc: 0.05 - ETA: 13s - loss: 4.4948 - acc: 0.06 - ETA: 13s - loss: 4.4958 - acc: 0.06 - ETA: 13s - loss: 4.4906 - acc: 0.05 - ETA: 13s - loss: 4.4887 - acc: 0.06 - ETA: 13s - loss: 4.4958 - acc: 0.05 - ETA: 13s - loss: 4.4916 - acc: 0.05 - ETA: 13s - loss: 4.4863 - acc: 0.05 - ETA: 12s - loss: 4.4929 - acc: 0.05 - ETA: 12s - loss: 4.4910 - acc: 0.05 - ETA: 12s - loss: 4.4861 - acc: 0.05 - ETA: 12s - loss: 4.4801 - acc: 0.05 - ETA: 12s - loss: 4.4796 - acc: 0.05 - ETA: 12s - loss: 4.4801 - acc: 0.05 - ETA: 12s - loss: 4.4823 - acc: 0.05 - ETA: 12s - loss: 4.4776 - acc: 0.06 - ETA: 12s - loss: 4.4771 - acc: 0.06 - ETA: 12s - loss: 4.4753 - acc: 0.05 - ETA: 12s - loss: 4.4730 - acc: 0.05 - ETA: 12s - loss: 4.4744 - acc: 0.05 - ETA: 11s - loss: 4.4795 - acc: 0.05 - ETA: 11s - loss: 4.4772 - acc: 0.05 - ETA: 11s - loss: 4.4797 - acc: 0.05 - ETA: 11s - loss: 4.4770 - acc: 0.05 - ETA: 11s - loss: 4.4797 - acc: 0.05 - ETA: 11s - loss: 4.4779 - acc: 0.05 - ETA: 11s - loss: 4.4791 - acc: 0.05 - ETA: 11s - loss: 4.4771 - acc: 0.05 - ETA: 11s - loss: 4.4838 - acc: 0.05 - ETA: 11s - loss: 4.4831 - acc: 0.05 - ETA: 11s - loss: 4.4814 - acc: 0.05 - ETA: 10s - loss: 4.4824 - acc: 0.05 - ETA: 10s - loss: 4.4861 - acc: 0.05 - ETA: 10s - loss: 4.4852 - acc: 0.05 - ETA: 10s - loss: 4.4861 - acc: 0.05 - ETA: 10s - loss: 4.4870 - acc: 0.05 - ETA: 10s - loss: 4.4873 - acc: 0.05 - ETA: 10s - loss: 4.4844 - acc: 0.05 - ETA: 10s - loss: 4.4849 - acc: 0.05 - ETA: 10s - loss: 4.4859 - acc: 0.05 - ETA: 10s - loss: 4.4872 - acc: 0.05 - ETA: 10s - loss: 4.4867 - acc: 0.05 - ETA: 10s - loss: 4.4905 - acc: 0.05 - ETA: 9s - loss: 4.4915 - acc: 0.0554 - ETA: 9s - loss: 4.4939 - acc: 0.054 - ETA: 9s - loss: 4.4948 - acc: 0.055 - ETA: 9s - loss: 4.4930 - acc: 0.055 - ETA: 9s - loss: 4.4927 - acc: 0.055 - ETA: 9s - loss: 4.4952 - acc: 0.054 - ETA: 9s - loss: 4.4958 - acc: 0.054 - ETA: 9s - loss: 4.4949 - acc: 0.054 - ETA: 9s - loss: 4.4983 - acc: 0.054 - ETA: 9s - loss: 4.5006 - acc: 0.054 - ETA: 9s - loss: 4.5009 - acc: 0.054 - ETA: 8s - loss: 4.5003 - acc: 0.054 - ETA: 8s - loss: 4.4982 - acc: 0.055 - ETA: 8s - loss: 4.4978 - acc: 0.055 - ETA: 8s - loss: 4.4990 - acc: 0.054 - ETA: 8s - loss: 4.4962 - acc: 0.054 - ETA: 8s - loss: 4.4959 - acc: 0.053 - ETA: 8s - loss: 4.4965 - acc: 0.053 - ETA: 8s - loss: 4.4959 - acc: 0.053 - ETA: 8s - loss: 4.4967 - acc: 0.053 - ETA: 8s - loss: 4.4992 - acc: 0.052 - ETA: 8s - loss: 4.4978 - acc: 0.052 - ETA: 7s - loss: 4.4986 - acc: 0.052 - ETA: 7s - loss: 4.4998 - acc: 0.052 - ETA: 7s - loss: 4.4960 - acc: 0.053 - ETA: 7s - loss: 4.4961 - acc: 0.053 - ETA: 7s - loss: 4.4963 - acc: 0.053 - ETA: 7s - loss: 4.4952 - acc: 0.053 - ETA: 7s - loss: 4.4959 - acc: 0.053 - ETA: 7s - loss: 4.4974 - acc: 0.052 - ETA: 7s - loss: 4.4980 - acc: 0.053 - ETA: 7s - loss: 4.4985 - acc: 0.052 - ETA: 7s - loss: 4.4984 - acc: 0.052 - ETA: 6s - loss: 4.4989 - acc: 0.052 - ETA: 6s - loss: 4.4974 - acc: 0.053 - ETA: 6s - loss: 4.4961 - acc: 0.054 - ETA: 6s - loss: 4.4969 - acc: 0.053 - ETA: 6s - loss: 4.4976 - acc: 0.053 - ETA: 6s - loss: 4.4984 - acc: 0.052 - ETA: 6s - loss: 4.4969 - acc: 0.052 - ETA: 6s - loss: 4.4979 - acc: 0.052 - ETA: 6s - loss: 4.4976 - acc: 0.052 - ETA: 6s - loss: 4.4976 - acc: 0.051 - ETA: 6s - loss: 4.4971 - acc: 0.051 - ETA: 6s - loss: 4.4969 - acc: 0.051 - ETA: 5s - loss: 4.4982 - acc: 0.051 - ETA: 5s - loss: 4.5012 - acc: 0.051 - ETA: 5s - loss: 4.4999 - acc: 0. ...
# Epoch 00009: val_loss did not improve
# 6680/6680 [==============================] - 16s 2ms/step - loss: 4.5029 - acc: 0.0522 - val_loss: 4.8280 - val_acc: 0.0323
# Epoch 10/10
# 6640/6680 [============================>.] - ETA: 15s - loss: 4.6450 - acc: 0.05 - ETA: 15s - loss: 4.5199 - acc: 0.08 - ETA: 15s - loss: 4.5177 - acc: 0.05 - ETA: 14s - loss: 4.4864 - acc: 0.06 - ETA: 14s - loss: 4.5034 - acc: 0.05 - ETA: 14s - loss: 4.5031 - acc: 0.05 - ETA: 14s - loss: 4.4842 - acc: 0.04 - ETA: 14s - loss: 4.5074 - acc: 0.04 - ETA: 14s - loss: 4.4774 - acc: 0.05 - ETA: 14s - loss: 4.4545 - acc: 0.06 - ETA: 14s - loss: 4.4508 - acc: 0.06 - ETA: 14s - loss: 4.4602 - acc: 0.06 - ETA: 14s - loss: 4.4501 - acc: 0.06 - ETA: 14s - loss: 4.4330 - acc: 0.06 - ETA: 13s - loss: 4.4254 - acc: 0.06 - ETA: 13s - loss: 4.4097 - acc: 0.06 - ETA: 13s - loss: 4.4174 - acc: 0.06 - ETA: 13s - loss: 4.4202 - acc: 0.06 - ETA: 13s - loss: 4.4251 - acc: 0.06 - ETA: 13s - loss: 4.4207 - acc: 0.06 - ETA: 13s - loss: 4.4268 - acc: 0.06 - ETA: 13s - loss: 4.4301 - acc: 0.06 - ETA: 13s - loss: 4.4293 - acc: 0.06 - ETA: 12s - loss: 4.4315 - acc: 0.05 - ETA: 12s - loss: 4.4223 - acc: 0.06 - ETA: 12s - loss: 4.4299 - acc: 0.06 - ETA: 12s - loss: 4.4282 - acc: 0.06 - ETA: 12s - loss: 4.4243 - acc: 0.06 - ETA: 12s - loss: 4.4216 - acc: 0.06 - ETA: 12s - loss: 4.4180 - acc: 0.06 - ETA: 12s - loss: 4.4240 - acc: 0.06 - ETA: 12s - loss: 4.4230 - acc: 0.06 - ETA: 12s - loss: 4.4301 - acc: 0.06 - ETA: 12s - loss: 4.4283 - acc: 0.06 - ETA: 11s - loss: 4.4270 - acc: 0.06 - ETA: 11s - loss: 4.4307 - acc: 0.05 - ETA: 11s - loss: 4.4299 - acc: 0.05 - ETA: 11s - loss: 4.4299 - acc: 0.05 - ETA: 11s - loss: 4.4286 - acc: 0.05 - ETA: 11s - loss: 4.4308 - acc: 0.05 - ETA: 11s - loss: 4.4278 - acc: 0.05 - ETA: 11s - loss: 4.4287 - acc: 0.05 - ETA: 11s - loss: 4.4292 - acc: 0.05 - ETA: 11s - loss: 4.4266 - acc: 0.05 - ETA: 11s - loss: 4.4273 - acc: 0.05 - ETA: 10s - loss: 4.4321 - acc: 0.05 - ETA: 10s - loss: 4.4357 - acc: 0.05 - ETA: 10s - loss: 4.4341 - acc: 0.05 - ETA: 10s - loss: 4.4345 - acc: 0.05 - ETA: 10s - loss: 4.4356 - acc: 0.05 - ETA: 10s - loss: 4.4347 - acc: 0.05 - ETA: 10s - loss: 4.4360 - acc: 0.05 - ETA: 10s - loss: 4.4347 - acc: 0.05 - ETA: 10s - loss: 4.4353 - acc: 0.05 - ETA: 10s - loss: 4.4343 - acc: 0.05 - ETA: 9s - loss: 4.4340 - acc: 0.0559 - ETA: 9s - loss: 4.4360 - acc: 0.054 - ETA: 9s - loss: 4.4378 - acc: 0.054 - ETA: 9s - loss: 4.4413 - acc: 0.053 - ETA: 9s - loss: 4.4429 - acc: 0.053 - ETA: 9s - loss: 4.4413 - acc: 0.053 - ETA: 9s - loss: 4.4413 - acc: 0.053 - ETA: 9s - loss: 4.4389 - acc: 0.054 - ETA: 9s - loss: 4.4378 - acc: 0.055 - ETA: 9s - loss: 4.4440 - acc: 0.055 - ETA: 9s - loss: 4.4459 - acc: 0.055 - ETA: 9s - loss: 4.4488 - acc: 0.054 - ETA: 8s - loss: 4.4475 - acc: 0.054 - ETA: 8s - loss: 4.4462 - acc: 0.054 - ETA: 8s - loss: 4.4486 - acc: 0.055 - ETA: 8s - loss: 4.4478 - acc: 0.055 - ETA: 8s - loss: 4.4488 - acc: 0.054 - ETA: 8s - loss: 4.4475 - acc: 0.055 - ETA: 8s - loss: 4.4474 - acc: 0.055 - ETA: 8s - loss: 4.4478 - acc: 0.055 - ETA: 8s - loss: 4.4479 - acc: 0.055 - ETA: 8s - loss: 4.4486 - acc: 0.055 - ETA: 8s - loss: 4.4490 - acc: 0.055 - ETA: 7s - loss: 4.4484 - acc: 0.055 - ETA: 7s - loss: 4.4482 - acc: 0.055 - ETA: 7s - loss: 4.4475 - acc: 0.055 - ETA: 7s - loss: 4.4466 - acc: 0.054 - ETA: 7s - loss: 4.4484 - acc: 0.054 - ETA: 7s - loss: 4.4499 - acc: 0.053 - ETA: 7s - loss: 4.4499 - acc: 0.053 - ETA: 7s - loss: 4.4498 - acc: 0.054 - ETA: 7s - loss: 4.4509 - acc: 0.054 - ETA: 7s - loss: 4.4534 - acc: 0.053 - ETA: 7s - loss: 4.4533 - acc: 0.053 - ETA: 7s - loss: 4.4539 - acc: 0.053 - ETA: 6s - loss: 4.4561 - acc: 0.053 - ETA: 6s - loss: 4.4552 - acc: 0.052 - ETA: 6s - loss: 4.4557 - acc: 0.052 - ETA: 6s - loss: 4.4573 - acc: 0.052 - ETA: 6s - loss: 4.4579 - acc: 0.052 - ETA: 6s - loss: 4.4567 - acc: 0.052 - ETA: 6s - loss: 4.4572 - acc: 0.052 - ETA: 6s - loss: 4.4573 - acc: 0.051 - ETA: 6s - loss: 4.4587 - acc: 0.051 - ETA: 6s - loss: 4.4577 - acc: 0.052 - ETA: 6s - loss: 4.4581 - acc: 0.052 - ETA: 5s - loss: 4.4590 - acc: 0.053 - ETA: 5s - loss: 4.4584 - acc: 0.052 - ETA: 5s - loss: 4.4582 - acc: 0.052 - ET ...
# Epoch 00010: val_loss improved from 4.58732 to 4.55550, saving model to saved_models/weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 16s 2ms/step - loss: 4.4658 - acc: 0.0536 - val_loss: 4.5555 - val_acc: 0.0443

# %% [markdown]
# ### Load the Model with the Best Validation Loss

# %%
model.load_weights('saved_models/weights.best.from_scratch.hdf5')

# %% [markdown]
# ### Test the Model
#
# Try out your model on the test dataset of dog images.  Ensure that your test accuracy is greater than 1%.

# %%
# get index of predicted dog breed for each image in test set
dog_breed_predictions = [np.argmax(model.predict(np.expand_dims(tensor, axis=0))) for tensor in test_tensors]

# report test accuracy
test_accuracy = 100*np.sum(np.array(dog_breed_predictions)==np.argmax(test_targets, axis=1))/len(dog_breed_predictions)
print('Test accuracy: %.4f%%' % test_accuracy)
# Out:
# Test accuracy: 3.5885%

# %% [markdown]
# ---
# <a id='step4'></a>
# ## Step 4: Use a CNN to Classify Dog Breeds
#
# To reduce training time without sacrificing accuracy, we show you how to train a CNN using transfer learning.  In the following step, you will get a chance to use transfer learning to train your own CNN.
#
# ### Obtain Bottleneck Features

# %%
bottleneck_features = np.load('bottleneck_features/DogVGG16Data.npz')
train_VGG16 = bottleneck_features['train']
valid_VGG16 = bottleneck_features['valid']
test_VGG16 = bottleneck_features['test']

# %% [markdown]
# ### Model Architecture
#
# The model uses the the pre-trained VGG-16 model as a fixed feature extractor, where the last convolutional output of VGG-16 is fed as input to our model.  We only add a global average pooling layer and a fully connected layer, where the latter contains one node for each dog category and is equipped with a softmax.

# %%
VGG16_model = Sequential()
VGG16_model.add(GlobalAveragePooling2D(input_shape=train_VGG16.shape[1:]))
VGG16_model.add(Dense(133, activation='softmax'))

VGG16_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# global_average_pooling2d_2 ( (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 133)               68229
# =================================================================
# Total params: 68,229
# Trainable params: 68,229
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Compile the Model

# %%
VGG16_model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

# %% [markdown]
# ### Train the Model

# %%
checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.VGG16.hdf5', 
                               verbose=1, save_best_only=True)

VGG16_model.fit(train_VGG16, train_targets, 
          validation_data=(valid_VGG16, valid_targets),
          epochs=20, batch_size=20, callbacks=[checkpointer], verbose=1)
# Out:
# Train on 6680 samples, validate on 835 samples
# Epoch 1/20
# 6560/6680 [============================>.] - ETA: 2:10 - loss: 15.1886 - acc: 0.0000e+ - ETA: 16s - loss: 14.8716 - acc: 0.0167     - ETA: 9s - loss: 14.7451 - acc: 0.020 - ETA: 6s - loss: 14.6066 - acc: 0.02 - ETA: 5s - loss: 14.5331 - acc: 0.02 - ETA: 4s - loss: 14.3390 - acc: 0.02 - ETA: 3s - loss: 14.2299 - acc: 0.03 - ETA: 3s - loss: 14.1833 - acc: 0.03 - ETA: 3s - loss: 14.0529 - acc: 0.03 - ETA: 2s - loss: 13.9326 - acc: 0.03 - ETA: 2s - loss: 13.8089 - acc: 0.04 - ETA: 2s - loss: 13.7558 - acc: 0.04 - ETA: 2s - loss: 13.6403 - acc: 0.04 - ETA: 2s - loss: 13.5127 - acc: 0.05 - ETA: 2s - loss: 13.4191 - acc: 0.05 - ETA: 1s - loss: 13.3239 - acc: 0.05 - ETA: 1s - loss: 13.2884 - acc: 0.06 - ETA: 1s - loss: 13.2250 - acc: 0.06 - ETA: 1s - loss: 13.1696 - acc: 0.06 - ETA: 1s - loss: 13.1004 - acc: 0.07 - ETA: 1s - loss: 13.0502 - acc: 0.07 - ETA: 1s - loss: 12.9444 - acc: 0.07 - ETA: 1s - loss: 12.9052 - acc: 0.07 - ETA: 1s - loss: 12.8406 - acc: 0.08 - ETA: 0s - loss: 12.7926 - acc: 0.08 - ETA: 0s - loss: 12.7181 - acc: 0.08 - ETA: 0s - loss: 12.6664 - acc: 0.08 - ETA: 0s - loss: 12.6032 - acc: 0.09 - ETA: 0s - loss: 12.5200 - acc: 0.09 - ETA: 0s - loss: 12.4885 - acc: 0.09 - ETA: 0s - loss: 12.4228 - acc: 0.10 - ETA: 0s - loss: 12.3634 - acc: 0.10 - ETA: 0s - loss: 12.3000 - acc: 0.10 - ETA: 0s - loss: 12.2448 - acc: 0.10 - ETA: 0s - loss: 12.1711 - acc: 0.11 - ETA: 0s - loss: 12.1295 - acc: 0.11 - ETA: 0s - loss: 12.0877 - acc: 0.11 - ETA: 0s - loss: 12.0106 - acc: 0.1232
# Epoch 00001: val_loss improved from inf to 10.37473, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 3s 409us/step - loss: 11.9835 - acc: 0.1247 - val_loss: 10.3747 - val_acc: 0.2156
# Epoch 2/20
# 6500/6680 [============================>.] - ETA: 1s - loss: 9.8367 - acc: 0.350 - ETA: 1s - loss: 9.8873 - acc: 0.265 - ETA: 1s - loss: 9.7399 - acc: 0.271 - ETA: 1s - loss: 9.6341 - acc: 0.287 - ETA: 1s - loss: 9.7419 - acc: 0.275 - ETA: 1s - loss: 9.6961 - acc: 0.275 - ETA: 1s - loss: 9.5700 - acc: 0.283 - ETA: 1s - loss: 9.5200 - acc: 0.277 - ETA: 1s - loss: 9.4489 - acc: 0.278 - ETA: 1s - loss: 9.4420 - acc: 0.285 - ETA: 1s - loss: 9.4338 - acc: 0.284 - ETA: 1s - loss: 9.5412 - acc: 0.282 - ETA: 1s - loss: 9.5003 - acc: 0.285 - ETA: 1s - loss: 9.5221 - acc: 0.286 - ETA: 1s - loss: 9.5235 - acc: 0.285 - ETA: 1s - loss: 9.5455 - acc: 0.284 - ETA: 1s - loss: 9.5467 - acc: 0.281 - ETA: 1s - loss: 9.5449 - acc: 0.281 - ETA: 1s - loss: 9.5323 - acc: 0.283 - ETA: 1s - loss: 9.5127 - acc: 0.285 - ETA: 0s - loss: 9.5241 - acc: 0.285 - ETA: 0s - loss: 9.5314 - acc: 0.285 - ETA: 0s - loss: 9.4758 - acc: 0.289 - ETA: 0s - loss: 9.4816 - acc: 0.289 - ETA: 0s - loss: 9.4862 - acc: 0.289 - ETA: 0s - loss: 9.4874 - acc: 0.290 - ETA: 0s - loss: 9.4877 - acc: 0.290 - ETA: 0s - loss: 9.4688 - acc: 0.292 - ETA: 0s - loss: 9.4771 - acc: 0.292 - ETA: 0s - loss: 9.4431 - acc: 0.295 - ETA: 0s - loss: 9.4320 - acc: 0.295 - ETA: 0s - loss: 9.3978 - acc: 0.297 - ETA: 0s - loss: 9.3938 - acc: 0.296 - ETA: 0s - loss: 9.3839 - acc: 0.298 - ETA: 0s - loss: 9.3625 - acc: 0.299 - ETA: 0s - loss: 9.3682 - acc: 0.300 - ETA: 0s - loss: 9.3541 - acc: 0.300 - ETA: 0s - loss: 9.3649 - acc: 0.301 - ETA: 0s - loss: 9.3577 - acc: 0.3017
# Epoch 00002: val_loss improved from 10.37473 to 9.28505, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 331us/step - loss: 9.3285 - acc: 0.3042 - val_loss: 9.2851 - val_acc: 0.3018
# Epoch 3/20
# 6500/6680 [============================>.] - ETA: 2s - loss: 11.4646 - acc: 0.25 - ETA: 2s - loss: 9.4700 - acc: 0.3222 - ETA: 1s - loss: 9.4441 - acc: 0.330 - ETA: 1s - loss: 9.2434 - acc: 0.342 - ETA: 1s - loss: 9.0557 - acc: 0.359 - ETA: 1s - loss: 9.0684 - acc: 0.356 - ETA: 1s - loss: 8.9626 - acc: 0.362 - ETA: 1s - loss: 8.9580 - acc: 0.362 - ETA: 1s - loss: 8.8471 - acc: 0.368 - ETA: 1s - loss: 8.8233 - acc: 0.366 - ETA: 1s - loss: 8.7314 - acc: 0.372 - ETA: 1s - loss: 8.7287 - acc: 0.371 - ETA: 1s - loss: 8.6396 - acc: 0.377 - ETA: 1s - loss: 8.6251 - acc: 0.374 - ETA: 1s - loss: 8.5830 - acc: 0.378 - ETA: 1s - loss: 8.6185 - acc: 0.378 - ETA: 1s - loss: 8.7279 - acc: 0.373 - ETA: 1s - loss: 8.6696 - acc: 0.377 - ETA: 1s - loss: 8.6392 - acc: 0.379 - ETA: 1s - loss: 8.6391 - acc: 0.380 - ETA: 0s - loss: 8.6452 - acc: 0.381 - ETA: 0s - loss: 8.6058 - acc: 0.383 - ETA: 0s - loss: 8.6205 - acc: 0.383 - ETA: 0s - loss: 8.5877 - acc: 0.384 - ETA: 0s - loss: 8.6057 - acc: 0.384 - ETA: 0s - loss: 8.6028 - acc: 0.385 - ETA: 0s - loss: 8.6420 - acc: 0.384 - ETA: 0s - loss: 8.6408 - acc: 0.383 - ETA: 0s - loss: 8.6657 - acc: 0.382 - ETA: 0s - loss: 8.6727 - acc: 0.381 - ETA: 0s - loss: 8.6455 - acc: 0.382 - ETA: 0s - loss: 8.6371 - acc: 0.382 - ETA: 0s - loss: 8.6352 - acc: 0.382 - ETA: 0s - loss: 8.6360 - acc: 0.381 - ETA: 0s - loss: 8.6151 - acc: 0.382 - ETA: 0s - loss: 8.6058 - acc: 0.381 - ETA: 0s - loss: 8.6163 - acc: 0.382 - ETA: 0s - loss: 8.6249 - acc: 0.380 - ETA: 0s - loss: 8.6203 - acc: 0.3814
# Epoch 00003: val_loss improved from 9.28505 to 8.99086, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 333us/step - loss: 8.6265 - acc: 0.3808 - val_loss: 8.9909 - val_acc: 0.3317
# Epoch 4/20
# 6500/6680 [============================>.] - ETA: 2s - loss: 11.3435 - acc: 0.25 - ETA: 1s - loss: 8.2301 - acc: 0.4227 - ETA: 1s - loss: 8.4431 - acc: 0.402 - ETA: 1s - loss: 8.3868 - acc: 0.403 - ETA: 1s - loss: 8.5450 - acc: 0.409 - ETA: 1s - loss: 8.5423 - acc: 0.408 - ETA: 1s - loss: 8.5766 - acc: 0.407 - ETA: 1s - loss: 8.5711 - acc: 0.403 - ETA: 1s - loss: 8.4298 - acc: 0.409 - ETA: 1s - loss: 8.4392 - acc: 0.409 - ETA: 1s - loss: 8.4291 - acc: 0.411 - ETA: 1s - loss: 8.3425 - acc: 0.415 - ETA: 1s - loss: 8.3605 - acc: 0.415 - ETA: 1s - loss: 8.3638 - acc: 0.413 - ETA: 1s - loss: 8.3222 - acc: 0.417 - ETA: 1s - loss: 8.3186 - acc: 0.419 - ETA: 1s - loss: 8.3465 - acc: 0.417 - ETA: 1s - loss: 8.3295 - acc: 0.418 - ETA: 1s - loss: 8.3140 - acc: 0.420 - ETA: 0s - loss: 8.2714 - acc: 0.421 - ETA: 0s - loss: 8.2446 - acc: 0.422 - ETA: 0s - loss: 8.2522 - acc: 0.420 - ETA: 0s - loss: 8.2377 - acc: 0.421 - ETA: 0s - loss: 8.2215 - acc: 0.423 - ETA: 0s - loss: 8.2421 - acc: 0.422 - ETA: 0s - loss: 8.2712 - acc: 0.420 - ETA: 0s - loss: 8.2484 - acc: 0.421 - ETA: 0s - loss: 8.2565 - acc: 0.420 - ETA: 0s - loss: 8.2190 - acc: 0.422 - ETA: 0s - loss: 8.1797 - acc: 0.425 - ETA: 0s - loss: 8.1661 - acc: 0.425 - ETA: 0s - loss: 8.1664 - acc: 0.424 - ETA: 0s - loss: 8.1432 - acc: 0.425 - ETA: 0s - loss: 8.1273 - acc: 0.426 - ETA: 0s - loss: 8.1246 - acc: 0.426 - ETA: 0s - loss: 8.1558 - acc: 0.423 - ETA: 0s - loss: 8.1676 - acc: 0.422 - ETA: 0s - loss: 8.1523 - acc: 0.4232
# Epoch 00004: val_loss improved from 8.99086 to 8.67004, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 324us/step - loss: 8.1471 - acc: 0.4231 - val_loss: 8.6700 - val_acc: 0.3533
# Epoch 5/20
# 6660/6680 [============================>.] - ETA: 1s - loss: 5.8198 - acc: 0.600 - ETA: 1s - loss: 8.0927 - acc: 0.440 - ETA: 1s - loss: 7.8846 - acc: 0.450 - ETA: 2s - loss: 7.7667 - acc: 0.458 - ETA: 1s - loss: 7.8020 - acc: 0.460 - ETA: 1s - loss: 7.7319 - acc: 0.465 - ETA: 1s - loss: 7.8221 - acc: 0.458 - ETA: 1s - loss: 7.7517 - acc: 0.463 - ETA: 1s - loss: 7.7321 - acc: 0.461 - ETA: 1s - loss: 7.6845 - acc: 0.464 - ETA: 1s - loss: 7.6946 - acc: 0.462 - ETA: 1s - loss: 7.7866 - acc: 0.457 - ETA: 1s - loss: 7.8220 - acc: 0.456 - ETA: 1s - loss: 7.8701 - acc: 0.453 - ETA: 1s - loss: 7.8575 - acc: 0.456 - ETA: 1s - loss: 7.8888 - acc: 0.455 - ETA: 1s - loss: 7.8253 - acc: 0.458 - ETA: 1s - loss: 7.8411 - acc: 0.458 - ETA: 1s - loss: 7.8076 - acc: 0.461 - ETA: 1s - loss: 7.7932 - acc: 0.461 - ETA: 0s - loss: 7.7632 - acc: 0.463 - ETA: 0s - loss: 7.7898 - acc: 0.462 - ETA: 0s - loss: 7.7639 - acc: 0.464 - ETA: 0s - loss: 7.7465 - acc: 0.464 - ETA: 0s - loss: 7.7069 - acc: 0.467 - ETA: 0s - loss: 7.7062 - acc: 0.466 - ETA: 0s - loss: 7.7131 - acc: 0.465 - ETA: 0s - loss: 7.6919 - acc: 0.468 - ETA: 0s - loss: 7.6930 - acc: 0.466 - ETA: 0s - loss: 7.7234 - acc: 0.465 - ETA: 0s - loss: 7.7492 - acc: 0.464 - ETA: 0s - loss: 7.7547 - acc: 0.464 - ETA: 0s - loss: 7.7589 - acc: 0.464 - ETA: 0s - loss: 7.7805 - acc: 0.463 - ETA: 0s - loss: 7.7978 - acc: 0.462 - ETA: 0s - loss: 7.7911 - acc: 0.462 - ETA: 0s - loss: 7.7735 - acc: 0.464 - ETA: 0s - loss: 7.7828 - acc: 0.463 - ETA: 0s - loss: 7.7941 - acc: 0.4625
# Epoch 00005: val_loss improved from 8.67004 to 8.44699, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 328us/step - loss: 7.7933 - acc: 0.4624 - val_loss: 8.4470 - val_acc: 0.3641
# Epoch 6/20
# 6500/6680 [============================>.] - ETA: 2s - loss: 8.0598 - acc: 0.500 - ETA: 1s - loss: 7.5864 - acc: 0.504 - ETA: 1s - loss: 7.7009 - acc: 0.502 - ETA: 1s - loss: 7.5523 - acc: 0.503 - ETA: 1s - loss: 7.6383 - acc: 0.495 - ETA: 1s - loss: 7.6519 - acc: 0.491 - ETA: 1s - loss: 7.5915 - acc: 0.494 - ETA: 1s - loss: 7.4755 - acc: 0.500 - ETA: 1s - loss: 7.5665 - acc: 0.494 - ETA: 1s - loss: 7.4844 - acc: 0.502 - ETA: 1s - loss: 7.6519 - acc: 0.491 - ETA: 1s - loss: 7.7257 - acc: 0.487 - ETA: 1s - loss: 7.7013 - acc: 0.489 - ETA: 1s - loss: 7.6620 - acc: 0.491 - ETA: 1s - loss: 7.6397 - acc: 0.491 - ETA: 1s - loss: 7.6033 - acc: 0.495 - ETA: 1s - loss: 7.5858 - acc: 0.495 - ETA: 1s - loss: 7.5705 - acc: 0.495 - ETA: 1s - loss: 7.6186 - acc: 0.491 - ETA: 1s - loss: 7.6100 - acc: 0.492 - ETA: 1s - loss: 7.5640 - acc: 0.494 - ETA: 0s - loss: 7.5655 - acc: 0.493 - ETA: 0s - loss: 7.5874 - acc: 0.492 - ETA: 0s - loss: 7.5943 - acc: 0.491 - ETA: 0s - loss: 7.5550 - acc: 0.493 - ETA: 0s - loss: 7.5827 - acc: 0.492 - ETA: 0s - loss: 7.5532 - acc: 0.493 - ETA: 0s - loss: 7.5695 - acc: 0.492 - ETA: 0s - loss: 7.5666 - acc: 0.492 - ETA: 0s - loss: 7.5901 - acc: 0.491 - ETA: 0s - loss: 7.5671 - acc: 0.492 - ETA: 0s - loss: 7.5944 - acc: 0.491 - ETA: 0s - loss: 7.5833 - acc: 0.492 - ETA: 0s - loss: 7.6140 - acc: 0.489 - ETA: 0s - loss: 7.6180 - acc: 0.489 - ETA: 0s - loss: 7.6405 - acc: 0.487 - ETA: 0s - loss: 7.6614 - acc: 0.486 - ETA: 0s - loss: 7.6503 - acc: 0.487 - ETA: 0s - loss: 7.6582 - acc: 0.4871
# Epoch 00006: val_loss did not improve
# 6680/6680 [==============================] - 2s 328us/step - loss: 7.6538 - acc: 0.4873 - val_loss: 8.4525 - val_acc: 0.3772
# Epoch 7/20
# 6620/6680 [============================>.] - ETA: 1s - loss: 8.4769 - acc: 0.450 - ETA: 1s - loss: 7.5937 - acc: 0.505 - ETA: 1s - loss: 7.6483 - acc: 0.494 - ETA: 1s - loss: 7.3241 - acc: 0.513 - ETA: 1s - loss: 7.1189 - acc: 0.527 - ETA: 1s - loss: 7.1181 - acc: 0.527 - ETA: 1s - loss: 7.2188 - acc: 0.520 - ETA: 1s - loss: 7.2432 - acc: 0.519 - ETA: 1s - loss: 7.3242 - acc: 0.515 - ETA: 1s - loss: 7.3408 - acc: 0.517 - ETA: 1s - loss: 7.3510 - acc: 0.516 - ETA: 1s - loss: 7.4744 - acc: 0.510 - ETA: 1s - loss: 7.4936 - acc: 0.509 - ETA: 1s - loss: 7.4713 - acc: 0.511 - ETA: 1s - loss: 7.4346 - acc: 0.512 - ETA: 1s - loss: 7.4097 - acc: 0.513 - ETA: 1s - loss: 7.4634 - acc: 0.509 - ETA: 1s - loss: 7.4796 - acc: 0.507 - ETA: 1s - loss: 7.4627 - acc: 0.507 - ETA: 1s - loss: 7.4435 - acc: 0.508 - ETA: 1s - loss: 7.4048 - acc: 0.509 - ETA: 0s - loss: 7.4316 - acc: 0.508 - ETA: 0s - loss: 7.4101 - acc: 0.510 - ETA: 0s - loss: 7.4130 - acc: 0.510 - ETA: 0s - loss: 7.4262 - acc: 0.509 - ETA: 0s - loss: 7.4298 - acc: 0.508 - ETA: 0s - loss: 7.3991 - acc: 0.510 - ETA: 0s - loss: 7.4190 - acc: 0.509 - ETA: 0s - loss: 7.4742 - acc: 0.506 - ETA: 0s - loss: 7.5196 - acc: 0.502 - ETA: 0s - loss: 7.5143 - acc: 0.502 - ETA: 0s - loss: 7.5241 - acc: 0.502 - ETA: 0s - loss: 7.5309 - acc: 0.501 - ETA: 0s - loss: 7.5368 - acc: 0.501 - ETA: 0s - loss: 7.5521 - acc: 0.500 - ETA: 0s - loss: 7.5432 - acc: 0.501 - ETA: 0s - loss: 7.5268 - acc: 0.502 - ETA: 0s - loss: 7.5247 - acc: 0.502 - ETA: 0s - loss: 7.5167 - acc: 0.502 - ETA: 0s - loss: 7.5190 - acc: 0.5027
# Epoch 00007: val_loss improved from 8.44699 to 8.22953, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 340us/step - loss: 7.5446 - acc: 0.5013 - val_loss: 8.2295 - val_acc: 0.3796
# Epoch 8/20
# 6560/6680 [============================>.] - ETA: 2s - loss: 8.8689 - acc: 0.450 - ETA: 2s - loss: 8.1867 - acc: 0.488 - ETA: 2s - loss: 7.5300 - acc: 0.519 - ETA: 1s - loss: 7.2514 - acc: 0.535 - ETA: 1s - loss: 7.3681 - acc: 0.528 - ETA: 1s - loss: 7.5563 - acc: 0.515 - ETA: 1s - loss: 7.5228 - acc: 0.515 - ETA: 1s - loss: 7.5989 - acc: 0.508 - ETA: 1s - loss: 7.6061 - acc: 0.507 - ETA: 1s - loss: 7.4868 - acc: 0.514 - ETA: 1s - loss: 7.5140 - acc: 0.509 - ETA: 1s - loss: 7.5529 - acc: 0.507 - ETA: 1s - loss: 7.6056 - acc: 0.503 - ETA: 1s - loss: 7.6239 - acc: 0.501 - ETA: 1s - loss: 7.5345 - acc: 0.506 - ETA: 1s - loss: 7.5365 - acc: 0.507 - ETA: 1s - loss: 7.5694 - acc: 0.505 - ETA: 1s - loss: 7.5863 - acc: 0.504 - ETA: 1s - loss: 7.5715 - acc: 0.504 - ETA: 1s - loss: 7.5706 - acc: 0.504 - ETA: 0s - loss: 7.5287 - acc: 0.506 - ETA: 0s - loss: 7.5785 - acc: 0.504 - ETA: 0s - loss: 7.5595 - acc: 0.506 - ETA: 0s - loss: 7.5211 - acc: 0.508 - ETA: 0s - loss: 7.5293 - acc: 0.507 - ETA: 0s - loss: 7.5326 - acc: 0.506 - ETA: 0s - loss: 7.4973 - acc: 0.508 - ETA: 0s - loss: 7.4823 - acc: 0.509 - ETA: 0s - loss: 7.4824 - acc: 0.508 - ETA: 0s - loss: 7.4562 - acc: 0.510 - ETA: 0s - loss: 7.4742 - acc: 0.508 - ETA: 0s - loss: 7.4768 - acc: 0.508 - ETA: 0s - loss: 7.4332 - acc: 0.511 - ETA: 0s - loss: 7.4371 - acc: 0.510 - ETA: 0s - loss: 7.4337 - acc: 0.510 - ETA: 0s - loss: 7.4151 - acc: 0.511 - ETA: 0s - loss: 7.3873 - acc: 0.512 - ETA: 0s - loss: 7.3648 - acc: 0.513 - ETA: 0s - loss: 7.3639 - acc: 0.5131
# Epoch 00008: val_loss improved from 8.22953 to 8.05570, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 332us/step - loss: 7.3635 - acc: 0.5132 - val_loss: 8.0557 - val_acc: 0.3856
# Epoch 9/20
# 6640/6680 [============================>.] - ETA: 1s - loss: 6.2633 - acc: 0.600 - ETA: 1s - loss: 6.8652 - acc: 0.570 - ETA: 1s - loss: 6.9034 - acc: 0.565 - ETA: 1s - loss: 7.0317 - acc: 0.551 - ETA: 1s - loss: 6.9786 - acc: 0.552 - ETA: 1s - loss: 7.1441 - acc: 0.540 - ETA: 1s - loss: 7.2254 - acc: 0.532 - ETA: 1s - loss: 7.1026 - acc: 0.539 - ETA: 1s - loss: 7.1466 - acc: 0.535 - ETA: 1s - loss: 7.1412 - acc: 0.537 - ETA: 1s - loss: 7.1007 - acc: 0.539 - ETA: 1s - loss: 7.1133 - acc: 0.538 - ETA: 1s - loss: 7.2500 - acc: 0.529 - ETA: 1s - loss: 7.1892 - acc: 0.533 - ETA: 1s - loss: 7.2400 - acc: 0.529 - ETA: 1s - loss: 7.1866 - acc: 0.532 - ETA: 1s - loss: 7.1804 - acc: 0.533 - ETA: 1s - loss: 7.1886 - acc: 0.532 - ETA: 1s - loss: 7.1727 - acc: 0.532 - ETA: 1s - loss: 7.1847 - acc: 0.532 - ETA: 1s - loss: 7.1530 - acc: 0.532 - ETA: 1s - loss: 7.1920 - acc: 0.529 - ETA: 0s - loss: 7.1789 - acc: 0.530 - ETA: 0s - loss: 7.1599 - acc: 0.529 - ETA: 0s - loss: 7.1714 - acc: 0.529 - ETA: 0s - loss: 7.1644 - acc: 0.528 - ETA: 0s - loss: 7.1487 - acc: 0.528 - ETA: 0s - loss: 7.1588 - acc: 0.526 - ETA: 0s - loss: 7.1428 - acc: 0.527 - ETA: 0s - loss: 7.1593 - acc: 0.526 - ETA: 0s - loss: 7.1600 - acc: 0.526 - ETA: 0s - loss: 7.1610 - acc: 0.527 - ETA: 0s - loss: 7.1378 - acc: 0.528 - ETA: 0s - loss: 7.1539 - acc: 0.527 - ETA: 0s - loss: 7.1500 - acc: 0.528 - ETA: 0s - loss: 7.1912 - acc: 0.526 - ETA: 0s - loss: 7.1820 - acc: 0.526 - ETA: 0s - loss: 7.1976 - acc: 0.525 - ETA: 0s - loss: 7.1940 - acc: 0.525 - ETA: 0s - loss: 7.1918 - acc: 0.525 - ETA: 0s - loss: 7.1561 - acc: 0.5283
# Epoch 00009: val_loss improved from 8.05570 to 7.92959, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 345us/step - loss: 7.1571 - acc: 0.5283 - val_loss: 7.9296 - val_acc: 0.4048
# Epoch 10/20
# 6640/6680 [============================>.] - ETA: 2s - loss: 8.1197 - acc: 0.450 - ETA: 1s - loss: 6.4446 - acc: 0.570 - ETA: 1s - loss: 6.9259 - acc: 0.547 - ETA: 1s - loss: 6.8561 - acc: 0.550 - ETA: 1s - loss: 6.9478 - acc: 0.544 - ETA: 1s - loss: 7.0749 - acc: 0.539 - ETA: 1s - loss: 6.9757 - acc: 0.545 - ETA: 1s - loss: 7.1290 - acc: 0.535 - ETA: 1s - loss: 7.1112 - acc: 0.538 - ETA: 1s - loss: 7.0408 - acc: 0.539 - ETA: 1s - loss: 7.0374 - acc: 0.542 - ETA: 1s - loss: 7.0040 - acc: 0.545 - ETA: 1s - loss: 7.0840 - acc: 0.540 - ETA: 1s - loss: 7.1461 - acc: 0.537 - ETA: 1s - loss: 7.1221 - acc: 0.538 - ETA: 1s - loss: 7.1204 - acc: 0.539 - ETA: 1s - loss: 7.1189 - acc: 0.537 - ETA: 1s - loss: 7.0609 - acc: 0.540 - ETA: 1s - loss: 7.0516 - acc: 0.541 - ETA: 0s - loss: 7.0526 - acc: 0.542 - ETA: 0s - loss: 7.0253 - acc: 0.544 - ETA: 0s - loss: 6.9991 - acc: 0.545 - ETA: 0s - loss: 6.9999 - acc: 0.545 - ETA: 0s - loss: 7.0728 - acc: 0.540 - ETA: 0s - loss: 7.0857 - acc: 0.539 - ETA: 0s - loss: 7.1024 - acc: 0.539 - ETA: 0s - loss: 7.1191 - acc: 0.538 - ETA: 0s - loss: 7.1015 - acc: 0.538 - ETA: 0s - loss: 7.0672 - acc: 0.540 - ETA: 0s - loss: 7.0785 - acc: 0.540 - ETA: 0s - loss: 7.0861 - acc: 0.539 - ETA: 0s - loss: 7.0778 - acc: 0.539 - ETA: 0s - loss: 7.0875 - acc: 0.538 - ETA: 0s - loss: 7.0952 - acc: 0.537 - ETA: 0s - loss: 7.0659 - acc: 0.539 - ETA: 0s - loss: 7.0362 - acc: 0.540 - ETA: 0s - loss: 7.0009 - acc: 0.542 - ETA: 0s - loss: 6.9898 - acc: 0.542 - ETA: 0s - loss: 6.9955 - acc: 0.5417
# Epoch 00010: val_loss improved from 7.92959 to 7.78071, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 331us/step - loss: 6.9949 - acc: 0.5418 - val_loss: 7.7807 - val_acc: 0.4108
# Epoch 11/20
# 6580/6680 [============================>.] - ETA: 1s - loss: 7.3964 - acc: 0.450 - ETA: 1s - loss: 6.7695 - acc: 0.555 - ETA: 1s - loss: 7.4237 - acc: 0.511 - ETA: 1s - loss: 7.1769 - acc: 0.530 - ETA: 1s - loss: 7.1520 - acc: 0.537 - ETA: 1s - loss: 6.9880 - acc: 0.547 - ETA: 1s - loss: 6.9366 - acc: 0.553 - ETA: 1s - loss: 6.8209 - acc: 0.561 - ETA: 1s - loss: 6.7432 - acc: 0.564 - ETA: 1s - loss: 6.7310 - acc: 0.564 - ETA: 1s - loss: 6.7762 - acc: 0.561 - ETA: 1s - loss: 6.7072 - acc: 0.564 - ETA: 1s - loss: 6.6339 - acc: 0.569 - ETA: 1s - loss: 6.6553 - acc: 0.567 - ETA: 1s - loss: 6.6828 - acc: 0.566 - ETA: 1s - loss: 6.7007 - acc: 0.565 - ETA: 1s - loss: 6.7245 - acc: 0.562 - ETA: 1s - loss: 6.6733 - acc: 0.565 - ETA: 1s - loss: 6.6265 - acc: 0.568 - ETA: 1s - loss: 6.6223 - acc: 0.568 - ETA: 1s - loss: 6.6400 - acc: 0.567 - ETA: 0s - loss: 6.6270 - acc: 0.566 - ETA: 0s - loss: 6.6112 - acc: 0.566 - ETA: 0s - loss: 6.5810 - acc: 0.567 - ETA: 0s - loss: 6.5827 - acc: 0.566 - ETA: 0s - loss: 6.6211 - acc: 0.564 - ETA: 0s - loss: 6.6068 - acc: 0.565 - ETA: 0s - loss: 6.6243 - acc: 0.564 - ETA: 0s - loss: 6.6341 - acc: 0.563 - ETA: 0s - loss: 6.6549 - acc: 0.562 - ETA: 0s - loss: 6.6555 - acc: 0.562 - ETA: 0s - loss: 6.6513 - acc: 0.562 - ETA: 0s - loss: 6.6411 - acc: 0.561 - ETA: 0s - loss: 6.6388 - acc: 0.561 - ETA: 0s - loss: 6.6510 - acc: 0.560 - ETA: 0s - loss: 6.6609 - acc: 0.560 - ETA: 0s - loss: 6.6711 - acc: 0.558 - ETA: 0s - loss: 6.6910 - acc: 0.557 - ETA: 0s - loss: 6.6942 - acc: 0.5565
# Epoch 00011: val_loss improved from 7.78071 to 7.55291, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 334us/step - loss: 6.7202 - acc: 0.5545 - val_loss: 7.5529 - val_acc: 0.4240
# Epoch 12/20
# 6500/6680 [============================>.] - ETA: 1s - loss: 7.1144 - acc: 0.550 - ETA: 1s - loss: 6.7277 - acc: 0.559 - ETA: 1s - loss: 6.4859 - acc: 0.582 - ETA: 1s - loss: 6.3296 - acc: 0.586 - ETA: 1s - loss: 6.4237 - acc: 0.573 - ETA: 1s - loss: 6.3426 - acc: 0.575 - ETA: 1s - loss: 6.2208 - acc: 0.583 - ETA: 1s - loss: 6.3056 - acc: 0.576 - ETA: 1s - loss: 6.3527 - acc: 0.574 - ETA: 1s - loss: 6.3582 - acc: 0.573 - ETA: 1s - loss: 6.3722 - acc: 0.572 - ETA: 1s - loss: 6.3655 - acc: 0.573 - ETA: 1s - loss: 6.4554 - acc: 0.567 - ETA: 1s - loss: 6.5289 - acc: 0.564 - ETA: 1s - loss: 6.5545 - acc: 0.564 - ETA: 1s - loss: 6.5406 - acc: 0.565 - ETA: 1s - loss: 6.5865 - acc: 0.561 - ETA: 1s - loss: 6.5661 - acc: 0.564 - ETA: 1s - loss: 6.5913 - acc: 0.562 - ETA: 0s - loss: 6.5834 - acc: 0.563 - ETA: 0s - loss: 6.5935 - acc: 0.562 - ETA: 0s - loss: 6.6138 - acc: 0.561 - ETA: 0s - loss: 6.5902 - acc: 0.563 - ETA: 0s - loss: 6.6089 - acc: 0.562 - ETA: 0s - loss: 6.5400 - acc: 0.567 - ETA: 0s - loss: 6.5281 - acc: 0.568 - ETA: 0s - loss: 6.5186 - acc: 0.569 - ETA: 0s - loss: 6.5178 - acc: 0.569 - ETA: 0s - loss: 6.5080 - acc: 0.570 - ETA: 0s - loss: 6.5290 - acc: 0.569 - ETA: 0s - loss: 6.5492 - acc: 0.567 - ETA: 0s - loss: 6.5574 - acc: 0.566 - ETA: 0s - loss: 6.5632 - acc: 0.566 - ETA: 0s - loss: 6.5567 - acc: 0.567 - ETA: 0s - loss: 6.5294 - acc: 0.569 - ETA: 0s - loss: 6.5257 - acc: 0.569 - ETA: 0s - loss: 6.5380 - acc: 0.568 - ETA: 0s - loss: 6.5515 - acc: 0.5683
# Epoch 00012: val_loss improved from 7.55291 to 7.52997, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 328us/step - loss: 6.5474 - acc: 0.5687 - val_loss: 7.5300 - val_acc: 0.4240
# Epoch 13/20
# 6480/6680 [============================>.] - ETA: 1s - loss: 5.6429 - acc: 0.650 - ETA: 2s - loss: 6.6052 - acc: 0.588 - ETA: 2s - loss: 6.1081 - acc: 0.620 - ETA: 1s - loss: 5.9135 - acc: 0.628 - ETA: 1s - loss: 6.3215 - acc: 0.598 - ETA: 1s - loss: 6.3825 - acc: 0.591 - ETA: 1s - loss: 6.3615 - acc: 0.592 - ETA: 1s - loss: 6.4446 - acc: 0.587 - ETA: 1s - loss: 6.4832 - acc: 0.585 - ETA: 1s - loss: 6.4916 - acc: 0.584 - ETA: 1s - loss: 6.4828 - acc: 0.584 - ETA: 1s - loss: 6.4563 - acc: 0.585 - ETA: 1s - loss: 6.4924 - acc: 0.581 - ETA: 1s - loss: 6.4759 - acc: 0.582 - ETA: 1s - loss: 6.5717 - acc: 0.577 - ETA: 1s - loss: 6.5427 - acc: 0.579 - ETA: 1s - loss: 6.5629 - acc: 0.578 - ETA: 1s - loss: 6.5821 - acc: 0.575 - ETA: 1s - loss: 6.5987 - acc: 0.574 - ETA: 1s - loss: 6.6916 - acc: 0.568 - ETA: 0s - loss: 6.6824 - acc: 0.568 - ETA: 0s - loss: 6.6547 - acc: 0.569 - ETA: 0s - loss: 6.6822 - acc: 0.568 - ETA: 0s - loss: 6.6079 - acc: 0.573 - ETA: 0s - loss: 6.6007 - acc: 0.573 - ETA: 0s - loss: 6.6026 - acc: 0.573 - ETA: 0s - loss: 6.5637 - acc: 0.576 - ETA: 0s - loss: 6.5586 - acc: 0.576 - ETA: 0s - loss: 6.5498 - acc: 0.576 - ETA: 0s - loss: 6.5742 - acc: 0.574 - ETA: 0s - loss: 6.5613 - acc: 0.576 - ETA: 0s - loss: 6.5342 - acc: 0.577 - ETA: 0s - loss: 6.5535 - acc: 0.576 - ETA: 0s - loss: 6.5253 - acc: 0.578 - ETA: 0s - loss: 6.5489 - acc: 0.577 - ETA: 0s - loss: 6.5333 - acc: 0.578 - ETA: 0s - loss: 6.5352 - acc: 0.578 - ETA: 0s - loss: 6.5118 - acc: 0.579 - ETA: 0s - loss: 6.5331 - acc: 0.5785
# Epoch 00013: val_loss improved from 7.52997 to 7.44760, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 334us/step - loss: 6.4864 - acc: 0.5814 - val_loss: 7.4476 - val_acc: 0.4407
# Epoch 14/20
# 6660/6680 [============================>.] - ETA: 1s - loss: 7.2556 - acc: 0.550 - ETA: 2s - loss: 5.6674 - acc: 0.644 - ETA: 2s - loss: 5.8098 - acc: 0.630 - ETA: 1s - loss: 6.1646 - acc: 0.611 - ETA: 1s - loss: 6.2970 - acc: 0.598 - ETA: 1s - loss: 6.0631 - acc: 0.611 - ETA: 1s - loss: 6.1394 - acc: 0.605 - ETA: 1s - loss: 6.2266 - acc: 0.600 - ETA: 1s - loss: 6.2965 - acc: 0.593 - ETA: 1s - loss: 6.2950 - acc: 0.594 - ETA: 1s - loss: 6.1666 - acc: 0.604 - ETA: 1s - loss: 6.2881 - acc: 0.596 - ETA: 1s - loss: 6.3742 - acc: 0.590 - ETA: 1s - loss: 6.3184 - acc: 0.595 - ETA: 1s - loss: 6.3122 - acc: 0.595 - ETA: 1s - loss: 6.3217 - acc: 0.595 - ETA: 1s - loss: 6.4022 - acc: 0.589 - ETA: 1s - loss: 6.3924 - acc: 0.589 - ETA: 1s - loss: 6.3985 - acc: 0.589 - ETA: 1s - loss: 6.4469 - acc: 0.586 - ETA: 0s - loss: 6.4989 - acc: 0.583 - ETA: 0s - loss: 6.5174 - acc: 0.582 - ETA: 0s - loss: 6.5073 - acc: 0.581 - ETA: 0s - loss: 6.4439 - acc: 0.585 - ETA: 0s - loss: 6.4372 - acc: 0.585 - ETA: 0s - loss: 6.4302 - acc: 0.585 - ETA: 0s - loss: 6.4364 - acc: 0.585 - ETA: 0s - loss: 6.4201 - acc: 0.585 - ETA: 0s - loss: 6.4236 - acc: 0.585 - ETA: 0s - loss: 6.4173 - acc: 0.585 - ETA: 0s - loss: 6.4117 - acc: 0.585 - ETA: 0s - loss: 6.4261 - acc: 0.584 - ETA: 0s - loss: 6.3860 - acc: 0.587 - ETA: 0s - loss: 6.3652 - acc: 0.588 - ETA: 0s - loss: 6.3675 - acc: 0.588 - ETA: 0s - loss: 6.3659 - acc: 0.588 - ETA: 0s - loss: 6.3848 - acc: 0.587 - ETA: 0s - loss: 6.3975 - acc: 0.586 - ETA: 0s - loss: 6.3979 - acc: 0.5863
# Epoch 00014: val_loss did not improve
# 6680/6680 [==============================] - 2s 321us/step - loss: 6.3957 - acc: 0.5865 - val_loss: 7.5407 - val_acc: 0.4251
# Epoch 15/20
# 6500/6680 [============================>.] - ETA: 2s - loss: 3.2278 - acc: 0.800 - ETA: 2s - loss: 5.6488 - acc: 0.650 - ETA: 2s - loss: 6.3233 - acc: 0.600 - ETA: 2s - loss: 6.4441 - acc: 0.593 - ETA: 1s - loss: 6.7128 - acc: 0.574 - ETA: 1s - loss: 6.6357 - acc: 0.575 - ETA: 1s - loss: 6.5522 - acc: 0.580 - ETA: 1s - loss: 6.4795 - acc: 0.582 - ETA: 1s - loss: 6.3981 - acc: 0.588 - ETA: 1s - loss: 6.3483 - acc: 0.591 - ETA: 1s - loss: 6.4243 - acc: 0.588 - ETA: 1s - loss: 6.4155 - acc: 0.588 - ETA: 1s - loss: 6.3941 - acc: 0.590 - ETA: 1s - loss: 6.3863 - acc: 0.590 - ETA: 1s - loss: 6.3490 - acc: 0.592 - ETA: 1s - loss: 6.3463 - acc: 0.591 - ETA: 1s - loss: 6.3158 - acc: 0.593 - ETA: 1s - loss: 6.2797 - acc: 0.595 - ETA: 1s - loss: 6.3150 - acc: 0.594 - ETA: 1s - loss: 6.3014 - acc: 0.596 - ETA: 0s - loss: 6.3148 - acc: 0.595 - ETA: 0s - loss: 6.3233 - acc: 0.594 - ETA: 0s - loss: 6.3604 - acc: 0.592 - ETA: 0s - loss: 6.3139 - acc: 0.595 - ETA: 0s - loss: 6.3197 - acc: 0.595 - ETA: 0s - loss: 6.3214 - acc: 0.596 - ETA: 0s - loss: 6.3405 - acc: 0.595 - ETA: 0s - loss: 6.3403 - acc: 0.594 - ETA: 0s - loss: 6.3784 - acc: 0.592 - ETA: 0s - loss: 6.3818 - acc: 0.592 - ETA: 0s - loss: 6.3611 - acc: 0.593 - ETA: 0s - loss: 6.3873 - acc: 0.592 - ETA: 0s - loss: 6.3365 - acc: 0.595 - ETA: 0s - loss: 6.3065 - acc: 0.597 - ETA: 0s - loss: 6.2958 - acc: 0.598 - ETA: 0s - loss: 6.3111 - acc: 0.597 - ETA: 0s - loss: 6.2982 - acc: 0.597 - ETA: 0s - loss: 6.3077 - acc: 0.5971
# Epoch 00015: val_loss improved from 7.44760 to 7.32695, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 334us/step - loss: 6.2975 - acc: 0.5979 - val_loss: 7.3270 - val_acc: 0.4491
# Epoch 16/20
# 6580/6680 [============================>.] - ETA: 3s - loss: 8.0596 - acc: 0.500 - ETA: 2s - loss: 5.5746 - acc: 0.645 - ETA: 1s - loss: 5.7033 - acc: 0.637 - ETA: 1s - loss: 5.9660 - acc: 0.622 - ETA: 1s - loss: 5.7994 - acc: 0.632 - ETA: 1s - loss: 5.7731 - acc: 0.635 - ETA: 1s - loss: 5.9426 - acc: 0.626 - ETA: 1s - loss: 6.1026 - acc: 0.617 - ETA: 1s - loss: 6.0932 - acc: 0.617 - ETA: 1s - loss: 6.0872 - acc: 0.616 - ETA: 1s - loss: 6.0837 - acc: 0.617 - ETA: 1s - loss: 6.1139 - acc: 0.614 - ETA: 1s - loss: 6.1132 - acc: 0.614 - ETA: 1s - loss: 6.1790 - acc: 0.610 - ETA: 1s - loss: 6.1901 - acc: 0.609 - ETA: 1s - loss: 6.1999 - acc: 0.609 - ETA: 1s - loss: 6.2062 - acc: 0.609 - ETA: 1s - loss: 6.2392 - acc: 0.607 - ETA: 1s - loss: 6.2784 - acc: 0.603 - ETA: 1s - loss: 6.2804 - acc: 0.602 - ETA: 0s - loss: 6.3119 - acc: 0.600 - ETA: 0s - loss: 6.2802 - acc: 0.602 - ETA: 0s - loss: 6.2522 - acc: 0.604 - ETA: 0s - loss: 6.2189 - acc: 0.606 - ETA: 0s - loss: 6.2130 - acc: 0.606 - ETA: 0s - loss: 6.1997 - acc: 0.607 - ETA: 0s - loss: 6.1706 - acc: 0.608 - ETA: 0s - loss: 6.1967 - acc: 0.607 - ETA: 0s - loss: 6.1928 - acc: 0.607 - ETA: 0s - loss: 6.1812 - acc: 0.607 - ETA: 0s - loss: 6.1922 - acc: 0.607 - ETA: 0s - loss: 6.1989 - acc: 0.606 - ETA: 0s - loss: 6.2326 - acc: 0.604 - ETA: 0s - loss: 6.2316 - acc: 0.604 - ETA: 0s - loss: 6.2437 - acc: 0.603 - ETA: 0s - loss: 6.2582 - acc: 0.603 - ETA: 0s - loss: 6.2662 - acc: 0.602 - ETA: 0s - loss: 6.2675 - acc: 0.602 - ETA: 0s - loss: 6.2727 - acc: 0.6020
# Epoch 00016: val_loss improved from 7.32695 to 7.30373, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 336us/step - loss: 6.2708 - acc: 0.6021 - val_loss: 7.3037 - val_acc: 0.4587
# Epoch 17/20
# 6520/6680 [============================>.] - ETA: 1s - loss: 6.4532 - acc: 0.600 - ETA: 1s - loss: 6.4113 - acc: 0.595 - ETA: 1s - loss: 6.4401 - acc: 0.594 - ETA: 1s - loss: 6.5340 - acc: 0.589 - ETA: 1s - loss: 6.2246 - acc: 0.609 - ETA: 1s - loss: 6.1445 - acc: 0.615 - ETA: 1s - loss: 6.2427 - acc: 0.608 - ETA: 1s - loss: 6.2176 - acc: 0.610 - ETA: 1s - loss: 6.1751 - acc: 0.613 - ETA: 1s - loss: 6.2167 - acc: 0.611 - ETA: 1s - loss: 6.1548 - acc: 0.615 - ETA: 1s - loss: 6.2241 - acc: 0.611 - ETA: 1s - loss: 6.2502 - acc: 0.609 - ETA: 1s - loss: 6.2507 - acc: 0.609 - ETA: 1s - loss: 6.2721 - acc: 0.607 - ETA: 1s - loss: 6.2247 - acc: 0.610 - ETA: 1s - loss: 6.2582 - acc: 0.608 - ETA: 1s - loss: 6.2417 - acc: 0.609 - ETA: 1s - loss: 6.2523 - acc: 0.608 - ETA: 1s - loss: 6.2789 - acc: 0.606 - ETA: 0s - loss: 6.2492 - acc: 0.607 - ETA: 0s - loss: 6.1780 - acc: 0.611 - ETA: 0s - loss: 6.1396 - acc: 0.613 - ETA: 0s - loss: 6.1537 - acc: 0.612 - ETA: 0s - loss: 6.1606 - acc: 0.612 - ETA: 0s - loss: 6.1578 - acc: 0.612 - ETA: 0s - loss: 6.2039 - acc: 0.609 - ETA: 0s - loss: 6.2264 - acc: 0.607 - ETA: 0s - loss: 6.2664 - acc: 0.604 - ETA: 0s - loss: 6.2383 - acc: 0.606 - ETA: 0s - loss: 6.2269 - acc: 0.606 - ETA: 0s - loss: 6.1767 - acc: 0.609 - ETA: 0s - loss: 6.1845 - acc: 0.608 - ETA: 0s - loss: 6.1736 - acc: 0.609 - ETA: 0s - loss: 6.1818 - acc: 0.608 - ETA: 0s - loss: 6.1949 - acc: 0.607 - ETA: 0s - loss: 6.2009 - acc: 0.606 - ETA: 0s - loss: 6.2334 - acc: 0.604 - ETA: 0s - loss: 6.2300 - acc: 0.6043
# Epoch 00017: val_loss did not improve
# 6680/6680 [==============================] - 2s 329us/step - loss: 6.2377 - acc: 0.6033 - val_loss: 7.4456 - val_acc: 0.4443
# Epoch 18/20
# 6520/6680 [============================>.] - ETA: 2s - loss: 4.6892 - acc: 0.700 - ETA: 2s - loss: 5.6308 - acc: 0.644 - ETA: 2s - loss: 5.7692 - acc: 0.629 - ETA: 1s - loss: 5.7243 - acc: 0.626 - ETA: 1s - loss: 6.1154 - acc: 0.602 - ETA: 1s - loss: 6.2951 - acc: 0.591 - ETA: 1s - loss: 6.2076 - acc: 0.596 - ETA: 1s - loss: 6.1011 - acc: 0.604 - ETA: 1s - loss: 6.1335 - acc: 0.602 - ETA: 1s - loss: 6.2102 - acc: 0.598 - ETA: 1s - loss: 6.2697 - acc: 0.594 - ETA: 1s - loss: 6.1538 - acc: 0.601 - ETA: 1s - loss: 6.0674 - acc: 0.607 - ETA: 1s - loss: 6.0075 - acc: 0.611 - ETA: 1s - loss: 6.0123 - acc: 0.611 - ETA: 1s - loss: 6.0618 - acc: 0.609 - ETA: 1s - loss: 6.1074 - acc: 0.606 - ETA: 1s - loss: 6.0589 - acc: 0.609 - ETA: 1s - loss: 6.0122 - acc: 0.611 - ETA: 1s - loss: 6.0467 - acc: 0.608 - ETA: 1s - loss: 6.0660 - acc: 0.606 - ETA: 0s - loss: 6.1392 - acc: 0.602 - ETA: 0s - loss: 6.1307 - acc: 0.602 - ETA: 0s - loss: 6.1377 - acc: 0.602 - ETA: 0s - loss: 6.1565 - acc: 0.601 - ETA: 0s - loss: 6.1555 - acc: 0.601 - ETA: 0s - loss: 6.1501 - acc: 0.602 - ETA: 0s - loss: 6.1531 - acc: 0.602 - ETA: 0s - loss: 6.1243 - acc: 0.604 - ETA: 0s - loss: 6.0886 - acc: 0.605 - ETA: 0s - loss: 6.0766 - acc: 0.607 - ETA: 0s - loss: 6.0555 - acc: 0.608 - ETA: 0s - loss: 6.0569 - acc: 0.607 - ETA: 0s - loss: 6.0450 - acc: 0.608 - ETA: 0s - loss: 6.0678 - acc: 0.606 - ETA: 0s - loss: 6.0925 - acc: 0.604 - ETA: 0s - loss: 6.1094 - acc: 0.603 - ETA: 0s - loss: 6.0956 - acc: 0.603 - ETA: 0s - loss: 6.1030 - acc: 0.6031
# Epoch 00018: val_loss improved from 7.30373 to 7.22625, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 334us/step - loss: 6.0965 - acc: 0.6033 - val_loss: 7.2263 - val_acc: 0.4467
# Epoch 19/20
# 6500/6680 [============================>.] - ETA: 1s - loss: 8.8652 - acc: 0.450 - ETA: 1s - loss: 5.3679 - acc: 0.660 - ETA: 1s - loss: 5.6522 - acc: 0.636 - ETA: 1s - loss: 5.5267 - acc: 0.642 - ETA: 1s - loss: 5.9196 - acc: 0.621 - ETA: 1s - loss: 6.0278 - acc: 0.611 - ETA: 1s - loss: 6.0042 - acc: 0.612 - ETA: 1s - loss: 6.2351 - acc: 0.598 - ETA: 1s - loss: 6.3855 - acc: 0.588 - ETA: 1s - loss: 6.3239 - acc: 0.593 - ETA: 1s - loss: 6.2500 - acc: 0.598 - ETA: 1s - loss: 6.2864 - acc: 0.595 - ETA: 1s - loss: 6.2131 - acc: 0.600 - ETA: 1s - loss: 6.1679 - acc: 0.602 - ETA: 1s - loss: 6.1365 - acc: 0.604 - ETA: 1s - loss: 6.1285 - acc: 0.605 - ETA: 1s - loss: 6.0807 - acc: 0.608 - ETA: 1s - loss: 6.0482 - acc: 0.609 - ETA: 1s - loss: 6.0258 - acc: 0.611 - ETA: 0s - loss: 5.9996 - acc: 0.613 - ETA: 0s - loss: 6.0098 - acc: 0.612 - ETA: 0s - loss: 6.0003 - acc: 0.612 - ETA: 0s - loss: 6.0161 - acc: 0.611 - ETA: 0s - loss: 5.9764 - acc: 0.614 - ETA: 0s - loss: 6.0078 - acc: 0.612 - ETA: 0s - loss: 5.9827 - acc: 0.613 - ETA: 0s - loss: 5.9479 - acc: 0.616 - ETA: 0s - loss: 5.9035 - acc: 0.618 - ETA: 0s - loss: 5.9369 - acc: 0.616 - ETA: 0s - loss: 5.9305 - acc: 0.617 - ETA: 0s - loss: 5.9421 - acc: 0.616 - ETA: 0s - loss: 5.9649 - acc: 0.615 - ETA: 0s - loss: 5.9846 - acc: 0.614 - ETA: 0s - loss: 5.9553 - acc: 0.616 - ETA: 0s - loss: 5.9380 - acc: 0.617 - ETA: 0s - loss: 5.9418 - acc: 0.617 - ETA: 0s - loss: 5.9483 - acc: 0.616 - ETA: 0s - loss: 5.9358 - acc: 0.6175
# Epoch 00019: val_loss improved from 7.22625 to 7.14717, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 327us/step - loss: 5.9632 - acc: 0.6157 - val_loss: 7.1472 - val_acc: 0.4719
# Epoch 20/20
# 6560/6680 [============================>.] - ETA: 1s - loss: 6.4474 - acc: 0.600 - ETA: 1s - loss: 6.6798 - acc: 0.580 - ETA: 1s - loss: 6.5023 - acc: 0.588 - ETA: 2s - loss: 6.1352 - acc: 0.614 - ETA: 1s - loss: 6.0179 - acc: 0.621 - ETA: 1s - loss: 6.0949 - acc: 0.615 - ETA: 1s - loss: 6.0662 - acc: 0.617 - ETA: 1s - loss: 5.9827 - acc: 0.620 - ETA: 1s - loss: 5.9337 - acc: 0.622 - ETA: 1s - loss: 5.8050 - acc: 0.630 - ETA: 1s - loss: 5.8291 - acc: 0.628 - ETA: 1s - loss: 5.8543 - acc: 0.626 - ETA: 1s - loss: 5.9065 - acc: 0.622 - ETA: 1s - loss: 5.8553 - acc: 0.624 - ETA: 1s - loss: 5.8604 - acc: 0.624 - ETA: 1s - loss: 5.8313 - acc: 0.624 - ETA: 1s - loss: 5.8348 - acc: 0.624 - ETA: 1s - loss: 5.8677 - acc: 0.622 - ETA: 1s - loss: 5.8564 - acc: 0.624 - ETA: 1s - loss: 5.8318 - acc: 0.625 - ETA: 1s - loss: 5.8702 - acc: 0.624 - ETA: 0s - loss: 5.8616 - acc: 0.624 - ETA: 0s - loss: 5.8555 - acc: 0.625 - ETA: 0s - loss: 5.8807 - acc: 0.624 - ETA: 0s - loss: 5.8478 - acc: 0.626 - ETA: 0s - loss: 5.8747 - acc: 0.625 - ETA: 0s - loss: 5.8954 - acc: 0.624 - ETA: 0s - loss: 5.9128 - acc: 0.622 - ETA: 0s - loss: 5.9443 - acc: 0.621 - ETA: 0s - loss: 5.9408 - acc: 0.621 - ETA: 0s - loss: 5.9372 - acc: 0.621 - ETA: 0s - loss: 5.9080 - acc: 0.622 - ETA: 0s - loss: 5.9287 - acc: 0.621 - ETA: 0s - loss: 5.9021 - acc: 0.623 - ETA: 0s - loss: 5.9036 - acc: 0.623 - ETA: 0s - loss: 5.9217 - acc: 0.622 - ETA: 0s - loss: 5.9444 - acc: 0.621 - ETA: 0s - loss: 5.9330 - acc: 0.622 - ETA: 0s - loss: 5.9368 - acc: 0.6220
# Epoch 00020: val_loss did not improve
# 6680/6680 [==============================] - 2s 326us/step - loss: 5.9300 - acc: 0.6223 - val_loss: 7.1705 - val_acc: 0.4707

# %% [markdown]
# ### Load the Model with the Best Validation Loss

# %%
VGG16_model.load_weights('saved_models/weights.best.VGG16.hdf5')

# %% [markdown]
# ### Test the Model
#
# Now, we can use the CNN to test how well it identifies breed within our test dataset of dog images.  We print the test accuracy below.

# %%
# get index of predicted dog breed for each image in test set
VGG16_predictions = [np.argmax(VGG16_model.predict(np.expand_dims(feature, axis=0))) for feature in test_VGG16]

# report test accuracy
test_accuracy = 100*np.sum(np.array(VGG16_predictions)==np.argmax(test_targets, axis=1))/len(VGG16_predictions)
print('Test accuracy: %.4f%%' % test_accuracy)
# Out:
# Test accuracy: 48.5646%

# %% [markdown]
# ### Predict Dog Breed with the Model

# %%
from extract_bottleneck_features import *

def VGG16_predict_breed(img_path):
    # extract bottleneck features
    bottleneck_feature = extract_VGG16(path_to_tensor(img_path))
    # obtain predicted vector
    predicted_vector = VGG16_model.predict(bottleneck_feature)
    # return dog breed that is predicted by the model
    return dog_names[np.argmax(predicted_vector)]

# %% [markdown]
# ---
# <a id='step5'></a>
# ## Step 5: Create a CNN to Classify Dog Breeds (using Transfer Learning)
#
# You will now use transfer learning to create a CNN that can identify dog breed from images.  Your CNN must attain at least 60% accuracy on the test set.
#
# In Step 4, we used transfer learning to create a CNN using VGG-16 bottleneck features.  In this section, you must use the bottleneck features from a different pre-trained model.  To make things easier for you, we have pre-computed the features for all of the networks that are currently available in Keras:
# - [VGG-19](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogVGG19Data.npz) bottleneck features
# - [ResNet-50](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogResnet50Data.npz) bottleneck features
# - [Inception](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogInceptionV3Data.npz) bottleneck features
# - [Xception](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogXceptionData.npz) bottleneck features
#
# The files are encoded as such:
#
#     Dog{network}Data.npz
#
# where `{network}`, in the above filename, can be one of `VGG19`, `Resnet50`, `InceptionV3`, or `Xception`.  Pick one of the above architectures, download the corresponding bottleneck features, and store the downloaded file in the `bottleneck_features/` folder in the repository.
#
# ### (IMPLEMENTATION) Obtain Bottleneck Features
#
# In the code block below, extract the bottleneck features corresponding to the train, test, and validation sets by running the following:
#
#     bottleneck_features = np.load('bottleneck_features/Dog{network}Data.npz')
#     train_{network} = bottleneck_features['train']
#     valid_{network} = bottleneck_features['valid']
#     test_{network} = bottleneck_features['test']

# %%
bottleneck_features = np.load('bottleneck_features/DogResnet50Data.npz')
train_Resnet50 = bottleneck_features['train']
valid_Resnet50 = bottleneck_features['valid']
test_Resnet50 = bottleneck_features['test']

# %% [markdown]
# ### (IMPLEMENTATION) Model Architecture
#
# Create a CNN to classify dog breed.  At the end of your code cell block, summarize the layers of your model by executing the line:
#
#         <your model's name>.summary()
#
# __Question 5:__ Outline the steps you took to get to your final CNN architecture and your reasoning at each step.  Describe why you think the architecture is suitable for the current problem.
#
# __Answer:__

# %%
### TODO: Define your architecture.

# Using Resnet Architecture since it has proven to be very good with ImageNet. 
# I tried using VGG-19, but the model was not training very fast. 
# It appears the the Resnet model is better at detecting the features that are useful for distinguishing dog breeds

Resnet50_model = Sequential()
Resnet50_model.add(GlobalAveragePooling2D(input_shape=train_Resnet50.shape[1:]))
Resnet50_model.add(Dense(133, activation='softmax'))

Resnet50_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# global_average_pooling2d_3 ( (None, 2048)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 133)               272517
# =================================================================
# Total params: 272,517
# Trainable params: 272,517
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### (IMPLEMENTATION) Compile the Model

# %%
### TODO: Compile the model.
Resnet50_model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# ### (IMPLEMENTATION) Train the Model
#
# Train your model in the code cell below.  Use model checkpointing to save the model that attains the best validation loss.
#
# You are welcome to [augment the training data](https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html), but this is not a requirement.

# %%
### TODO: Train the model.
checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.Resnet50.hdf5', 
                               verbose=1, save_best_only=True)

epochs = 20

Resnet50_model.fit(train_Resnet50, train_targets, 
          validation_data=(valid_Resnet50, valid_targets),
          epochs=epochs, batch_size=20, callbacks=[checkpointer], verbose=1)
# Out:
# Train on 6680 samples, validate on 835 samples
# Epoch 1/20
# 6640/6680 [============================>.] - ETA: 2:24 - loss: 5.2738 - acc: 0.0000e+0 - ETA: 13s - loss: 5.6157 - acc: 0.0167    - ETA: 7s - loss: 5.3687 - acc: 0.0523 - ETA: 5s - loss: 5.1508 - acc: 0.075 - ETA: 4s - loss: 4.7111 - acc: 0.117 - ETA: 3s - loss: 4.2726 - acc: 0.174 - ETA: 3s - loss: 3.9544 - acc: 0.231 - ETA: 2s - loss: 3.7300 - acc: 0.261 - ETA: 2s - loss: 3.4927 - acc: 0.296 - ETA: 2s - loss: 3.2678 - acc: 0.331 - ETA: 1s - loss: 3.0855 - acc: 0.359 - ETA: 1s - loss: 2.9409 - acc: 0.382 - ETA: 1s - loss: 2.7901 - acc: 0.406 - ETA: 1s - loss: 2.6658 - acc: 0.429 - ETA: 1s - loss: 2.5652 - acc: 0.447 - ETA: 1s - loss: 2.4681 - acc: 0.462 - ETA: 1s - loss: 2.3721 - acc: 0.479 - ETA: 0s - loss: 2.2897 - acc: 0.493 - ETA: 0s - loss: 2.2200 - acc: 0.505 - ETA: 0s - loss: 2.1666 - acc: 0.514 - ETA: 0s - loss: 2.1217 - acc: 0.524 - ETA: 0s - loss: 2.0639 - acc: 0.534 - ETA: 0s - loss: 2.0163 - acc: 0.543 - ETA: 0s - loss: 1.9700 - acc: 0.550 - ETA: 0s - loss: 1.9299 - acc: 0.557 - ETA: 0s - loss: 1.8903 - acc: 0.563 - ETA: 0s - loss: 1.8530 - acc: 0.570 - ETA: 0s - loss: 1.8120 - acc: 0.576 - ETA: 0s - loss: 1.7778 - acc: 0.582 - ETA: 0s - loss: 1.7454 - acc: 0.588 - ETA: 0s - loss: 1.7134 - acc: 0.5937
# Epoch 00001: val_loss improved from inf to 0.85243, saving model to saved_models/weights.best.Resnet50.hdf5
# 6680/6680 [==============================] - 2s 350us/step - loss: 1.7085 - acc: 0.5946 - val_loss: 0.8524 - val_acc: 0.7341
# Epoch 2/20
# 6500/6680 [============================>.] - ETA: 1s - loss: 0.4423 - acc: 0.850 - ETA: 1s - loss: 0.3867 - acc: 0.900 - ETA: 1s - loss: 0.3885 - acc: 0.889 - ETA: 1s - loss: 0.3825 - acc: 0.897 - ETA: 1s - loss: 0.3735 - acc: 0.902 - ETA: 1s - loss: 0.3840 - acc: 0.895 - ETA: 1s - loss: 0.3784 - acc: 0.898 - ETA: 1s - loss: 0.3707 - acc: 0.902 - ETA: 1s - loss: 0.3725 - acc: 0.900 - ETA: 1s - loss: 0.3741 - acc: 0.901 - ETA: 1s - loss: 0.3751 - acc: 0.900 - ETA: 0s - loss: 0.3667 - acc: 0.904 - ETA: 0s - loss: 0.3663 - acc: 0.902 - ETA: 0s - loss: 0.3643 - acc: 0.902 - ETA: 0s - loss: 0.3638 - acc: 0.903 - ETA: 0s - loss: 0.3599 - acc: 0.905 - ETA: 0s - loss: 0.3578 - acc: 0.905 - ETA: 0s - loss: 0.3567 - acc: 0.906 - ETA: 0s - loss: 0.3597 - acc: 0.905 - ETA: 0s - loss: 0.3620 - acc: 0.903 - ETA: 0s - loss: 0.3617 - acc: 0.903 - ETA: 0s - loss: 0.3600 - acc: 0.904 - ETA: 0s - loss: 0.3585 - acc: 0.904 - ETA: 0s - loss: 0.3572 - acc: 0.904 - ETA: 0s - loss: 0.3568 - acc: 0.904 - ETA: 0s - loss: 0.3554 - acc: 0.905 - ETA: 0s - loss: 0.3537 - acc: 0.906 - ETA: 0s - loss: 0.3547 - acc: 0.905 - ETA: 0s - loss: 0.3533 - acc: 0.906 - ETA: 0s - loss: 0.3553 - acc: 0.9054
# Epoch 00002: val_loss improved from 0.85243 to 0.68573, saving model to saved_models/weights.best.Resnet50.hdf5
# 6680/6680 [==============================] - 2s 253us/step - loss: 0.3546 - acc: 0.9052 - val_loss: 0.6857 - val_acc: 0.7916
# Epoch 3/20
# 6640/6680 [============================>.] - ETA: 1s - loss: 0.1638 - acc: 0.950 - ETA: 1s - loss: 0.1679 - acc: 0.980 - ETA: 1s - loss: 0.1770 - acc: 0.976 - ETA: 1s - loss: 0.1559 - acc: 0.979 - ETA: 1s - loss: 0.1562 - acc: 0.977 - ETA: 1s - loss: 0.1602 - acc: 0.975 - ETA: 1s - loss: 0.1566 - acc: 0.976 - ETA: 1s - loss: 0.1543 - acc: 0.976 - ETA: 1s - loss: 0.1556 - acc: 0.976 - ETA: 1s - loss: 0.1537 - acc: 0.976 - ETA: 0s - loss: 0.1521 - acc: 0.977 - ETA: 0s - loss: 0.1546 - acc: 0.975 - ETA: 0s - loss: 0.1547 - acc: 0.974 - ETA: 0s - loss: 0.1558 - acc: 0.975 - ETA: 0s - loss: 0.1550 - acc: 0.974 - ETA: 0s - loss: 0.1539 - acc: 0.975 - ETA: 0s - loss: 0.1534 - acc: 0.975 - ETA: 0s - loss: 0.1515 - acc: 0.975 - ETA: 0s - loss: 0.1518 - acc: 0.975 - ETA: 0s - loss: 0.1504 - acc: 0.975 - ETA: 0s - loss: 0.1505 - acc: 0.975 - ETA: 0s - loss: 0.1525 - acc: 0.973 - ETA: 0s - loss: 0.1541 - acc: 0.972 - ETA: 0s - loss: 0.1546 - acc: 0.972 - ETA: 0s - loss: 0.1558 - acc: 0.972 - ETA: 0s - loss: 0.1563 - acc: 0.972 - ETA: 0s - loss: 0.1565 - acc: 0.972 - ETA: 0s - loss: 0.1565 - acc: 0.972 - ETA: 0s - loss: 0.1586 - acc: 0.971 - ETA: 0s - loss: 0.1595 - acc: 0.9708
# Epoch 00003: val_loss improved from 0.68573 to 0.59384, saving model to saved_models/weights.best.Resnet50.hdf5
# 6680/6680 [==============================] - 2s 249us/step - loss: 0.1599 - acc: 0.9707 - val_loss: 0.5938 - val_acc: 0.8132
# Epoch 4/20
# 6460/6680 [============================>.] - ETA: 2s - loss: 0.0707 - acc: 1.000 - ETA: 1s - loss: 0.0788 - acc: 0.992 - ETA: 1s - loss: 0.0922 - acc: 0.992 - ETA: 1s - loss: 0.0927 - acc: 0.987 - ETA: 1s - loss: 0.0898 - acc: 0.987 - ETA: 1s - loss: 0.0849 - acc: 0.989 - ETA: 1s - loss: 0.0837 - acc: 0.990 - ETA: 1s - loss: 0.0826 - acc: 0.991 - ETA: 1s - loss: 0.0841 - acc: 0.992 - ETA: 1s - loss: 0.0844 - acc: 0.992 - ETA: 0s - loss: 0.0841 - acc: 0.991 - ETA: 0s - loss: 0.0856 - acc: 0.991 - ETA: 0s - loss: 0.0840 - acc: 0.991 - ETA: 0s - loss: 0.0838 - acc: 0.991 - ETA: 0s - loss: 0.0872 - acc: 0.991 - ETA: 0s - loss: 0.0868 - acc: 0.991 - ETA: 0s - loss: 0.0877 - acc: 0.990 - ETA: 0s - loss: 0.0867 - acc: 0.991 - ETA: 0s - loss: 0.0859 - acc: 0.991 - ETA: 0s - loss: 0.0866 - acc: 0.990 - ETA: 0s - loss: 0.0874 - acc: 0.991 - ETA: 0s - loss: 0.0892 - acc: 0.989 - ETA: 0s - loss: 0.0895 - acc: 0.989 - ETA: 0s - loss: 0.0896 - acc: 0.989 - ETA: 0s - loss: 0.0896 - acc: 0.989 - ETA: 0s - loss: 0.0895 - acc: 0.989 - ETA: 0s - loss: 0.0889 - acc: 0.989 - ETA: 0s - loss: 0.0893 - acc: 0.988 - ETA: 0s - loss: 0.0884 - acc: 0.988 - ETA: 0s - loss: 0.0894 - acc: 0.9887
# Epoch 00004: val_loss did not improve
# 6680/6680 [==============================] - 2s 250us/step - loss: 0.0894 - acc: 0.9886 - val_loss: 0.5961 - val_acc: 0.8168
# Epoch 5/20
# 6640/6680 [============================>.] - ETA: 1s - loss: 0.0387 - acc: 1.000 - ETA: 1s - loss: 0.0581 - acc: 0.995 - ETA: 1s - loss: 0.0572 - acc: 0.993 - ETA: 1s - loss: 0.0535 - acc: 0.995 - ETA: 1s - loss: 0.0500 - acc: 0.996 - ETA: 1s - loss: 0.0501 - acc: 0.996 - ETA: 1s - loss: 0.0497 - acc: 0.997 - ETA: 1s - loss: 0.0489 - acc: 0.996 - ETA: 1s - loss: 0.0495 - acc: 0.996 - ETA: 1s - loss: 0.0495 - acc: 0.996 - ETA: 1s - loss: 0.0486 - acc: 0.996 - ETA: 0s - loss: 0.0482 - acc: 0.996 - ETA: 0s - loss: 0.0489 - acc: 0.996 - ETA: 0s - loss: 0.0500 - acc: 0.996 - ETA: 0s - loss: 0.0512 - acc: 0.996 - ETA: 0s - loss: 0.0522 - acc: 0.996 - ETA: 0s - loss: 0.0529 - acc: 0.995 - ETA: 0s - loss: 0.0526 - acc: 0.995 - ETA: 0s - loss: 0.0531 - acc: 0.995 - ETA: 0s - loss: 0.0530 - acc: 0.995 - ETA: 0s - loss: 0.0535 - acc: 0.995 - ETA: 0s - loss: 0.0536 - acc: 0.995 - ETA: 0s - loss: 0.0539 - acc: 0.994 - ETA: 0s - loss: 0.0539 - acc: 0.994 - ETA: 0s - loss: 0.0538 - acc: 0.994 - ETA: 0s - loss: 0.0536 - acc: 0.994 - ETA: 0s - loss: 0.0549 - acc: 0.994 - ETA: 0s - loss: 0.0554 - acc: 0.994 - ETA: 0s - loss: 0.0555 - acc: 0.994 - ETA: 0s - loss: 0.0557 - acc: 0.9941
# Epoch 00005: val_loss did not improve
# 6680/6680 [==============================] - 2s 243us/step - loss: 0.0557 - acc: 0.9942 - val_loss: 0.6201 - val_acc: 0.8072
# Epoch 6/20
# 6420/6680 [===========================>..] - ETA: 1s - loss: 0.0416 - acc: 1.000 - ETA: 1s - loss: 0.0416 - acc: 0.995 - ETA: 1s - loss: 0.0374 - acc: 0.997 - ETA: 1s - loss: 0.0363 - acc: 0.998 - ETA: 1s - loss: 0.0360 - acc: 0.998 - ETA: 1s - loss: 0.0352 - acc: 0.999 - ETA: 1s - loss: 0.0345 - acc: 0.999 - ETA: 1s - loss: 0.0341 - acc: 0.999 - ETA: 1s - loss: 0.0334 - acc: 0.999 - ETA: 1s - loss: 0.0326 - acc: 0.999 - ETA: 1s - loss: 0.0342 - acc: 0.998 - ETA: 0s - loss: 0.0343 - acc: 0.998 - ETA: 0s - loss: 0.0358 - acc: 0.997 - ETA: 0s - loss: 0.0358 - acc: 0.997 - ETA: 0s - loss: 0.0356 - acc: 0.997 - ETA: 0s - loss: 0.0353 - acc: 0.997 - ETA: 0s - loss: 0.0353 - acc: 0.997 - ETA: 0s - loss: 0.0351 - acc: 0.997 - ETA: 0s - loss: 0.0362 - acc: 0.997 - ETA: 0s - loss: 0.0363 - acc: 0.997 - ETA: 0s - loss: 0.0366 - acc: 0.997 - ETA: 0s - loss: 0.0375 - acc: 0.997 - ETA: 0s - loss: 0.0378 - acc: 0.996 - ETA: 0s - loss: 0.0383 - acc: 0.996 - ETA: 0s - loss: 0.0388 - acc: 0.996 - ETA: 0s - loss: 0.0397 - acc: 0.996 - ETA: 0s - loss: 0.0402 - acc: 0.995 - ETA: 0s - loss: 0.0406 - acc: 0.995 - ETA: 0s - loss: 0.0405 - acc: 0.9956
# Epoch 00006: val_loss improved from 0.59384 to 0.56091, saving model to saved_models/weights.best.Resnet50.hdf5
# 6680/6680 [==============================] - 2s 247us/step - loss: 0.0406 - acc: 0.9957 - val_loss: 0.5609 - val_acc: 0.8240
# Epoch 7/20
# 6520/6680 [============================>.] - ETA: 2s - loss: 0.0136 - acc: 1.000 - ETA: 1s - loss: 0.0220 - acc: 1.000 - ETA: 1s - loss: 0.0219 - acc: 1.000 - ETA: 1s - loss: 0.0238 - acc: 0.998 - ETA: 1s - loss: 0.0231 - acc: 0.998 - ETA: 1s - loss: 0.0234 - acc: 0.998 - ETA: 1s - loss: 0.0228 - acc: 0.998 - ETA: 1s - loss: 0.0230 - acc: 0.998 - ETA: 1s - loss: 0.0228 - acc: 0.998 - ETA: 1s - loss: 0.0222 - acc: 0.999 - ETA: 0s - loss: 0.0222 - acc: 0.999 - ETA: 0s - loss: 0.0225 - acc: 0.998 - ETA: 0s - loss: 0.0228 - acc: 0.998 - ETA: 0s - loss: 0.0230 - acc: 0.998 - ETA: 0s - loss: 0.0229 - acc: 0.998 - ETA: 0s - loss: 0.0246 - acc: 0.998 - ETA: 0s - loss: 0.0254 - acc: 0.998 - ETA: 0s - loss: 0.0268 - acc: 0.997 - ETA: 0s - loss: 0.0269 - acc: 0.998 - ETA: 0s - loss: 0.0274 - acc: 0.997 - ETA: 0s - loss: 0.0280 - acc: 0.997 - ETA: 0s - loss: 0.0288 - acc: 0.997 - ETA: 0s - loss: 0.0292 - acc: 0.997 - ETA: 0s - loss: 0.0291 - acc: 0.997 - ETA: 0s - loss: 0.0295 - acc: 0.997 - ETA: 0s - loss: 0.0296 - acc: 0.997 - ETA: 0s - loss: 0.0297 - acc: 0.997 - ETA: 0s - loss: 0.0300 - acc: 0.997 - ETA: 0s - loss: 0.0299 - acc: 0.997 - ETA: 0s - loss: 0.0300 - acc: 0.9971
# Epoch 00007: val_loss did not improve
# 6680/6680 [==============================] - 2s 248us/step - loss: 0.0297 - acc: 0.9972 - val_loss: 0.5728 - val_acc: 0.8383
# Epoch 8/20
# 6660/6680 [============================>.] - ETA: 1s - loss: 0.0086 - acc: 1.000 - ETA: 1s - loss: 0.0160 - acc: 1.000 - ETA: 1s - loss: 0.0181 - acc: 1.000 - ETA: 1s - loss: 0.0254 - acc: 0.998 - ETA: 1s - loss: 0.0220 - acc: 0.998 - ETA: 1s - loss: 0.0235 - acc: 0.998 - ETA: 1s - loss: 0.0231 - acc: 0.998 - ETA: 1s - loss: 0.0223 - acc: 0.998 - ETA: 1s - loss: 0.0214 - acc: 0.998 - ETA: 1s - loss: 0.0208 - acc: 0.999 - ETA: 0s - loss: 0.0213 - acc: 0.998 - ETA: 0s - loss: 0.0211 - acc: 0.998 - ETA: 0s - loss: 0.0224 - acc: 0.998 - ETA: 0s - loss: 0.0219 - acc: 0.998 - ETA: 0s - loss: 0.0217 - acc: 0.998 - ETA: 0s - loss: 0.0220 - acc: 0.998 - ETA: 0s - loss: 0.0219 - acc: 0.998 - ETA: 0s - loss: 0.0216 - acc: 0.999 - ETA: 0s - loss: 0.0215 - acc: 0.999 - ETA: 0s - loss: 0.0213 - acc: 0.999 - ETA: 0s - loss: 0.0212 - acc: 0.999 - ETA: 0s - loss: 0.0213 - acc: 0.998 - ETA: 0s - loss: 0.0215 - acc: 0.998 - ETA: 0s - loss: 0.0213 - acc: 0.998 - ETA: 0s - loss: 0.0216 - acc: 0.998 - ETA: 0s - loss: 0.0216 - acc: 0.998 - ETA: 0s - loss: 0.0215 - acc: 0.998 - ETA: 0s - loss: 0.0217 - acc: 0.998 - ETA: 0s - loss: 0.0227 - acc: 0.998 - ETA: 0s - loss: 0.0234 - acc: 0.998 - ETA: 0s - loss: 0.0232 - acc: 0.9983
# Epoch 00008: val_loss improved from 0.56091 to 0.55296, saving model to saved_models/weights.best.Resnet50.hdf5
# 6680/6680 [==============================] - 2s 260us/step - loss: 0.0240 - acc: 0.9982 - val_loss: 0.5530 - val_acc: 0.8347
# Epoch 9/20
# 6600/6680 [============================>.] - ETA: 1s - loss: 0.0170 - acc: 1.000 - ETA: 1s - loss: 0.0201 - acc: 1.000 - ETA: 1s - loss: 0.0284 - acc: 0.995 - ETA: 1s - loss: 0.0259 - acc: 0.997 - ETA: 1s - loss: 0.0229 - acc: 0.997 - ETA: 1s - loss: 0.0218 - acc: 0.998 - ETA: 1s - loss: 0.0207 - acc: 0.998 - ETA: 1s - loss: 0.0195 - acc: 0.998 - ETA: 1s - loss: 0.0184 - acc: 0.998 - ETA: 1s - loss: 0.0199 - acc: 0.998 - ETA: 1s - loss: 0.0222 - acc: 0.996 - ETA: 1s - loss: 0.0216 - acc: 0.997 - ETA: 0s - loss: 0.0227 - acc: 0.996 - ETA: 0s - loss: 0.0234 - acc: 0.995 - ETA: 0s - loss: 0.0231 - acc: 0.995 - ETA: 0s - loss: 0.0236 - acc: 0.995 - ETA: 0s - loss: 0.0232 - acc: 0.996 - ETA: 0s - loss: 0.0244 - acc: 0.995 - ETA: 0s - loss: 0.0239 - acc: 0.995 - ETA: 0s - loss: 0.0256 - acc: 0.995 - ETA: 0s - loss: 0.0255 - acc: 0.995 - ETA: 0s - loss: 0.0252 - acc: 0.995 - ETA: 0s - loss: 0.0251 - acc: 0.995 - ETA: 0s - loss: 0.0255 - acc: 0.995 - ETA: 0s - loss: 0.0251 - acc: 0.995 - ETA: 0s - loss: 0.0251 - acc: 0.995 - ETA: 0s - loss: 0.0248 - acc: 0.995 - ETA: 0s - loss: 0.0253 - acc: 0.995 - ETA: 0s - loss: 0.0251 - acc: 0.995 - ETA: 0s - loss: 0.0247 - acc: 0.995 - ETA: 0s - loss: 0.0245 - acc: 0.9959
# Epoch 00009: val_loss did not improve
# 6680/6680 [==============================] - 2s 250us/step - loss: 0.0243 - acc: 0.9960 - val_loss: 0.5822 - val_acc: 0.8359
# Epoch 10/20
# 6660/6680 [============================>.] - ETA: 1s - loss: 0.0140 - acc: 1.000 - ETA: 1s - loss: 0.0138 - acc: 1.000 - ETA: 1s - loss: 0.0128 - acc: 1.000 - ETA: 1s - loss: 0.0165 - acc: 0.998 - ETA: 1s - loss: 0.0273 - acc: 0.996 - ETA: 1s - loss: 0.0327 - acc: 0.995 - ETA: 1s - loss: 0.0303 - acc: 0.995 - ETA: 1s - loss: 0.0279 - acc: 0.996 - ETA: 1s - loss: 0.0294 - acc: 0.995 - ETA: 1s - loss: 0.0273 - acc: 0.995 - ETA: 1s - loss: 0.0260 - acc: 0.996 - ETA: 0s - loss: 0.0275 - acc: 0.995 - ETA: 0s - loss: 0.0262 - acc: 0.996 - ETA: 0s - loss: 0.0253 - acc: 0.996 - ETA: 0s - loss: 0.0241 - acc: 0.996 - ETA: 0s - loss: 0.0234 - acc: 0.997 - ETA: 0s - loss: 0.0227 - acc: 0.997 - ETA: 0s - loss: 0.0230 - acc: 0.996 - ETA: 0s - loss: 0.0222 - acc: 0.997 - ETA: 0s - loss: 0.0215 - acc: 0.997 - ETA: 0s - loss: 0.0210 - acc: 0.997 - ETA: 0s - loss: 0.0206 - acc: 0.997 - ETA: 0s - loss: 0.0220 - acc: 0.997 - ETA: 0s - loss: 0.0218 - acc: 0.997 - ETA: 0s - loss: 0.0215 - acc: 0.997 - ETA: 0s - loss: 0.0221 - acc: 0.997 - ETA: 0s - loss: 0.0221 - acc: 0.997 - ETA: 0s - loss: 0.0236 - acc: 0.997 - ETA: 0s - loss: 0.0234 - acc: 0.996 - ETA: 0s - loss: 0.0231 - acc: 0.997 - ETA: 0s - loss: 0.0227 - acc: 0.9971
# Epoch 00010: val_loss did not improve
# 6680/6680 [==============================] - 2s 246us/step - loss: 0.0227 - acc: 0.9972 - val_loss: 0.5684 - val_acc: 0.8359
# Epoch 11/20
# 6640/6680 [============================>.] - ETA: 1s - loss: 0.0027 - acc: 1.000 - ETA: 1s - loss: 0.0080 - acc: 1.000 - ETA: 1s - loss: 0.0080 - acc: 1.000 - ETA: 1s - loss: 0.0078 - acc: 1.000 - ETA: 1s - loss: 0.0082 - acc: 1.000 - ETA: 1s - loss: 0.0082 - acc: 1.000 - ETA: 1s - loss: 0.0083 - acc: 1.000 - ETA: 1s - loss: 0.0084 - acc: 1.000 - ETA: 1s - loss: 0.0103 - acc: 0.999 - ETA: 1s - loss: 0.0120 - acc: 0.999 - ETA: 0s - loss: 0.0130 - acc: 0.998 - ETA: 0s - loss: 0.0128 - acc: 0.998 - ETA: 0s - loss: 0.0126 - acc: 0.998 - ETA: 0s - loss: 0.0124 - acc: 0.998 - ETA: 0s - loss: 0.0123 - acc: 0.998 - ETA: 0s - loss: 0.0145 - acc: 0.998 - ETA: 0s - loss: 0.0142 - acc: 0.998 - ETA: 0s - loss: 0.0138 - acc: 0.998 - ETA: 0s - loss: 0.0139 - acc: 0.998 - ETA: 0s - loss: 0.0136 - acc: 0.998 - ETA: 0s - loss: 0.0134 - acc: 0.998 - ETA: 0s - loss: 0.0141 - acc: 0.998 - ETA: 0s - loss: 0.0144 - acc: 0.998 - ETA: 0s - loss: 0.0147 - acc: 0.998 - ETA: 0s - loss: 0.0152 - acc: 0.998 - ETA: 0s - loss: 0.0151 - acc: 0.998 - ETA: 0s - loss: 0.0167 - acc: 0.998 - ETA: 0s - loss: 0.0168 - acc: 0.998 - ETA: 0s - loss: 0.0165 - acc: 0.998 - ETA: 0s - loss: 0.0162 - acc: 0.9982
# Epoch 00011: val_loss did not improve
# 6680/6680 [==============================] - 2s 242us/step - loss: 0.0161 - acc: 0.9982 - val_loss: 0.5708 - val_acc: 0.8347
# Epoch 12/20
# 6560/6680 [============================>.] - ETA: 1s - loss: 0.0051 - acc: 1.000 - ETA: 1s - loss: 0.0074 - acc: 1.000 - ETA: 1s - loss: 0.0079 - acc: 1.000 - ETA: 1s - loss: 0.0074 - acc: 1.000 - ETA: 1s - loss: 0.0070 - acc: 1.000 - ETA: 1s - loss: 0.0100 - acc: 0.999 - ETA: 1s - loss: 0.0098 - acc: 0.999 - ETA: 1s - loss: 0.0096 - acc: 0.999 - ETA: 1s - loss: 0.0093 - acc: 0.999 - ETA: 1s - loss: 0.0113 - acc: 0.999 - ETA: 1s - loss: 0.0112 - acc: 0.999 - ETA: 0s - loss: 0.0111 - acc: 0.998 - ETA: 0s - loss: 0.0138 - acc: 0.997 - ETA: 0s - loss: 0.0155 - acc: 0.997 - ETA: 0s - loss: 0.0164 - acc: 0.996 - ETA: 0s - loss: 0.0159 - acc: 0.997 - ETA: 0s - loss: 0.0162 - acc: 0.996 - ETA: 0s - loss: 0.0165 - acc: 0.996 - ETA: 0s - loss: 0.0161 - acc: 0.997 - ETA: 0s - loss: 0.0163 - acc: 0.997 - ETA: 0s - loss: 0.0158 - acc: 0.997 - ETA: 0s - loss: 0.0154 - acc: 0.997 - ETA: 0s - loss: 0.0150 - acc: 0.997 - ETA: 0s - loss: 0.0147 - acc: 0.997 - ETA: 0s - loss: 0.0148 - acc: 0.997 - ETA: 0s - loss: 0.0152 - acc: 0.997 - ETA: 0s - loss: 0.0150 - acc: 0.997 - ETA: 0s - loss: 0.0147 - acc: 0.997 - ETA: 0s - loss: 0.0145 - acc: 0.997 - ETA: 0s - loss: 0.0149 - acc: 0.9976
# Epoch 00012: val_loss did not improve
# 6680/6680 [==============================] - 2s 243us/step - loss: 0.0153 - acc: 0.9973 - val_loss: 0.5982 - val_acc: 0.8479
# Epoch 13/20
# 6500/6680 [============================>.] - ETA: 1s - loss: 0.0074 - acc: 1.000 - ETA: 1s - loss: 0.0062 - acc: 1.000 - ETA: 1s - loss: 0.0142 - acc: 0.997 - ETA: 1s - loss: 0.0136 - acc: 0.998 - ETA: 1s - loss: 0.0116 - acc: 0.998 - ETA: 1s - loss: 0.0103 - acc: 0.999 - ETA: 1s - loss: 0.0094 - acc: 0.999 - ETA: 1s - loss: 0.0089 - acc: 0.999 - ETA: 1s - loss: 0.0087 - acc: 0.999 - ETA: 1s - loss: 0.0084 - acc: 0.999 - ETA: 1s - loss: 0.0106 - acc: 0.999 - ETA: 1s - loss: 0.0104 - acc: 0.999 - ETA: 0s - loss: 0.0108 - acc: 0.998 - ETA: 0s - loss: 0.0104 - acc: 0.999 - ETA: 0s - loss: 0.0102 - acc: 0.999 - ETA: 0s - loss: 0.0129 - acc: 0.998 - ETA: 0s - loss: 0.0149 - acc: 0.997 - ETA: 0s - loss: 0.0146 - acc: 0.997 - ETA: 0s - loss: 0.0160 - acc: 0.997 - ETA: 0s - loss: 0.0158 - acc: 0.997 - ETA: 0s - loss: 0.0163 - acc: 0.997 - ETA: 0s - loss: 0.0163 - acc: 0.997 - ETA: 0s - loss: 0.0161 - acc: 0.997 - ETA: 0s - loss: 0.0166 - acc: 0.997 - ETA: 0s - loss: 0.0176 - acc: 0.996 - ETA: 0s - loss: 0.0178 - acc: 0.996 - ETA: 0s - loss: 0.0181 - acc: 0.996 - ETA: 0s - loss: 0.0187 - acc: 0.996 - ETA: 0s - loss: 0.0184 - acc: 0.996 - ETA: 0s - loss: 0.0183 - acc: 0.9962
# Epoch 00013: val_loss did not improve
# 6680/6680 [==============================] - 2s 248us/step - loss: 0.0181 - acc: 0.9963 - val_loss: 0.6187 - val_acc: 0.8263
# Epoch 14/20
# 6480/6680 [============================>.] - ETA: 1s - loss: 0.0072 - acc: 1.000 - ETA: 1s - loss: 0.0086 - acc: 1.000 - ETA: 1s - loss: 0.0095 - acc: 0.997 - ETA: 1s - loss: 0.0085 - acc: 0.998 - ETA: 1s - loss: 0.0082 - acc: 0.998 - ETA: 1s - loss: 0.0087 - acc: 0.999 - ETA: 1s - loss: 0.0086 - acc: 0.999 - ETA: 1s - loss: 0.0125 - acc: 0.998 - ETA: 1s - loss: 0.0155 - acc: 0.997 - ETA: 1s - loss: 0.0149 - acc: 0.997 - ETA: 1s - loss: 0.0154 - acc: 0.997 - ETA: 1s - loss: 0.0144 - acc: 0.997 - ETA: 0s - loss: 0.0142 - acc: 0.998 - ETA: 0s - loss: 0.0141 - acc: 0.998 - ETA: 0s - loss: 0.0148 - acc: 0.998 - ETA: 0s - loss: 0.0152 - acc: 0.997 - ETA: 0s - loss: 0.0161 - acc: 0.997 - ETA: 0s - loss: 0.0165 - acc: 0.997 - ETA: 0s - loss: 0.0165 - acc: 0.997 - ETA: 0s - loss: 0.0160 - acc: 0.997 - ETA: 0s - loss: 0.0168 - acc: 0.997 - ETA: 0s - loss: 0.0169 - acc: 0.997 - ETA: 0s - loss: 0.0169 - acc: 0.997 - ETA: 0s - loss: 0.0166 - acc: 0.997 - ETA: 0s - loss: 0.0163 - acc: 0.997 - ETA: 0s - loss: 0.0166 - acc: 0.997 - ETA: 0s - loss: 0.0180 - acc: 0.996 - ETA: 0s - loss: 0.0189 - acc: 0.996 - ETA: 0s - loss: 0.0187 - acc: 0.996 - ETA: 0s - loss: 0.0185 - acc: 0.9966
# Epoch 00014: val_loss did not improve
# 6680/6680 [==============================] - 2s 246us/step - loss: 0.0185 - acc: 0.9966 - val_loss: 0.6506 - val_acc: 0.8395
# Epoch 15/20
# 6500/6680 [============================>.] - ETA: 1s - loss: 0.0054 - acc: 1.000 - ETA: 1s - loss: 0.0163 - acc: 0.995 - ETA: 1s - loss: 0.0120 - acc: 0.997 - ETA: 1s - loss: 0.0110 - acc: 0.998 - ETA: 1s - loss: 0.0100 - acc: 0.998 - ETA: 1s - loss: 0.0098 - acc: 0.998 - ETA: 1s - loss: 0.0088 - acc: 0.998 - ETA: 1s - loss: 0.0082 - acc: 0.998 - ETA: 1s - loss: 0.0080 - acc: 0.998 - ETA: 1s - loss: 0.0076 - acc: 0.999 - ETA: 1s - loss: 0.0075 - acc: 0.999 - ETA: 0s - loss: 0.0071 - acc: 0.999 - ETA: 0s - loss: 0.0071 - acc: 0.999 - ETA: 0s - loss: 0.0069 - acc: 0.999 - ETA: 0s - loss: 0.0069 - acc: 0.999 - ETA: 0s - loss: 0.0068 - acc: 0.999 - ETA: 0s - loss: 0.0066 - acc: 0.999 - ETA: 0s - loss: 0.0067 - acc: 0.999 - ETA: 0s - loss: 0.0076 - acc: 0.999 - ETA: 0s - loss: 0.0088 - acc: 0.998 - ETA: 0s - loss: 0.0086 - acc: 0.998 - ETA: 0s - loss: 0.0087 - acc: 0.998 - ETA: 0s - loss: 0.0095 - acc: 0.998 - ETA: 0s - loss: 0.0096 - acc: 0.998 - ETA: 0s - loss: 0.0103 - acc: 0.998 - ETA: 0s - loss: 0.0107 - acc: 0.998 - ETA: 0s - loss: 0.0128 - acc: 0.997 - ETA: 0s - loss: 0.0126 - acc: 0.997 - ETA: 0s - loss: 0.0125 - acc: 0.997 - ETA: 0s - loss: 0.0137 - acc: 0.9978
# Epoch 00015: val_loss did not improve
# 6680/6680 [==============================] - 2s 246us/step - loss: 0.0140 - acc: 0.9976 - val_loss: 0.7402 - val_acc: 0.8204
# Epoch 16/20
# 6640/6680 [============================>.] - ETA: 1s - loss: 0.0023 - acc: 1.000 - ETA: 1s - loss: 0.0145 - acc: 0.990 - ETA: 1s - loss: 0.0104 - acc: 0.995 - ETA: 1s - loss: 0.0101 - acc: 0.997 - ETA: 1s - loss: 0.0133 - acc: 0.996 - ETA: 1s - loss: 0.0143 - acc: 0.995 - ETA: 1s - loss: 0.0136 - acc: 0.995 - ETA: 1s - loss: 0.0142 - acc: 0.995 - ETA: 1s - loss: 0.0156 - acc: 0.995 - ETA: 1s - loss: 0.0167 - acc: 0.994 - ETA: 0s - loss: 0.0176 - acc: 0.994 - ETA: 0s - loss: 0.0195 - acc: 0.994 - ETA: 0s - loss: 0.0229 - acc: 0.993 - ETA: 0s - loss: 0.0247 - acc: 0.993 - ETA: 0s - loss: 0.0239 - acc: 0.993 - ETA: 0s - loss: 0.0229 - acc: 0.994 - ETA: 0s - loss: 0.0223 - acc: 0.994 - ETA: 0s - loss: 0.0235 - acc: 0.994 - ETA: 0s - loss: 0.0223 - acc: 0.994 - ETA: 0s - loss: 0.0213 - acc: 0.994 - ETA: 0s - loss: 0.0205 - acc: 0.995 - ETA: 0s - loss: 0.0214 - acc: 0.994 - ETA: 0s - loss: 0.0217 - acc: 0.994 - ETA: 0s - loss: 0.0215 - acc: 0.994 - ETA: 0s - loss: 0.0209 - acc: 0.994 - ETA: 0s - loss: 0.0203 - acc: 0.995 - ETA: 0s - loss: 0.0202 - acc: 0.995 - ETA: 0s - loss: 0.0204 - acc: 0.995 - ETA: 0s - loss: 0.0207 - acc: 0.995 - ETA: 0s - loss: 0.0202 - acc: 0.9952
# Epoch 00016: val_loss did not improve
# 6680/6680 [==============================] - 2s 243us/step - loss: 0.0202 - acc: 0.9952 - val_loss: 0.6410 - val_acc: 0.8347
# Epoch 17/20
# 6620/6680 [============================>.] - ETA: 1s - loss: 0.0033 - acc: 1.000 - ETA: 1s - loss: 0.0041 - acc: 1.000 - ETA: 1s - loss: 0.0036 - acc: 1.000 - ETA: 1s - loss: 0.0102 - acc: 0.998 - ETA: 1s - loss: 0.0087 - acc: 0.998 - ETA: 1s - loss: 0.0077 - acc: 0.999 - ETA: 1s - loss: 0.0074 - acc: 0.999 - ETA: 1s - loss: 0.0074 - acc: 0.998 - ETA: 1s - loss: 0.0122 - acc: 0.997 - ETA: 1s - loss: 0.0113 - acc: 0.997 - ETA: 1s - loss: 0.0147 - acc: 0.996 - ETA: 0s - loss: 0.0172 - acc: 0.996 - ETA: 0s - loss: 0.0164 - acc: 0.996 - ETA: 0s - loss: 0.0163 - acc: 0.996 - ETA: 0s - loss: 0.0164 - acc: 0.996 - ETA: 0s - loss: 0.0170 - acc: 0.995 - ETA: 0s - loss: 0.0174 - acc: 0.995 - ETA: 0s - loss: 0.0178 - acc: 0.994 - ETA: 0s - loss: 0.0182 - acc: 0.994 - ETA: 0s - loss: 0.0215 - acc: 0.994 - ETA: 0s - loss: 0.0263 - acc: 0.993 - ETA: 0s - loss: 0.0274 - acc: 0.992 - ETA: 0s - loss: 0.0294 - acc: 0.992 - ETA: 0s - loss: 0.0343 - acc: 0.991 - ETA: 0s - loss: 0.0380 - acc: 0.990 - ETA: 0s - loss: 0.0402 - acc: 0.990 - ETA: 0s - loss: 0.0425 - acc: 0.989 - ETA: 0s - loss: 0.0458 - acc: 0.989 - ETA: 0s - loss: 0.0485 - acc: 0.988 - ETA: 0s - loss: 0.0496 - acc: 0.988 - ETA: 0s - loss: 0.0503 - acc: 0.9875
# Epoch 00017: val_loss did not improve
# 6680/6680 [==============================] - 2s 250us/step - loss: 0.0507 - acc: 0.9873 - val_loss: 0.9310 - val_acc: 0.7820
# Epoch 18/20
# 6640/6680 [============================>.] - ETA: 1s - loss: 0.1005 - acc: 0.950 - ETA: 1s - loss: 0.0905 - acc: 0.970 - ETA: 1s - loss: 0.0897 - acc: 0.973 - ETA: 1s - loss: 0.0880 - acc: 0.977 - ETA: 1s - loss: 0.0804 - acc: 0.979 - ETA: 1s - loss: 0.0744 - acc: 0.981 - ETA: 1s - loss: 0.1180 - acc: 0.974 - ETA: 1s - loss: 0.1259 - acc: 0.970 - ETA: 1s - loss: 0.1175 - acc: 0.972 - ETA: 1s - loss: 0.1141 - acc: 0.973 - ETA: 1s - loss: 0.1151 - acc: 0.971 - ETA: 1s - loss: 0.1092 - acc: 0.972 - ETA: 1s - loss: 0.1064 - acc: 0.972 - ETA: 0s - loss: 0.1017 - acc: 0.973 - ETA: 0s - loss: 0.0983 - acc: 0.974 - ETA: 0s - loss: 0.0990 - acc: 0.973 - ETA: 0s - loss: 0.0986 - acc: 0.973 - ETA: 0s - loss: 0.0971 - acc: 0.974 - ETA: 0s - loss: 0.0965 - acc: 0.974 - ETA: 0s - loss: 0.0960 - acc: 0.974 - ETA: 0s - loss: 0.0957 - acc: 0.973 - ETA: 0s - loss: 0.0941 - acc: 0.974 - ETA: 0s - loss: 0.0924 - acc: 0.974 - ETA: 0s - loss: 0.0911 - acc: 0.974 - ETA: 0s - loss: 0.0896 - acc: 0.974 - ETA: 0s - loss: 0.0890 - acc: 0.974 - ETA: 0s - loss: 0.0904 - acc: 0.974 - ETA: 0s - loss: 0.0899 - acc: 0.974 - ETA: 0s - loss: 0.0912 - acc: 0.973 - ETA: 0s - loss: 0.0938 - acc: 0.973 - ETA: 0s - loss: 0.0943 - acc: 0.9726
# Epoch 00018: val_loss did not improve
# 6680/6680 [==============================] - 2s 250us/step - loss: 0.0954 - acc: 0.9725 - val_loss: 0.9913 - val_acc: 0.7772
# Epoch 19/20
# 6520/6680 [============================>.] - ETA: 2s - loss: 0.0256 - acc: 1.000 - ETA: 1s - loss: 0.0709 - acc: 0.973 - ETA: 1s - loss: 0.0639 - acc: 0.974 - ETA: 1s - loss: 0.0664 - acc: 0.975 - ETA: 1s - loss: 0.0652 - acc: 0.978 - ETA: 1s - loss: 0.0561 - acc: 0.982 - ETA: 1s - loss: 0.0544 - acc: 0.982 - ETA: 1s - loss: 0.0578 - acc: 0.983 - ETA: 1s - loss: 0.0597 - acc: 0.983 - ETA: 1s - loss: 0.0553 - acc: 0.984 - ETA: 1s - loss: 0.0531 - acc: 0.984 - ETA: 0s - loss: 0.0548 - acc: 0.984 - ETA: 0s - loss: 0.0587 - acc: 0.983 - ETA: 0s - loss: 0.0622 - acc: 0.982 - ETA: 0s - loss: 0.0639 - acc: 0.981 - ETA: 0s - loss: 0.0635 - acc: 0.981 - ETA: 0s - loss: 0.0625 - acc: 0.981 - ETA: 0s - loss: 0.0615 - acc: 0.982 - ETA: 0s - loss: 0.0643 - acc: 0.982 - ETA: 0s - loss: 0.0631 - acc: 0.982 - ETA: 0s - loss: 0.0640 - acc: 0.982 - ETA: 0s - loss: 0.0628 - acc: 0.982 - ETA: 0s - loss: 0.0616 - acc: 0.982 - ETA: 0s - loss: 0.0597 - acc: 0.983 - ETA: 0s - loss: 0.0578 - acc: 0.983 - ETA: 0s - loss: 0.0571 - acc: 0.983 - ETA: 0s - loss: 0.0558 - acc: 0.984 - ETA: 0s - loss: 0.0566 - acc: 0.984 - ETA: 0s - loss: 0.0564 - acc: 0.984 - ETA: 0s - loss: 0.0559 - acc: 0.9840
# Epoch 00019: val_loss did not improve
# 6680/6680 [==============================] - 2s 244us/step - loss: 0.0560 - acc: 0.9841 - val_loss: 0.8806 - val_acc: 0.8084
# Epoch 20/20
# 6540/6680 [============================>.] - ETA: 2s - loss: 0.0520 - acc: 0.950 - ETA: 1s - loss: 0.0178 - acc: 0.991 - ETA: 1s - loss: 0.0183 - acc: 0.993 - ETA: 1s - loss: 0.0218 - acc: 0.991 - ETA: 1s - loss: 0.0259 - acc: 0.992 - ETA: 1s - loss: 0.0229 - acc: 0.994 - ETA: 1s - loss: 0.0235 - acc: 0.994 - ETA: 1s - loss: 0.0208 - acc: 0.995 - ETA: 1s - loss: 0.0211 - acc: 0.994 - ETA: 1s - loss: 0.0194 - acc: 0.995 - ETA: 0s - loss: 0.0183 - acc: 0.995 - ETA: 0s - loss: 0.0214 - acc: 0.994 - ETA: 0s - loss: 0.0202 - acc: 0.994 - ETA: 0s - loss: 0.0202 - acc: 0.994 - ETA: 0s - loss: 0.0197 - acc: 0.994 - ETA: 0s - loss: 0.0203 - acc: 0.994 - ETA: 0s - loss: 0.0216 - acc: 0.994 - ETA: 0s - loss: 0.0215 - acc: 0.994 - ETA: 0s - loss: 0.0222 - acc: 0.994 - ETA: 0s - loss: 0.0224 - acc: 0.994 - ETA: 0s - loss: 0.0222 - acc: 0.994 - ETA: 0s - loss: 0.0219 - acc: 0.994 - ETA: 0s - loss: 0.0210 - acc: 0.994 - ETA: 0s - loss: 0.0203 - acc: 0.994 - ETA: 0s - loss: 0.0196 - acc: 0.994 - ETA: 0s - loss: 0.0193 - acc: 0.994 - ETA: 0s - loss: 0.0187 - acc: 0.995 - ETA: 0s - loss: 0.0182 - acc: 0.995 - ETA: 0s - loss: 0.0182 - acc: 0.995 - ETA: 0s - loss: 0.0177 - acc: 0.9954
# Epoch 00020: val_loss did not improve
# 6680/6680 [==============================] - 2s 244us/step - loss: 0.0175 - acc: 0.9955 - val_loss: 0.8114 - val_acc: 0.8036

# %% [markdown]
# ### (IMPLEMENTATION) Load the Model with the Best Validation Loss

# %%
### TODO: Load the model weights with the best validation loss.
Resnet50_model.load_weights('saved_models/weights.best.Resnet50.hdf5')

# %% [markdown]
# ### (IMPLEMENTATION) Test the Model
#
# Try out your model on the test dataset of dog images. Ensure that your test accuracy is greater than 60%.

# %%
### TODO: Calculate classification accuracy on the test dataset.
# get index of predicted dog breed for each image in test set
Resnet50_predictions = [np.argmax(Resnet50_model.predict(np.expand_dims(feature, axis=0))) for feature in test_Resnet50]

# report test accuracy
test_accuracy = 100*np.sum(np.array(Resnet50_predictions)==np.argmax(test_targets, axis=1))/len(Resnet50_predictions)
print('Test accuracy: %.4f%%' % test_accuracy)
# Out:
# Test accuracy: 82.1770%

# %% [markdown]
# ### (IMPLEMENTATION) Predict Dog Breed with the Model
#
# Write a function that takes an image path as input and returns the dog breed (`Affenpinscher`, `Afghan_hound`, etc) that is predicted by your model.
#
# Similar to the analogous function in Step 5, your function should have three steps:
# 1. Extract the bottleneck features corresponding to the chosen CNN model.
# 2. Supply the bottleneck features as input to the model to return the predicted vector.  Note that the argmax of this prediction vector gives the index of the predicted dog breed.
# 3. Use the `dog_names` array defined in Step 0 of this notebook to return the corresponding breed.
#
# The functions to extract the bottleneck features can be found in `extract_bottleneck_features.py`, and they have been imported in an earlier code cell.  To obtain the bottleneck features corresponding to your chosen CNN architecture, you need to use the function
#
#     extract_{network}
#
# where `{network}`, in the above filename, should be one of `VGG19`, `Resnet50`, `InceptionV3`, or `Xception`.

# %%
### TODO: Write a function that takes a path to an image as input
### and returns the dog breed that is predicted by the model.

from extract_bottleneck_features import *

def Resnet50_predict_breed(img_path):
    # extract bottleneck features
    bottleneck_feature = extract_Resnet50(path_to_tensor(img_path))
    # obtain predicted vector
    predicted_vector = Resnet50_model.predict(bottleneck_feature)
    
    # return dog breed that is predicted by the model
    return dog_names[np.argmax(predicted_vector)]

# %% [markdown]
# ---
# <a id='step6'></a>
# ## Step 6: Write your Algorithm
#
# Write an algorithm that accepts a file path to an image and first determines whether the image contains a human, dog, or neither.  Then,
# - if a __dog__ is detected in the image, return the predicted breed.
# - if a __human__ is detected in the image, return the resembling dog breed.
# - if __neither__ is detected in the image, provide output that indicates an error.
#
# You are welcome to write your own functions for detecting humans and dogs in images, but feel free to use the `face_detector` and `dog_detector` functions developed above.  You are __required__ to use your CNN from Step 5 to predict dog breed.
#
# Some sample output for our algorithm is provided below, but feel free to design your own user experience!
#
# ![Sample Human Output](images/sample_human_output.png)
#
#
# ### (IMPLEMENTATION) Write your Algorithm

# %%
### TODO: Write your algorithm.
### Feel free to use as many code cells as needed.
def dog_algorithm(image_path):
    breed = Resnet50_predict_breed(image_path)
    if dog_detector(image_path):
        print('dog breed is ' + breed)
    else:
        print('person looks like ' + breed)
        
    image = cv2.imread(image_path)
    cv_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    plt.imshow(cv_rgb)
    plt.show()

# %% [markdown]
# ---
# <a id='step7'></a>
# ## Step 7: Test Your Algorithm
#
# In this section, you will take your new algorithm for a spin!  What kind of dog does the algorithm think that __you__ look like?  If you have a dog, does it predict your dog's breed accurately?  If you have a cat, does it mistakenly think that your cat is a dog?
#
# ### (IMPLEMENTATION) Test Your Algorithm on Sample Images!
#
# Test your algorithm at least six images on your computer.  Feel free to use any images you like.  Use at least two human and two dog images.
#
# __Question 6:__ Is the output better than you expected :) ?  Or worse :( ?  Provide at least three possible points of improvement for your algorithm.
#
# __Answer:__

# %%
## TODO: Execute your algorithm from Step 6 on
## at least 6 images on your computer.
## Feel free to use as many code cells as needed.
sample_images = np.array(glob("sampleImages/*"))

for image_path in sample_images:
    dog_algorithm(image_path)
# Out:
# person looks like Bichon_frise
# dog breed is American_eskimo_dog
# dog breed is Leonberger
# dog breed is Labrador_retriever
# person looks like Borzoi
# person looks like Manchester_terrier
